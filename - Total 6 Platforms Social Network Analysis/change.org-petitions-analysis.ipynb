# %%
import pandas as pd
from matplotlib import pyplot as plt
from collections import Counter

# %%
dataset = '/home/sergei/data/change_org_petitions_Amber_Heard_at_20211005-222550_limit_1000_offset_0_delay_ms_500.csv'

# %%
df = pd.read_csv(dataset)
df
# Out:
#            _index      _type                    _id    _score  \
# 0    petitions-en  petitions  20569720::Amber Heard  7.115500
# 1    petitions-en  petitions  26062476::Amber Heard  6.871536
# 2    petitions-en  petitions  25704328::Amber Heard  6.744285
# 3    petitions-en  petitions  25752458::Amber Heard  6.438685
# 4    petitions-en  petitions  13641580::Amber Heard  6.325689
# ..            ...        ...                    ...       ...
# 288  petitions-en  petitions   4373742::Amber Heard  0.669221
# 289  petitions-en  petitions  23141324::Amber Heard  0.633609
# 290  petitions-en  petitions  13269107::Amber Heard  0.567439
# 291  petitions-en  petitions               13392951  0.507148
# 292  petitions-en  petitions               14168553  0.453598
#
#      _source__total_signature_count _source__created_locale  \
# 0                             23844                   en-US
# 1                             13594                   en-US
# 2                             34486                  es-419
# 3                             38987                   en-US
# 4                             11460                   ru-RU
# ..                              ...                     ...
# 288                               5                   en-US
# 289                              12                   en-US
# 290                               6                   en-GB
# 291                               8                   en-US
# 292                               7                  es-419
#
#     _source__first_name  _source__weekly_signature_count  \
# 0                 Linda                              324
# 1              Kasandra                               77
# 2                Alexis                              116
# 3               Dominic                               31
# 4                   Ksu                                5
# ..                  ...                              ...
# 288           Michael S                                0
# 289              Hunter                                0
# 290                 Tom                                0
# 291             Crystal                                0
# 292               Bruce                                1
#
#     _source__recent_activity_date  _source__is_pledge  ...  \
# 0            2020-03-01T07:41:24Z               False  ...
# 1            2021-01-14T22:55:30Z               False  ...
# 2            2020-11-07T02:37:54Z               False  ...
# 3            2021-05-15T19:11:39Z               False  ...
# 4            2019-11-16T18:31:44Z               False  ...
# ..                            ...                 ...  ...
# 288          2015-09-28T21:04:19Z               False  ...
# 289          2020-06-28T21:44:07Z               False  ...
# 290          2018-06-09T01:51:59Z               False  ...
# 291          2018-07-19T22:06:26Z               False  ...
# 292          2019-01-12T14:41:48Z               False  ...
#
#     petition__organization__photo_id petition__photo  \
# 0                                NaN             NaN
# 1                                NaN             NaN
# 2                                NaN             NaN
# 3                                NaN             NaN
# 4                                NaN             NaN
# ..                               ...             ...
# 288                              NaN             NaN
# 289                              NaN             NaN
# 290                              NaN             NaN
# 291                              NaN             NaN
# 292                              NaN             NaN
#
#      petition__restricted_location__city  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 288                                  NaN
# 289                                  NaN
# 290                                  NaN
# 291                                  NaN
# 292                                  NaN
#
#      petition__restricted_location__country_code  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 288                                          NaN
# 289                                          NaN
# 290                                          NaN
# 291                                          NaN
# 292                                          NaN
#
#     petition__restricted_location__lat  petition__restricted_location__lng  \
# 0                                  NaN                                 NaN
# 1                                  NaN                                 NaN
# 2                                  NaN                                 NaN
# 3                                  NaN                                 NaN
# 4                                  NaN                                 NaN
# ..                                 ...                                 ...
# 288                                NaN                                 NaN
# 289                                NaN                                 NaN
# 290                                NaN                                 NaN
# 291                                NaN                                 NaN
# 292                                NaN                                 NaN
#
#     petition__restricted_location__state_code  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 288                                       NaN
# 289                                       NaN
# 290                                       NaN
# 291                                       NaN
# 292                                       NaN
#
#      petition__restricted_location__google_places_id  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 288                                              NaN
# 289                                              NaN
# 290                                              NaN
# 291                                              NaN
# 292                                              NaN
#
#     petition__restricted_location__photo_id  petition__missingPetition
# 0                                       NaN                        NaN
# 1                                       NaN                        NaN
# 2                                       NaN                        NaN
# 3                                       NaN                        NaN
# 4                                       NaN                        NaN
# ..                                      ...                        ...
# 288                                     NaN                        NaN
# 289                                     NaN                        NaN
# 290                                     NaN                        NaN
# 291                                     NaN                       True
# 292                                     NaN                       True
#
# [293 rows x 367 columns]

# %%
# removing columns with ==1 entry
col_unique_vals = {col: len(set(df[col])) for col in df.columns}
for col, vals in col_unique_vals.items():
    if vals <= 1:
        print("dropping", col)
        del df[col]
# Out:
# dropping _index
# dropping _type
# dropping _source__is_pledge
# dropping _source__discoverable

# %%
list(df.columns)
# Out:
# ['_id',
#  '_score',
#  '_source__total_signature_count',
#  '_source__created_locale',
#  '_source__first_name',
#  '_source__weekly_signature_count',
#  '_source__recent_activity_date',
#  '_source__targeting_description',
#  '_source__created_at',
#  '_source__user_id',
#  '_source__victory',
#  '_source__victory_date',
#  '_source__status',
#  '_source__user_city',
#  '_source__user_photo_id',
#  '_source__tag_objects',
#  '_source__coachable',
#  '_source__sponsored_campaign',
#  '_source__tag_names',
#  '_source__country_code',
#  '_source__user_state',
#  '_source__sponsorship_active',
#  '_source__relevant_location',
#  '_source__movement_ids',
#  '_source__petition_id',
#  '_source__last_name',
#  '_source__slug',
#  '_source__petition_photo_id',
#  '_source__ask',
#  'highlight__letter_body',
#  'highlight__description',
#  'highlight__ask',
#  'petition__id',
#  'petition__document_id',
#  'petition__ask',
#  'petition__created_at',
#  'petition__deleted_at',
#  'petition__published_at',
#  'petition__last_edited_at',
#  'petition__original_locale',
#  'petition__languages',
#  'petition__title',
#  'petition__description',
#  'petition__targeting_description',
#  'petition__letter_body',
#  'petition__end_date',
#  'petition__goal',
#  'petition__relevant_location__city',
#  'petition__relevant_location__country_code',
#  'petition__relevant_location__lat',
#  'petition__relevant_location__lng',
#  'petition__relevant_location__state_code',
#  'petition__relevant_location__google_places_id',
#  'petition__relevant_location__photo_id',
#  'petition__restricted_location',
#  'petition__slug',
#  'petition__status',
#  'petition__victory_date',
#  'petition__victory_description',
#  'petition__is_verified_victory',
#  'petition__is_victory',
#  'petition__video',
#  'petition__is_pledge',
#  'petition__topic',
#  'petition__tags',
#  'petition__discoverable',
#  'petition__sponsored_campaign',
#  'petition__organization_free_email_optins',
#  'petition__displayed_signature_count',
#  'petition__total_signature_count',
#  'petition__weekly_signature_count',
#  'petition__total_page_views',
#  'petition__total_share_count',
#  'petition__daily_signature_count',
#  'petition__monthly_signature_count',
#  'petition__daily_signup_count',
#  'petition__weekly_signup_count',
#  'petition__monthly_signup_count',
#  'petition__total_signup_count',
#  'petition__supporter_message_count',
#  'petition__starter_vanity_url',
#  'petition__activity__recruit.copylink.count',
#  'petition__activity__recruit.copylink.last_updated',
#  'petition__activity__recruit.email.count',
#  'petition__activity__recruit.email.last_updated',
#  'petition__activity__recruit.facebook.count',
#  'petition__activity__recruit.facebook.last_updated',
#  'petition__activity__recruit.facebook_messenger_mobile.count',
#  'petition__activity__recruit.facebook_messenger_mobile.last_updated',
#  'petition__activity__recruit.facebook_messenger_web.count',
#  'petition__activity__recruit.facebook_messenger_web.last_updated',
#  'petition__activity__recruit.sms.count',
#  'petition__activity__recruit.sms.last_updated',
#  'petition__activity__recruit.twitter.count',
#  'petition__activity__recruit.twitter.last_updated',
#  'petition__activity__recruit.whatsapp.count',
#  'petition__activity__recruit.whatsapp.last_updated',
#  'petition__activity__share.copylink.count',
#  'petition__activity__share.copylink.last_updated',
#  'petition__activity__share.email.count',
#  'petition__activity__share.email.last_updated',
#  'petition__activity__share.facebook.count',
#  'petition__activity__share.facebook.last_updated',
#  'petition__activity__share.facebook_messenger.count',
#  'petition__activity__share.facebook_messenger.last_updated',
#  'petition__activity__share.line.count',
#  'petition__activity__share.line.last_updated',
#  'petition__activity__share.sms.count',
#  'petition__activity__share.sms.last_updated',
#  'petition__activity__share.twitter.count',
#  'petition__activity__share.twitter.last_updated',
#  'petition__activity__share.whatsapp.count',
#  'petition__activity__share.whatsapp.last_updated',
#  'petition__photo__id',
#  'petition__photo__url',
#  'petition__photo__sizes__square__url',
#  'petition__photo__sizes__square__processing',
#  'petition__photo__sizes__square__size__width',
#  'petition__photo__sizes__square__size__height',
#  'petition__photo__sizes__small__url',
#  'petition__photo__sizes__small__processing',
#  'petition__photo__sizes__small__size__width',
#  'petition__photo__sizes__small__size__height',
#  'petition__photo__sizes__medium__url',
#  'petition__photo__sizes__medium__processing',
#  'petition__photo__sizes__medium__size__width',
#  'petition__photo__sizes__medium__size__height',
#  'petition__photo__sizes__large__url',
#  'petition__photo__sizes__large__processing',
#  'petition__photo__sizes__large__size__width',
#  'petition__photo__sizes__large__size__height',
#  'petition__photo__type',
#  'petition__user__id',
#  'petition__user__slug',
#  'petition__user__first_name',
#  'petition__user__last_name',
#  'petition__user__short_display_name',
#  'petition__user__display_name',
#  'petition__user__city',
#  'petition__user__state_code',
#  'petition__user__country_code',
#  'petition__user__website',
#  'petition__user__locale',
#  'petition__user__description',
#  'petition__user__photo__id',
#  'petition__user__photo__url',
#  'petition__user__photo__sizes__small__url',
#  'petition__user__photo__sizes__small__processing',
#  'petition__user__photo__sizes__small__size__width',
#  'petition__user__photo__sizes__small__size__height',
#  'petition__user__photo__sizes__medium__url',
#  'petition__user__photo__sizes__medium__processing',
#  'petition__user__photo__sizes__medium__size__width',
#  'petition__user__photo__sizes__medium__size__height',
#  'petition__user__photo__sizes__large__url',
#  'petition__user__photo__sizes__large__processing',
#  'petition__user__photo__sizes__large__size__width',
#  'petition__user__photo__sizes__large__size__height',
#  'petition__user__photo__sizes__xlarge__url',
#  'petition__user__photo__sizes__xlarge__processing',
#  'petition__user__photo__sizes__xlarge__size__width',
#  'petition__user__photo__sizes__xlarge__size__height',
#  'petition__user__roles',
#  'petition__targets',
#  'petition__hide_comments',
#  'petition__hide_dm_action_panel',
#  'petition__enable_human_verification',
#  'petition__creator_name',
#  'petition__creator_photo__id',
#  'petition__creator_photo__url',
#  'petition__creator_photo__sizes__small__url',
#  'petition__creator_photo__sizes__small__processing',
#  'petition__creator_photo__sizes__small__size__width',
#  'petition__creator_photo__sizes__small__size__height',
#  'petition__creator_photo__sizes__medium__url',
#  'petition__creator_photo__sizes__medium__processing',
#  'petition__creator_photo__sizes__medium__size__width',
#  'petition__creator_photo__sizes__medium__size__height',
#  'petition__creator_photo__sizes__large__url',
#  'petition__creator_photo__sizes__large__processing',
#  'petition__creator_photo__sizes__large__size__width',
#  'petition__creator_photo__sizes__large__size__height',
#  'petition__creator_photo__sizes__xlarge__url',
#  'petition__creator_photo__sizes__xlarge__processing',
#  'petition__creator_photo__sizes__xlarge__size__width',
#  'petition__creator_photo__sizes__xlarge__size__height',
#  'petition__display_title',
#  'petition__petition_title',
#  'petition__petition_status',
#  'petition__calculated_goal',
#  'petition__media__id',
#  'petition__media__url',
#  'petition__media__sizes__square__url',
#  'petition__media__sizes__square__processing',
#  'petition__media__sizes__square__size__width',
#  'petition__media__sizes__square__size__height',
#  'petition__media__sizes__small__url',
#  'petition__media__sizes__small__processing',
#  'petition__media__sizes__small__size__width',
#  'petition__media__sizes__small__size__height',
#  'petition__media__sizes__medium__url',
#  'petition__media__sizes__medium__processing',
#  'petition__media__sizes__medium__size__width',
#  'petition__media__sizes__medium__size__height',
#  'petition__media__sizes__large__url',
#  'petition__media__sizes__large__processing',
#  'petition__media__sizes__large__size__width',
#  'petition__media__sizes__large__size__height',
#  'petition__media__type',
#  'petition__primary_target__id',
#  'petition__primary_target__display_name',
#  'petition__primary_target__email',
#  'petition__primary_target__type',
#  'petition__primary_target__slug',
#  'petition__primary_target__description',
#  'petition__primary_target__photo_id',
#  'petition__primary_target__publicly_visible',
#  'petition__primary_target__verified_at',
#  'petition__primary_target__summary',
#  'petition__primary_target__locale',
#  'petition__primary_target__confirmed_at',
#  'petition__primary_target__is_person',
#  'petition__primary_target__additional_data__first_name',
#  'petition__primary_target__additional_data__last_name',
#  'petition__primary_target__additional_data__title',
#  'petition__primary_target__has_email',
#  'petition__progress',
#  'petition__activity__recruit.custom_url.count',
#  'petition__activity__recruit.custom_url.last_updated',
#  'petition__activity__share.custom_url.count',
#  'petition__activity__share.custom_url.last_updated',
#  'petition__primary_target__photo__id',
#  'petition__primary_target__photo__url',
#  'petition__primary_target__photo__sizes__small__url',
#  'petition__primary_target__photo__sizes__small__processing',
#  'petition__primary_target__photo__sizes__small__size__width',
#  'petition__primary_target__photo__sizes__small__size__height',
#  'petition__primary_target__photo__sizes__medium__url',
#  'petition__primary_target__photo__sizes__medium__processing',
#  'petition__primary_target__photo__sizes__medium__size__width',
#  'petition__primary_target__photo__sizes__medium__size__height',
#  'petition__primary_target__photo__sizes__large__url',
#  'petition__primary_target__photo__sizes__large__processing',
#  'petition__primary_target__photo__sizes__large__size__width',
#  'petition__primary_target__photo__sizes__large__size__height',
#  'petition__primary_target__photo__sizes__xlarge__url',
#  'petition__primary_target__photo__sizes__xlarge__processing',
#  'petition__primary_target__photo__sizes__xlarge__size__width',
#  'petition__primary_target__photo__sizes__xlarge__size__height',
#  '_source__user_zipcode',
#  'highlight__targeting_description',
#  '_source__relevant_location__location__lon',
#  '_source__relevant_location__location__lat',
#  'petition__activity__share.vk.count',
#  'petition__activity__share.vk.last_updated',
#  'highlight__first_name',
#  'petition__organization__id',
#  'petition__organization__slug',
#  'petition__organization__name',
#  'petition__organization__website',
#  'petition__organization__country_code',
#  'petition__organization__mission',
#  'petition__organization__address',
#  'petition__organization__address_line_2',
#  'petition__organization__city',
#  'petition__organization__state',
#  'petition__organization__state_code',
#  'petition__organization__zipcode',
#  'petition__organization__postal_code',
#  'petition__organization__formatted_location_string',
#  'petition__organization__fb_page',
#  'petition__organization__twitter_page',
#  'petition__organization__phone_number',
#  'petition__organization__admin_contact_name',
#  'petition__organization__admin_contact_email',
#  'petition__organization__tax_name',
#  'petition__organization__tax_id_number',
#  'petition__organization__tax_address',
#  'petition__organization__tax_city',
#  'petition__organization__tax_state_code',
#  'petition__organization__tax_country_code',
#  'petition__organization__non_profit',
#  'petition__organization__verified_by',
#  'petition__organization__verified_at',
#  'petition__organization__verification_requested_at',
#  'petition__organization__video',
#  'petition__organization__photo__id',
#  'petition__organization__photo__url',
#  'petition__organization__photo__sizes__small__url',
#  'petition__organization__photo__sizes__small__processing',
#  'petition__organization__photo__sizes__small__size__width',
#  'petition__organization__photo__sizes__small__size__height',
#  'petition__organization__photo__sizes__medium__url',
#  'petition__organization__photo__sizes__medium__processing',
#  'petition__organization__photo__sizes__medium__size__width',
#  'petition__organization__photo__sizes__medium__size__height',
#  'petition__organization__photo__sizes__large__url',
#  'petition__organization__photo__sizes__large__processing',
#  'petition__organization__photo__sizes__large__size__width',
#  'petition__organization__photo__sizes__large__size__height',
#  'petition__activity__recruit..count',
#  'petition__activity__share.gmail.last_updated',
#  'petition__activity__share.gmail.count',
#  'petition__activity__recruit..last_updated',
#  'highlight__last_name',
#  'petition__primary_target__additional_data__state_code',
#  'petition__primary_target__additional_data__type',
#  'petition__activity__recruit.abi_gmail.count',
#  'petition__activity__recruit.abi_gmail.last_updated',
#  'petition__primary_target__additional_data__state',
#  'petition__primary_target__additional_data__district',
#  'petition__primary_target__additional_data__active',
#  'petition__photo_id',
#  'petition__video__embed_tag',
#  'petition__video__photo__id',
#  'petition__video__photo__url',
#  'petition__video__photo__sizes__square__url',
#  'petition__video__photo__sizes__square__processing',
#  'petition__video__photo__sizes__square__size__width',
#  'petition__video__photo__sizes__square__size__height',
#  'petition__video__photo__sizes__small__url',
#  'petition__video__photo__sizes__small__processing',
#  'petition__video__photo__sizes__small__size__width',
#  'petition__video__photo__sizes__small__size__height',
#  'petition__video__photo__sizes__medium__url',
#  'petition__video__photo__sizes__medium__processing',
#  'petition__video__photo__sizes__medium__size__width',
#  'petition__video__photo__sizes__medium__size__height',
#  'petition__video__photo__sizes__large__url',
#  'petition__video__photo__sizes__large__processing',
#  'petition__video__photo__sizes__large__size__width',
#  'petition__video__photo__sizes__large__size__height',
#  'petition__video__type',
#  'petition__video__id',
#  'petition__media__embed_tag',
#  'petition__media__photo__id',
#  'petition__media__photo__url',
#  'petition__media__photo__sizes__square__url',
#  'petition__media__photo__sizes__square__processing',
#  'petition__media__photo__sizes__square__size__width',
#  'petition__media__photo__sizes__square__size__height',
#  'petition__media__photo__sizes__small__url',
#  'petition__media__photo__sizes__small__processing',
#  'petition__media__photo__sizes__small__size__width',
#  'petition__media__photo__sizes__small__size__height',
#  'petition__media__photo__sizes__medium__url',
#  'petition__media__photo__sizes__medium__processing',
#  'petition__media__photo__sizes__medium__size__width',
#  'petition__media__photo__sizes__medium__size__height',
#  'petition__media__photo__sizes__large__url',
#  'petition__media__photo__sizes__large__processing',
#  'petition__media__photo__sizes__large__size__width',
#  'petition__media__photo__sizes__large__size__height',
#  'petition__organization__photo_id',
#  'petition__photo',
#  'petition__restricted_location__city',
#  'petition__restricted_location__country_code',
#  'petition__restricted_location__lat',
#  'petition__restricted_location__lng',
#  'petition__restricted_location__state_code',
#  'petition__restricted_location__google_places_id',
#  'petition__restricted_location__photo_id',
#  'petition__missingPetition']

# %%
df['petition__created_at'] = pd.to_datetime(df.petition__created_at)

# %%
str(df['petition__created_at'].iloc[-1])
# Out:
# 'NaT'

# %%
plt.title("Cumulative number of petitions")
plt.xlabel("Date")
plt.ylabel("Total number of petitions")
created_at = sorted(filter(lambda x: str(x) != 'NaT', df.petition__created_at))
plt.plot(created_at, list(range(len(created_at))))
plt.xticks(rotation=85)
plt.savefig('figures/petitions_created.png', bbox_inches='tight', transparent=False)
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.title("Comments by state (US)")
states, freqs = zip(*Counter(df.petition__user__state_code).most_common())
plt.pie(freqs, labels=states)

plt.subplot(1, 2, 2)
plt.title("Comments by country")
states, freqs = zip(*Counter(df.petition__user__country_code).most_common())
plt.pie(freqs, labels=states)

plt.savefig('./figures/petitions-state-country-pie.png', transparent=False,
            bbox_inches='tight')

plt.show()
