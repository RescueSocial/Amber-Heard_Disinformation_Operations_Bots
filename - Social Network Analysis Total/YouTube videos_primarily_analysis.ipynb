# %%
import pandas as pd
import os
pd.set_option('display.max_columns', 500)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import matplotlib.dates as mdates
import plotly.express as px
import plotly.graph_objects as go
import re
import warnings
import datetime
warnings.filterwarnings('ignore')
sb.set_style("darkgrid")
# %matplotlib inline

import helpers

# To Apply helpers updates without resarting the kernel
import importlib
importlib.reload(helpers)

# # To keep track of any module updates
# %load_ext autoreload
# %autoreload2

# %config InlineBackend.figure_format = 'retina'

# %%
df_videos = pd.read_csv("../clean_data/video_data_cleaned.csv")
df_videos.p_dtime = pd.to_datetime(df_videos.p_dtime)

# %%
print(df_videos.shape)
df_videos.head()
# Out:
# (6893, 16)
#             id                         etag                   p_dtime  \
# 0  14SUI93R_k8  zUX2H4amXbJxvecYfsO-9mMha7c 2021-03-19 17:00:30+00:00
# 1  9rC1gEB5wSk  W_OcjSa0xjX5E8u4uZKGTkOVnek 2020-12-30 16:25:16+00:00
# 2  nkofr7qZSw0  rz1_nfM8S8B8philEP9Y1CIt2fE 2019-04-28 16:13:50+00:00
# 3  82niI4hiImY  JH06ceCKw9jT7K-EdPycpZ7_LaE 2021-12-05 13:19:52+00:00
# 4  kNA2wjVsp9c  NoIaeQvZ9WgkrjicJcz5wPlHiT4 2021-06-15 18:37:07+00:00
#
#                       ch_id  \
# 0  UC-NINtNMPM75eaqh07RCy_Q
# 1  UCNoGr_InOOlv0XhHO9KC3Hg
# 2  UC4L8zPgbx3ZATeWZ-iEIKiA
# 3  UCeooMl4PFAM9kLPHvavt2KQ
# 4  UCycYfOSLuPwdKJx4fLrlJgA
#
#                                                title  \
# 0  jason momoa defends amber heard after aquaman ...
# 1  solving a rubik's cube everyday until amber he...
# 2  amber heard ,jacob latimore ,charlie plummer k...
# 3              amber heard trolls on twitter again!?
# 4                amber heard workout for aquaman-2 🔥
#
#                                          description          ch_title  \
# 0  jason momoa defends amber heard after aquaman ...    InformOverload
# 1                                 fire amber heard 😡  Fire Amber Heard
# 2  amber heard , jacob latimore , charlie plummer...      Zach Simmons
# 3  amber heard trolls on twitter again!?\n\ncheck...           eHacker
# 4                                                NaN      Random Watch
#
#                                         snippet.tags        category  \
# 0  ['io', 'informoverload', 'inform overload', 'a...       Education
# 1                                                NaN  People & Blogs
# 2  ['Amber Heard', 'Jacob Lattimore', 'connection...   Entertainment
# 3  ['Amber Heard', 'Amber heard twitter', 'Amber ...   Entertainment
# 4                                                NaN  People & Blogs
#
#           duration  is_licensed  n_views  n_likes  n_dislikes  n_comments  \
# 0  0 days 00:04:45         True    32001   1394.0        71.0       942.0
# 1  0 days 00:00:21        False        4      2.0         0.0         0.0
# 2  0 days 00:15:33        False     1768     21.0        21.0         8.0
# 3  0 days 00:05:45         True     2604    376.0         1.0       148.0
# 4  0 days 00:00:31        False      327      9.0         8.0         0.0
#
#    year
# 0  2021
# 1  2020
# 2  2019
# 3  2021
# 4  2021

# %%
df_videos.id.nunique()
# Out:
# 6893

# %%
df_videos.etag.nunique()
# Out:
# 6893

# %%
df_videos.p_dtime.min(), df_videos.p_dtime.max()
# Out:
# (Timestamp('2008-01-07 17:02:08+0000', tz='UTC'),
#  Timestamp('2021-12-06 22:58:02+0000', tz='UTC'))

# %%
years = (
    df_videos.groupby("year")
    .count()["id"]
    .to_frame()
    .reset_index()
    .rename(columns={"id": "n_videos"})
)

# %%
years
# Out:
#     year  n_videos
# 0   2008         3
# 1   2009        15
# 2   2010        14
# 3   2011        47
# 4   2012        20
# 5   2013        78
# 6   2014        59
# 7   2015        89
# 8   2016       329
# 9   2017       213
# 10  2018       407
# 11  2019       318
# 12  2020      1869
# 13  2021      3432

# %%
helpers.bar(years, "year", "n_videos", "Number of Videos over Years", text=0, margin=500)

# %%
helpers.pie(years, "Number of Videos over Years")

# %%
categories = df_videos["category"].value_counts().to_frame().reset_index().rename(
    columns={"index": "category",
            "category": "n_videos"}
)

# %%
categories
# Out:
#                  category  n_videos
# 0           Entertainment      3785
# 1          People & Blogs      1477
# 2        Film & Animation       593
# 3         News & Politics       431
# 4               Education       187
# 5                   Music       100
# 6           Howto & Style        76
# 7                  Gaming        67
# 8                  Comedy        67
# 9                  Sports        29
# 10   Science & Technology        29
# 11  Nonprofits & Activism        24
# 12       Autos & Vehicles        16
# 13        Travel & Events         9
# 14         Pets & Animals         3

# %%
helpers.bar(categories, "category", "n_videos", "Videos Categries", text=0, margin=500)

# %%
helpers.pie(categories, "Videos Categries")

# %%
fig = px.box(df_videos, y="n_likes")
fig.show("svg")

# %%
df_videos["n_likes"].describe()
# Out:
# count    6.697000e+03
# mean     4.811032e+03
# std      5.656654e+04
# min      0.000000e+00
# 25%      7.000000e+00
# 50%      8.600000e+01
# 75%      6.690000e+02
# max      2.616631e+06
# Name: n_likes, dtype: float64

# %%
fig = px.box(df_videos, y="n_views")
fig.show("svg")

# %%
df_videos["n_views"].describe()
# Out:
# count    6.893000e+03
# mean     3.691218e+05
# std      4.803435e+06
# min      0.000000e+00
# 25%      2.800000e+02
# 50%      2.603000e+03
# 75%      2.360300e+04
# max      1.787249e+08
# Name: n_views, dtype: float64

# %%
fig = px.box(df_videos, y="n_dislikes")
fig.show("svg")

# %%
df_videos["n_dislikes"].describe()
# Out:
# count      6697.000000
# mean        345.131999
# std        6532.767791
# min           0.000000
# 25%           1.000000
# 50%           6.000000
# 75%          34.000000
# max      479614.000000
# Name: n_dislikes, dtype: float64

# %%
fig = px.box(df_videos, y="n_comments")
fig.show("svg")

# %%
df_videos["n_comments"].describe()
# Out:
# count      6707.000000
# mean        399.017295
# std        2982.544042
# min           0.000000
# 25%           1.000000
# 50%          21.000000
# 75%         195.000000
# max      131021.000000
# Name: n_comments, dtype: float64

# %%
# datetime.datetime.strptime(df_videos.duration[0], "%H:%M:%S")

# %%
df_videos["duration"] = pd.to_timedelta(df_videos.duration)

# %%
df_videos["duration_seconds"] = df_videos["duration"].apply(lambda x: x.total_seconds())

# %%
fig = px.box(df_videos, y="duration_seconds")
fig.show("svg")

# %%
df_videos["duration_seconds"].describe()
# Out:
# count     6893.000000
# mean       697.487306
# std       1488.500020
# min          2.000000
# 25%        127.000000
# 50%        350.000000
# 75%        587.000000
# max      34150.000000
# Name: duration_seconds, dtype: float64

# %%
fig = px.box(df_videos, y="duration")
fig.show("svg")

# %%
df_videos["duration"].describe()
# Out:
# count                         6893
# mean     0 days 00:11:37.487305962
# std      0 days 00:24:48.500020038
# min                0 days 00:00:02
# 25%                0 days 00:02:07
# 50%                0 days 00:05:50
# 75%                0 days 00:09:47
# max                0 days 09:29:10
# Name: duration, dtype: object

# %%
sum(df_videos["title"].duplicated())
# Out:
# 188

# %% [markdown]
# #### 188 repeated titles

# %%
df_videos["title"].value_counts().head(133)
# Out:
# gully official trailer (2021) amber heard                                         10
# amber heard                                                                        7
# amber heard : après johnny depp et elon musk, sean penn serait sous son charme     6
# gully official trailer (2021)                                                      5
# aquaman 2 (2022) teaser trailer - jason momoa, amber heard (fan made)              5
#                                                                                   ..
# amber heard gives johnny depp's $7m divorce settlement to two charities            2
# solving a rubik's cube everyday until amber heard gets fired - day 33              2
# amber heard accuses johnny depp of repeatedly threatening to kill her              2
# amber heard hot in aquaman                                                         2
# amber heard donates divorce settlement to charity                                  2
# Name: title, Length: 133, dtype: int64
