# %%
import pandas as pd
import requests
from time import sleep
pd.set_option('display.max_columns', None)
from get_petitions import search_petitions

# %%
pd.DataFrame(search_petitions('Amber Heard'))
# Out:
#          _index      _type                    _id    _score  \
# 0  petitions-fr  petitions  13641580::Amber Heard  1.687169
# 1  petitions-fr  petitions  20195775::Amber Heard  0.946862
#
#    _source__total_signature_count _source__created_locale _source__first_name  \
# 0                              72                   ru-RU                 Ksu
# 1                              20                   fr-FR                   N
#
#    _source__weekly_signature_count _source__recent_activity_date  \
# 0                               49          2018-10-05T12:57:38Z
# 1                                0          2020-02-05T16:56:44Z
#
#    _source__is_pledge _source__targeting_description   _source__created_at  \
# 0               False                                 2018-10-05T12:57:38Z
# 1               False                      Pinocchio  2020-02-05T16:56:44Z
#
#   _source__user_id  _source__victory _source__victory_date _source__status  \
# 0        903678381             False                  None               1
# 1       1041245979             False                  None               1
#
#   _source__user_city _source__user_photo_id  \
# 0             Moscow                      0
# 1                NaN                      0
#
#                                 _source__tag_objects  _source__coachable  \
# 0                                               None               False
# 1  [{'id': 476575, 'name': 'Autre', 'locale': 'fr...               False
#
#    _source__sponsored_campaign _source__tag_names _source__country_code  \
# 0                        False               None                    RU
# 1                        False            [Autre]                    FR
#
#    _source__sponsorship_active  _source__discoverable  \
# 0                         True                   True
# 1                         True                   True
#
#   _source__relevant_location _source__movement_ids _source__petition_id  \
# 0                       None                  None             13641580
# 1                       None                  None             20195775
#
#   _source__last_name                                   _source__slug  \
# 0               Vamp                     johnny-depp-we-are-with-you
# 1                  A  pinocchio-regarder-pinocchio-streaming-vf-2020
#
#   _source__petition_photo_id                            _source__ask  \
# 0                  221150164            Johnny Depp We are with you!
# 1                  223075105  Regarder Pinocchio Streaming VF [2020]
#
#                               highlight__description  petition__id  \
# 0  [ triumph! Stop lying to <mark>Amber</mark> <m...      13641580
# 1  [,Aventure,Science-FictionStars: Jason Momoa, ...      20195775
#
#   petition__document_id                                    petition__ask  \
# 0              13641580  Johnny Depp is innocent - Amber heard abuser!!!
# 1              20195775           Regarder Pinocchio Streaming VF [2020]
#
#    petition__created_at petition__deleted_at petition__published_at  \
# 0  2018-10-05T12:57:38Z                 None   2018-10-05T13:13:42Z
# 1  2020-02-05T16:56:44Z                 None   2020-02-05T17:02:12Z
#
#   petition__last_edited_at petition__original_locale petition__languages  \
# 0                     None                     ru-RU            [en, ru]
# 1                     None                     fr-FR                [fr]
#
#                                      petition__title  \
# 0                              #JohnnyDeppisinnocent
# 1  Pinocchio : Regarder Pinocchio Streaming VF [2...
#
#                                petition__description  \
# 0  <p><strong>We want to help Johnny Depp win a t...
# 1  <p>Pinocchio Streaming vf , Regarder Pinocchio...
#
#   petition__targeting_description                   petition__letter_body  \
# 0                     Johnny Depp            Johnny Depp We are with you!
# 1                       Pinocchio  Regarder Pinocchio Streaming VF [2020]
#
#   petition__end_date petition__goal petition__relevant_location__city  \
# 0         2020-11-18           None                      Лос-Анджелес
# 1         2021-02-05           None                              None
#
#   petition__relevant_location__country_code  petition__relevant_location__lat  \
# 0                                        US                           34.0522
# 1                                        FR                               NaN
#
#    petition__relevant_location__lng petition__relevant_location__state_code  \
# 0                          -118.244                                      CA
# 1                               NaN                                    None
#
#   petition__relevant_location__google_places_id  \
# 0                   ChIJE9on3F3HwoAR9AhGJW_fL-I
# 1                                          None
#
#   petition__relevant_location__photo_id petition__restricted_location  \
# 0                                  None                          None
# 1                                  None                          None
#
#                                    petition__slug petition__status  \
# 0                            johnnydeppisinnocent        published
# 1  pinocchio-regarder-pinocchio-streaming-vf-2020        published
#
#   petition__victory_date petition__victory_description  \
# 0                   None                          None
# 1                   None                          None
#
#    petition__is_verified_victory  petition__is_victory petition__video  \
# 0                          False                 False            None
# 1                          False                 False            None
#
#    petition__is_pledge petition__topic  \
# 0                False            None
# 1                False            None
#
#                                       petition__tags  petition__discoverable  \
# 0                                                 []                    True
# 1  [{'id': 476575, 'locale': 'fr-FR', 'name': 'Au...                    True
#
#    petition__sponsored_campaign petition__organization_free_email_optins  \
# 0                         False                                     None
# 1                         False                                     None
#
#    petition__displayed_signature_count  petition__total_signature_count  \
# 0                                11492                            11492
# 1                                   20                               20
#
#    petition__weekly_signature_count  petition__total_page_views  \
# 0                                10                       79090
# 1                                 0                        3740
#
#    petition__total_share_count  petition__daily_signature_count  \
# 0                        12848                                2
# 1                           19                                0
#
#    petition__monthly_signature_count  petition__daily_signup_count  \
# 0                                 36                             0
# 1                                  0                             0
#
#    petition__weekly_signup_count  petition__monthly_signup_count  \
# 0                              1                               8
# 1                              0                               0
#
#    petition__total_signup_count petition__supporter_message_count  \
# 0                          4214                              None
# 1                             6                              None
#
#   petition__starter_vanity_url  petition__activity__recruit.email.count  \
# 0                         None                                      3.0
# 1                         None                                      NaN
#
#    petition__activity__recruit.email.last_updated  \
# 0                                    1.632845e+09
# 1                                             NaN
#
#    petition__activity__recruit.sms.count  \
# 0                                    1.0
# 1                                    NaN
#
#    petition__activity__recruit.sms.last_updated  \
# 0                                  1.626810e+09
# 1                                           NaN
#
#    petition__activity__share.copylink.count  \
# 0                                      55.0
# 1                                       NaN
#
#    petition__activity__share.copylink.last_updated  \
# 0                                     1.633288e+09
# 1                                              NaN
#
#    petition__activity__share.email.count  \
# 0                                    9.0
# 1                                    NaN
#
#    petition__activity__share.email.last_updated  \
# 0                                  1.633269e+09
# 1                                           NaN
#
#    petition__activity__share.facebook.count  \
# 0                                      13.0
# 1                                       NaN
#
#    petition__activity__share.facebook.last_updated  \
# 0                                     1.632646e+09
# 1                                              NaN
#
#    petition__activity__share.facebook_messenger.count  \
# 0                                                2.0
# 1                                                NaN
#
#    petition__activity__share.facebook_messenger.last_updated  \
# 0                                       1.628764e+09
# 1                                                NaN
#
#    petition__activity__share.sms.count  \
# 0                                  7.0
# 1                                  NaN
#
#    petition__activity__share.sms.last_updated  \
# 0                                1.627477e+09
# 1                                         NaN
#
#    petition__activity__share.twitter.count  \
# 0                                      7.0
# 1                                      NaN
#
#    petition__activity__share.twitter.last_updated  \
# 0                                    1.628394e+09
# 1                                             NaN
#
#    petition__activity__share.vk.count  \
# 0                                 1.0
# 1                                 NaN
#
#    petition__activity__share.vk.last_updated  \
# 0                               1.627633e+09
# 1                                        NaN
#
#    petition__activity__share.whatsapp.count  \
# 0                                      23.0
# 1                                       NaN
#
#    petition__activity__share.whatsapp.last_updated  petition__photo__id  \
# 0                                     1.633009e+09            221150164
# 1                                              NaN            223075105
#
#                           petition__photo__url  \
# 0  photos/6/mw/dy/mWmWdyTGlXlcuvD-fullsize.jpg
# 1  photos/7/uh/sq/rgUHSQCWUVrweGE-fullsize.jpg
#
#                  petition__photo__sizes__square__url  \
# 0  //assets.change.org/photos/6/mw/dy/mWmWdyTGlXl...
# 1  //assets.change.org/photos/7/uh/sq/rgUHSQCWUVr...
#
#    petition__photo__sizes__square__processing  \
# 0                                       False
# 1                                       False
#
#    petition__photo__sizes__square__size__width  \
# 0                                          400
# 1                                          400
#
#    petition__photo__sizes__square__size__height  \
# 0                                           400
# 1                                           400
#
#                   petition__photo__sizes__small__url  \
# 0  //assets.change.org/photos/6/mw/dy/mWmWdyTGlXl...
# 1  //assets.change.org/photos/7/uh/sq/rgUHSQCWUVr...
#
#    petition__photo__sizes__small__processing  \
# 0                                      False
# 1                                      False
#
#    petition__photo__sizes__small__size__width  \
# 0                                         400
# 1                                         400
#
#    petition__photo__sizes__small__size__height  \
# 0                                          225
# 1                                          225
#
#                  petition__photo__sizes__medium__url  \
# 0  //assets.change.org/photos/6/mw/dy/mWmWdyTGlXl...
# 1  //assets.change.org/photos/7/uh/sq/rgUHSQCWUVr...
#
#    petition__photo__sizes__medium__processing  \
# 0                                       False
# 1                                       False
#
#    petition__photo__sizes__medium__size__width  \
# 0                                          800
# 1                                          800
#
#    petition__photo__sizes__medium__size__height  \
# 0                                           450
# 1                                           450
#
#                   petition__photo__sizes__large__url  \
# 0  //assets.change.org/photos/6/mw/dy/mWmWdyTGlXl...
# 1  //assets.change.org/photos/7/uh/sq/rgUHSQCWUVr...
#
#    petition__photo__sizes__large__processing  \
# 0                                      False
# 1                                      False
#
#    petition__photo__sizes__large__size__width  \
# 0                                        1600
# 1                                        1600
#
#    petition__photo__sizes__large__size__height petition__photo__type  \
# 0                                          900                 photo
# 1                                          900                 photo
#
#    petition__user__id petition__user__slug petition__user__first_name  \
# 0           903678381            903678381                        Ksu
# 1          1041245979           1041245979                          N
#
#   petition__user__last_name petition__user__short_display_name  \
# 0                      Vamp                                Ksu
# 1                         A                                  N
#
#   petition__user__display_name petition__user__city  \
# 0                     Ksu Vamp               Moscow
# 1                          N A
#
#   petition__user__state_code petition__user__country_code  \
# 0                                                      RU
# 1                                                      FR
#
#   petition__user__website petition__user__locale petition__user__description  \
# 0                                          ru-RU
# 1                    None                  fr-FR                        None
#
#   petition__user__roles                                  petition__targets  \
# 0                    []  [{'id': 591569, 'display_name': 'Johnny Depp',...
# 1                    []  [{'id': 3393100, 'display_name': 'Pinocchio', ...
#
#    petition__hide_comments  petition__hide_dm_action_panel  \
# 0                    False                           False
# 1                    False                           False
#
#    petition__enable_human_verification petition__creator_name  \
# 0                                False               Ksu Vamp
# 1                                False                    N A
#
#                              petition__display_title  \
# 0                              #JohnnyDeppisinnocent
# 1  Pinocchio : Regarder Pinocchio Streaming VF [2...
#
#                             petition__petition_title  \
# 0                              #JohnnyDeppisinnocent
# 1  Pinocchio : Regarder Pinocchio Streaming VF [2...
#
#   petition__petition_status  petition__calculated_goal  petition__media__id  \
# 0                    active                      15000            221150164
# 1                    active                        100            223075105
#
#                           petition__media__url  \
# 0  photos/6/mw/dy/mWmWdyTGlXlcuvD-fullsize.jpg
# 1  photos/7/uh/sq/rgUHSQCWUVrweGE-fullsize.jpg
#
#                  petition__media__sizes__square__url  \
# 0  //assets.change.org/photos/6/mw/dy/mWmWdyTGlXl...
# 1  //assets.change.org/photos/7/uh/sq/rgUHSQCWUVr...
#
#    petition__media__sizes__square__processing  \
# 0                                       False
# 1                                       False
#
#    petition__media__sizes__square__size__width  \
# 0                                          400
# 1                                          400
#
#    petition__media__sizes__square__size__height  \
# 0                                           400
# 1                                           400
#
#                   petition__media__sizes__small__url  \
# 0  //assets.change.org/photos/6/mw/dy/mWmWdyTGlXl...
# 1  //assets.change.org/photos/7/uh/sq/rgUHSQCWUVr...
#
#    petition__media__sizes__small__processing  \
# 0                                      False
# 1                                      False
#
#    petition__media__sizes__small__size__width  \
# 0                                         400
# 1                                         400
#
#    petition__media__sizes__small__size__height  \
# 0                                          225
# 1                                          225
#
#                  petition__media__sizes__medium__url  \
# 0  //assets.change.org/photos/6/mw/dy/mWmWdyTGlXl...
# 1  //assets.change.org/photos/7/uh/sq/rgUHSQCWUVr...
#
#    petition__media__sizes__medium__processing  \
# 0                                       False
# 1                                       False
#
#    petition__media__sizes__medium__size__width  \
# 0                                          800
# 1                                          800
#
#    petition__media__sizes__medium__size__height  \
# 0                                           450
# 1                                           450
#
#                   petition__media__sizes__large__url  \
# 0  //assets.change.org/photos/6/mw/dy/mWmWdyTGlXl...
# 1  //assets.change.org/photos/7/uh/sq/rgUHSQCWUVr...
#
#    petition__media__sizes__large__processing  \
# 0                                      False
# 1                                      False
#
#    petition__media__sizes__large__size__width  \
# 0                                        1600
# 1                                        1600
#
#    petition__media__sizes__large__size__height petition__media__type  \
# 0                                          900                 photo
# 1                                          900                 photo
#
#    petition__primary_target__id petition__primary_target__display_name  \
# 0                        591569                            Johnny Depp
# 1                       3393100                              Pinocchio
#
#   petition__primary_target__email petition__primary_target__type  \
# 0                            None                         Custom
# 1                            None                         Custom
#
#   petition__primary_target__slug petition__primary_target__description  \
# 0                    johnny-depp                                  None
# 1                      pinocchio                                  None
#
#   petition__primary_target__photo_id  \
# 0                               None
# 1                               None
#
#    petition__primary_target__publicly_visible  \
# 0                                       False
# 1                                       False
#
#   petition__primary_target__verified_at petition__primary_target__summary  \
# 0                                  None                              None
# 1                                  None                              None
#
#   petition__primary_target__locale petition__primary_target__confirmed_at  \
# 0                            en-AU                                   None
# 1                             None                                   None
#
#    petition__primary_target__is_person  \
# 0                                 True
# 1                                 True
#
#   petition__primary_target__additional_data__first_name  \
# 0                                             Johnny
# 1                                          Pinocchio
#
#   petition__primary_target__additional_data__last_name  \
# 0                                               Depp
# 1                                               None
#
#   petition__primary_target__additional_data__title  \
# 0                                             None
# 1                                             None
#
#    petition__primary_target__has_email  petition__progress
# 0                                False           76.613333
# 1                                False           20.000000
