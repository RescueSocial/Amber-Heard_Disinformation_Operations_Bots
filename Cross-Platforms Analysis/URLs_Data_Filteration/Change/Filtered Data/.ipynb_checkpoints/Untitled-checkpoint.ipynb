# %%
import pandas as pd
pd.set_option("display.max_columns", 500)

# %%
df_all_petitions_comments_4 = pd.read_csv("df_all_petitions_comments_4.csv")

# %%
df_all_petitions_comments_4.head(2)
# Out:
#           id                                            comment  parent_id  \
# 0  811611340  I'm signing because I grew up watching this ma...          0
# 1  817824172                             WB supports abusers!!!          0
#
#    children_count commentable_type  commentable_id  likes     role  \
# 0               0            Event        25699792      0  comment
# 1               0            Event        20569720      1  comment
#
#                   created_at  deleted_at    user.id  user.slug  \
# 0  2021-01-06 08:05:17+00:00         NaN  417677182  417677182
# 1  2021-04-30 14:07:16+00:00         NaN  270408901  270408901
#
#   user.first_name user.last_name user.short_display_name user.display_name  \
# 0         Ainsley          Welch                 Ainsley     Ainsley Welch
# 1           Steve           Kass                   Steve        Steve Kass
#
#          user.city user.state_code user.country_code user.website user.locale  \
# ...

# %%
df_all_petitions_milestones_4 = pd.read_csv("df_all_petitions_milestones_4.csv")

# %%
df_all_petitions_milestones_4.head(2)
# Out:
#                 __typename        id                  createdAt  \
# 0  MilestonePetitionUpdate  28302775  2021-01-04 15:37:35+00:00
# 1  MilestonePetitionUpdate  28622990  2021-02-27 16:07:25+00:00
#
#    signatureCount                                     petition__slug title  \
# 0           100.0                 us-remove-amber-heard-from-aquaman   NaN
# 1           200.0  warner-brothers-replace-amber-heard-in-justice...   NaN
#
#   description photo video  embeddedMedia  dmResponse status_manual
# 0         NaN   NaN   NaN            NaN         NaN       against
# 1         NaN   NaN   NaN            NaN         NaN       against

# %%
df_comments_petition_slug_hollywood_boycott_aquaman_2_4 = pd.read_csv("df_comments_petition_slug_hollywood_boycott_aquaman_2_4.csv")

# %%
df_comments_petition_slug_hollywood_boycott_aquaman_2_4.head(2)
# Out:
#           id                                            comment  parent_id  \
# 0  817824172                             WB supports abusers!!!          0
# 1  817783686  Due to recent evidence it is clear she lied an...          0
#
#    children_count commentable_type  commentable_id  likes     role  \
# 0               0            Event        20569720      1  comment
# 1               0            Event        20569720      1  comment
#
#                   created_at  deleted_at    user__id  user__slug  \
# 0  2021-04-30 14:07:16+00:00         NaN   270408901   270408901
# 1  2021-04-29 19:58:11+00:00         NaN  1198838350  1198838350
#
#   user__first_name user__last_name user__short_display_name  \
# 0            Steve            Kass                    Steve
# 1           Amanda          Avelar                   Amanda
#
#   user__display_name       user__city user__state_code user__country_code  \
# 0         Steve Kass  San Francisco's               CA                 US
# ...

# %%
df_petition_slug_4 = pd.read_csv("df_petition_slug_4.csv")

# %%
df_petition_slug_4
# Out:
# Empty DataFrame
# Columns: [timestamp, node.id, node.displayName, node.photo.id, node.photo.userSmall.url, node.photo]
# Index: []

# %%
df_petitions_AH_4 = pd.read_csv("df_petitions_AH_4.csv")

# %%
def get_urls(string):
    """
    Get links from text
    """
    regex = r"(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'\".,<>?«»“”‘’]))"
    url = re.findall(regex, string)
    urls = [x[0] for x in url]
    return urls

# %%
import re

# %%
df_petitions_AH_4.petition__description.apply(lambda x: get_urls(x))
# Out:
# 0                                                    []
# 1     [https://www.thesun.co.uk/news/uknews/13084520...
# 2                                                    []
# 3                                                    []
# 4                                                    []
# 5                                                    []
# 6     [https://80b08171-ce73-4488-b369-fe3934b0504a....
# 7     [https://www.thesun.co.uk/news/13082970/johnny...
# 8     [https://www.thesun.co.uk/news/13082970/johnny...
# 9                                                    []
# 10                                                   []
# 11                                                   []
# 12                                                   []
# 13                                                   []
# 14                                                   []
# 15                                                   []
# 16                                                   []
# ...
