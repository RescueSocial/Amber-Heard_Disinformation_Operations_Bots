# %%
from helpers import (
    URLS,
    get_urls,
    urls_df,
    one_link_df,
    one_link_urls,
    one_link_urls_with_count,
    df_more_than_link, more_than_one_link_with_count
)
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Twitter Data URLs

# %%
twitter_filter_path =  "../URLS_Data/Twitter/"

# %% [markdown]
# ## Table of Contents
# <ul>
# <li><a href="#Comments"><b>Comments</b></a></li>
# <li><a href="#Posts">Posts</a></li>
# </ul>

# %%
twitter_data_path =  "../_Twitter - Data/"

# %% [markdown]
# <a id='Tweets'></a>
#
# ## Tweets
#
#
# ><ul>
#  <li><a href="#4">4 Months</a></li>
#  <li><a href="#12">December</a></li>
#
#  </ul>

# %%
df_tweets_21 = pd.read_csv(twitter_data_path + "tweets_2021.csv")

# %%
df_tweets_21.head(2)
# Out:
#                 id_str                 created_at  \
# 0  1345359931550134272  2021-01-02 13:22:57+00:00
# 1  1345359929507459075  2021-01-02 13:22:57+00:00
#
#                                            full_text lang  \
# 0  So ready ✨ for the next #DeppMovieNight\n\nFil...   en
# 1  #Johnuary #DeppMovieNight #JusticeForJohnnyDep...  und
#
#   in_reply_to_status_id_str in_reply_to_user_id  \
# 0                       NaN                 NaN
# 1                       NaN                 NaN
#
#                                    entities.hashtags entities.media  \
# 0  [{'indices': [24, 39], 'text': 'DeppMovieNight...            NaN
# 1  [{'indices': [0, 9], 'text': 'Johnuary'}, {'in...            NaN
#
#   entities.symbols entities.urls  ... user.friends_count user.lang  \
# 0               []            []  ...              544.0       NaN
# 1               []            []  ...               52.0       NaN
#
#          user.location               user.name user.screen_name  \
# ...

# %%
df_tweets_21.columns
# Out:
# Index(['id_str', 'created_at', 'full_text', 'lang',
#        'in_reply_to_status_id_str', 'in_reply_to_user_id', 'entities.hashtags',
#        'entities.media', 'entities.symbols', 'entities.urls',
#        'entities.user_mentions', 'source', 'quoted_status.id_str',
#        'quoted_status.created_at', 'quoted_status.full_text',
#        'quoted_status.lang', 'quoted_status.in_reply_to_status_id_str',
#        'quoted_status.in_reply_to_user_id', 'quoted_status.entities.hashtags',
#        'quoted_status.entities.media', 'quoted_status.entities.symbols',
#        'quoted_status.entities.urls', 'quoted_status.entities.user_mentions',
#        'quoted_status.user.id_str', 'quoted_status.source', 'user.id_str',
#        'user.created_at', 'user.description', 'user.followers_count',
#        'user.friends_count', 'user.lang', 'user.location', 'user.name',
#        'user.screen_name', 'user.profile_banner_url', 'user.profile_image_url',
# ...

# %%
df_tweets_21["created_at"] = pd.to_datetime(df_tweets_21["created_at"])

# %%
df_tweets_21.drop_duplicates(inplace=True)

# %%
df_tweets_21.shape[0]
# Out:
# 228687

# %%
df_tweets_20 = pd.read_csv(twitter_data_path + "tweets_2020_lite(1).csv")

# %%
df_tweets_20.head(1)
# Out:
#                 id_str                 created_at  \
# 0  1214659714698633223  2020-01-07 21:26:57+00:00
#
#                                            full_text  user.id_str  \
# 0  @jackshitnobody He is a great actor . And ambe...   3416958298
#
#   user.screen_name      user.name            user.created_at
# 0    Kenman_RiderW  SpecSpiderKen  2015-08-12 03:54:29+00:00

# %%
df_tweets_20["created_at"] = pd.to_datetime(df_tweets_20["created_at"])

# %%
df_tweets_20.drop_duplicates(inplace=True)

# %%
urls_tweets_20 = URLS(df_tweets_20)
urls_tweets_21 = URLS(df_tweets_21)

# %%
# 4 months data
df_tweets_4_months = urls_tweets_21.months_filteration(
    datetime_column="created_at", start="2021-01-01 00:00:00", end="2021-05-01 00:00:00"
)

# %%
# dec data
df_tweets_dec = urls_tweets_20.months_filteration(
    datetime_column="created_at", start="2020-12-01 00:00:00", end="2021-01-01 00:00:00"
)

# %%
df_tweets_4_months.created_at.min(), df_tweets_4_months.created_at.max()
# Out:
# (datetime.datetime(2021, 1, 1, 0, 0, 7, tzinfo=tzutc()),
#  datetime.datetime(2021, 4, 25, 23, 59, 6, tzinfo=tzutc()))

# %%
df_tweets_dec.created_at.min(), df_tweets_dec.created_at.max()
# Out:
# (Timestamp('2020-12-01 00:00:27+0000', tz='UTC'),
#  Timestamp('2020-12-31 23:59:51+0000', tz='UTC'))

# %% [markdown]
# ### 4 Months
# <a id='4'></a>
#
#
# ><ul>
#  <li><a href="#one4">One Link</a></li>
#  <li><a href="#more4">More Than One Link</a></li>
#
#  </ul>

# %%
df_tweets_4_months.shape[0]
# Out:
# 228686

# %%
df_tweets_4_months.drop_duplicates(inplace=True)

# %%
df_tweets_4_months["urls"] = df_tweets_4_months.full_text.astype(str).apply(lambda x: get_urls(x))

# %%
df_tweets_4_months["n_urls"] = df_tweets_4_months.urls.apply(lambda x: len(x))

# %%
df_tweets_4_months_urls = urls_df(df_tweets_4_months)

# %%
df_tweets_4_months_urls.head(10)
# Out:
#                 id_str                 created_at  \
# 0  1345358697959047168  2021-01-02 13:18:03+00:00
# 1  1345357307115307009  2021-01-02 13:12:32+00:00
# 2  1345357193709826052  2021-01-02 13:12:05+00:00
# 3  1345356222191591424  2021-01-02 13:08:13+00:00
# 4  1345354652930494465  2021-01-02 13:01:59+00:00
# 5  1345354607002869760  2021-01-02 13:01:48+00:00
# 6  1345353269237997570  2021-01-02 12:56:29+00:00
# 7  1345352861564231681  2021-01-02 12:54:52+00:00
# 8  1345352821047259136  2021-01-02 12:54:42+00:00
# 9  1345290114046558208  2021-01-02 08:45:32+00:00
#
#                                            full_text lang  \
# 0  @_missyc97_ 2021 to Amber Heard.😂 https://t.co...   en
# 1  When Amber Heard is in the mood but her mortal...   en
# 2  @kathygriffin These didn’t age well. Oh Kathy ...   en
# 3  Amores, hoje vai rolar mais uma #DeppMovieNigh...   pt
# 4  Buenos días 🌞 \n\n#JohnnyDepp \n#JusticeForJoh...   es
# 5  Here's the best way to hold a watch-along on #...   en
# ...

# %%
# save data
df_tweets_4_months_urls.to_csv(
    twitter_filter_path + "df_tweets_4_months_urls.csv", index=False
)

# %% [markdown]
# <a id='one4'></a>
# #### One Link
#
# ><ul>
#  <li><a href="#one4">One Link</a></li>
#  <li><a href="#more4">More Than One Link</a></li>
#
#  </ul>

# %%
df_tweets_4_months_urls_1_link = one_link_df(df_tweets_4_months_urls)

# %%
df_tweets_4_months_urls_1_link.head(1)
# Out:
#                 id_str                 created_at  \
# 0  1345358697959047168  2021-01-02 13:18:03+00:00
#
#                                            full_text lang  \
# 0  @_missyc97_ 2021 to Amber Heard.😂 https://t.co...   en
#
#   in_reply_to_status_id_str    in_reply_to_user_id entities.hashtags  \
# 0     1345357659885678592.0  1083787499980374016.0                []
#
#                                       entities.media entities.symbols  \
# 0  [{'original_info': {'width': 296, 'focus_rects...               []
#
#   entities.urls  ... user.name user.screen_name  \
# 0            []  ...     Liono          f_liono
#
#                              user.profile_banner_url  \
# 0  https://pbs.twimg.com/profile_banners/12438150...
#
#                               user.profile_image_url user.statuses_count  \
# 0  http://pbs.twimg.com/profile_images/1384133945...             28996.0
#
#   user.url  user.verified                       urls n_urls  \
# ...

# %%
list_tweets_4_months_urls_1_link = one_link_urls(df_tweets_4_months_urls_1_link)

# %%
list_tweets_4_months_urls_1_link
# Out:
# array([list(['https://t.co/5djnLz36zv']),
#        list(['https://t.co/MYFspp5yLA']),
#        list(['https://t.co/nrcetCauxr']), ...,
#        list(['https://t.co/UIDQw7a4c2']),
#        list(['https://t.co/NI5aXL1X7R']),
#        list(['https://t.co/GOOQGL79GP'])], dtype=object)

# %%
df_tweets_4_months_urls_1_link.head(1)
# Out:
#                 id_str                 created_at  \
# 0  1345358697959047168  2021-01-02 13:18:03+00:00
#
#                                            full_text lang  \
# 0  @_missyc97_ 2021 to Amber Heard.😂 https://t.co...   en
#
#   in_reply_to_status_id_str    in_reply_to_user_id entities.hashtags  \
# 0     1345357659885678592.0  1083787499980374016.0                []
#
#                                       entities.media entities.symbols  \
# 0  [{'original_info': {'width': 296, 'focus_rects...               []
#
#   entities.urls  ... user.name user.screen_name  \
# 0            []  ...     Liono          f_liono
#
#                              user.profile_banner_url  \
# 0  https://pbs.twimg.com/profile_banners/12438150...
#
#                               user.profile_image_url user.statuses_count  \
# 0  http://pbs.twimg.com/profile_images/1384133945...             28996.0
#
#   user.url  user.verified                       urls n_urls  \
# ...

# %%
df_tweets_4_months_urls_1_link["user.id_str"]
# Out:
# 0        1.243815e+18
# 1        7.101272e+08
# 2        1.891289e+07
# 3        9.872408e+17
# 4        1.335587e+18
#              ...
# 62949    1.277703e+18
# 62950    1.610834e+08
# 62951    3.820443e+09
# 62952    1.277703e+18
# 62953    1.482895e+07
# Name: user.id_str, Length: 62954, dtype: float64

# %%
df_tweets_4_months_urls_1_link_ith_users_count = one_link_urls_with_count(
    df_tweets_4_months_urls_1_link, user_column="user.id_str", url_column="url"
)

# %%
df_tweets_4_months_urls_1_link_ith_users_count
# Out:
#                           link  count  n_users
# 0      https://t.co/5djnLz36zv      1        1
# 1      https://t.co/MBqZrI8zUt      1        1
# 2      https://t.co/Gy5NP2jcIK      1        1
# 3      https://t.co/NITKF98NfM      1        1
# 4      https://t.co/vGo68u4ALf      1        1
# ...                        ...    ...      ...
# 59618  https://t.co/yVQUnY77KX      1        1
# 59619  https://t.co/aekcEOS2r5      1        1
# 59620  https://t.co/xgkG9t2xi1      1        1
# 59621  https://t.co/IPfXjBgX4p      1        1
# 59622  https://t.co/GOOQGL79GP      1        1
#
# [59623 rows x 3 columns]

# %%
df_tweets_4_months_urls_1_link_ith_users_count.to_csv(
    twitter_filter_path
    + "df_tweets_4_months_urls_1_link.csv",
    index=False,
)

# %% [markdown]
# <a id='more4'></a>
# #### More Than One Link
#
# ><ul>
#  <li><a href="#one4">One Link</a></li>
#  <li><a href="#more4">More Than One Link</a></li>
#
#  </ul>

# %%
df_tweets_4_months_urls_more = df_more_than_link(df_tweets_4_months_urls)

# %%
df_tweets_4_months_urls_more.head(2)
# Out:
#                 id_str                 created_at  \
# 0  1345233358889091074  2021-01-02 05:00:00+00:00
# 1  1353271503526227968  2021-01-24 09:20:43+00:00
#
#                                            full_text lang  \
# 0  "Just that JOHNNY DEPP IS INNOCENT "\n\nTake t...   en
# 1  I have an Instagram for this account aswell bt...   en
#
#   in_reply_to_status_id_str    in_reply_to_user_id  \
# 0     1340073306603589632.0  1338967066469167104.0
# 1                       NaN                    NaN
#
#                                    entities.hashtags  \
# 0  [{'indices': [130, 151], 'text': 'JusticeForJo...
# 1  [{'indices': [98, 109], 'text': 'johnnydepp'},...
#
#                                       entities.media entities.symbols  \
# 0  [{'original_info': {'width': 733, 'focus_rects...               []
# 1  [{'original_info': {'width': 1152, 'focus_rect...               []
#
#                                        entities.urls  ... user.location  \
# ...

# %%
df_tweets_4_months_urls_more_link_with_users_count = more_than_one_link_with_count(df_tweets_4_months_urls_more,
                             "user.id_str",
                             "urls")

# %%
df_tweets_4_months_urls_more_link_with_users_count.to_csv(
    twitter_filter_path
    + "df_tweets_4_months_urls_more.csv",
    index=False,
)

# %% [markdown]
# ### December
# <a id='12'></a>
#
#
# ><ul>
#  <li><a href="#one12">One Link</a></li>
#  <li><a href="#more12">More Than One Link</a></li>
#
#  </ul>

# %%
df_tweets_dec["urls"] = df_tweets_dec.full_text.apply(lambda x: get_urls(x))

# %%
df_tweets_dec["n_urls"] = df_tweets_dec.urls.apply(lambda x: len(x))

# %%
df_tweets_dec_urls = urls_df(df_tweets_dec)

# %%
df_tweets_dec_urls.head(5)
# Out:
#                 id_str                created_at  \
# 0  1338253238244683777 2020-12-13 22:43:30+00:00
# 1  1338253210646163456 2020-12-13 22:43:23+00:00
# 2  1338252357453443075 2020-12-13 22:40:00+00:00
# 3  1338251599983104002 2020-12-13 22:36:59+00:00
# 4  1338251229017804801 2020-12-13 22:35:31+00:00
#
#                                            full_text          user.id_str  \
# 0  It Is just me? Or everybody does when sees Joh...  1327952287889821706
# 1  I reckon the old boy is behind all of this.\nP...  1329500457748848648
# 2  Johnny Depp exige a Warner Bros. sacar a Amber...            244218738
# 3  Yesterday I went to a store and asked for the ...           1231252446
# 4  @feral_feminist @Zephyrdust8 @win_confidante @...  1302990802260504577
#
#   user.screen_name               user.name            user.created_at  \
# 0  Camilaalustiza3           OnlyForJohnny  2020-11-15 12:31:21+00:00
# 1        Aishacat5           Aishacat🏴‍☠️😻  2020-11-19 19:03:24+00:00
# ...

# %%
# save data
df_tweets_dec_urls.to_csv(
    twitter_filter_path + "df_tweets_dec_urls.csv", index=False
)

# %% [markdown]
# <a id='one12'></a>
# #### One Link
#
# ><ul>
#  <li><a href="#one12">One Link</a></li>
#  <li><a href="#more12">More Than One Link</a></li>
#
#  </ul>

# %%
df_tweets_dec_urls_1_link = one_link_df(df_tweets_dec_urls)

# %%
df_tweets_dec_urls_1_link.head(1)
# Out:
#                 id_str                created_at  \
# 0  1338253238244683777 2020-12-13 22:43:30+00:00
#
#                                            full_text          user.id_str  \
# 0  It Is just me? Or everybody does when sees Joh...  1327952287889821706
#
#   user.screen_name      user.name            user.created_at  \
# 0  Camilaalustiza3  OnlyForJohnny  2020-11-15 12:31:21+00:00
#
#                         urls  n_urls                      url
# 0  [https://t.co/UzOD82X1oU]       1  https://t.co/UzOD82X1oU

# %%
list_tweets_dec_urls_1_link = one_link_urls(df_tweets_dec_urls_1_link)

# %%
list_tweets_dec_urls_1_link
# Out:
# array([list(['https://t.co/UzOD82X1oU']),
#        list(['https://t.co/cSg2ieMaaA']),
#        list(['https://t.co/iIKojPGvhY']), ...,
#        list(['https://t.co/p7SBtTMNbI']),
#        list(['https://t.co/9fgaSRtGQf']),
#        list(['https://t.co/Q3GSkvO1QM'])], dtype=object)

# %%
df_tweets_dec_urls_1_link_ith_users_count = one_link_urls_with_count(
    df_tweets_dec_urls_1_link, user_column="user.id_str", url_column="url"
)

# %%
df_tweets_dec_urls_1_link_ith_users_count
# Out:
#                           link  count  n_users
# 0      https://t.co/UzOD82X1oU      1        1
# 1      https://t.co/znaaj58ogP      1        1
# 2      https://t.co/wIUkxC9omO      1        1
# 3      https://t.co/6NlaDeRNIQ      1        1
# 4      https://t.co/wRwDKWGMQE      1        1
# ...                        ...    ...      ...
# 21544  https://t.co/pJkk2uXTYm      1        1
# 21545  https://t.co/alrYa5vtUx      1        1
# 21546  https://t.co/uQLbkf7O8O      1        1
# 21547  https://t.co/pAz0hJ8XCV      1        1
# 21548  https://t.co/Q3GSkvO1QM      1        1
#
# [21549 rows x 3 columns]

# %%
# save data
df_tweets_dec_urls_1_link_ith_users_count.to_csv(
    twitter_filter_path
    + "df_tweets_dec_urls_1_link.csv",
    index=False,
)

# %% [markdown]
# <a id='more4'></a>
# #### More Than One Link
#
# ><ul>
#  <li><a href="#one4">One Link</a></li>
#  <li><a href="#more4">More Than One Link</a></li>
#
#  </ul>

# %%
df_tweets_dec_urls_urls_more = df_more_than_link(df_tweets_dec_urls)

# %%
df_tweets_dec_urls_urls_more.head(2)
# Out:
#                 id_str                created_at  \
# 0  1338252357453443075 2020-12-13 22:40:00+00:00
# 1  1338262424063860738 2020-12-13 23:20:00+00:00
#
#                                            full_text  user.id_str  \
# 0  Johnny Depp exige a Warner Bros. sacar a Amber...    244218738
# 1  Johnny Depp exige a Warner Bros. sacar a Amber...    415155226
#
#   user.screen_name             user.name            user.created_at  \
# 0     SinEmbargoMX        Sin Embargo MX  2011-01-28 20:21:23+00:00
# 1     MagazineSEMX  Sin Embargo Magazine  2011-11-17 23:55:57+00:00
#
#                                                 urls  n_urls
# 0  [https://t.co/NHto0O1Ftk, https://t.co/v6P21cV...       2
# 1  [https://t.co/quKtMDv5Ry, https://t.co/N4Nwds7...       2

# %%
df_tweets_dec_urls_urls_more_with_users_count = more_than_one_link_with_count(df_tweets_dec_urls_urls_more,
                             "user.id_str",
                             "urls")

# %%
df_tweets_dec_urls_urls_more_with_users_count.to_csv(
    twitter_filter_path
    + "df_tweets_dec_urls_more.csv",
    index=False,
)
