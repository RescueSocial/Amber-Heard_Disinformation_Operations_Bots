# %%
import pandas as pd
import json
import requests
from io import StringIO
from csv import reader
import os
import glob
import numpy as np
import shutil
import time
import datetime

# %%
# read all data
folder_path = r"C:\Users\David\Amber Heard Case\Youtube\New Data (filtered with 'amber' word)\combined files for videos"
yt_data = pd.read_csv(folder_path +r"\all_scrabed_data_for_34_files(filterd).csv", parse_dates=['snippet.publishedAt'])

# %%
yt_data.shape
# Out:
# (6893, 52)

# %%
yt_data.head()
# Out:
#    Unnamed: 0           id  Unnamed: 0.1           kind  \
# 0           0  14SUI93R_k8           0.0  youtube#video
# 1           1  9rC1gEB5wSk           0.0  youtube#video
# 2           2  nkofr7qZSw0           0.0  youtube#video
# 3           3  82niI4hiImY           NaN  youtube#video
# 4           4  kNA2wjVsp9c           0.0  youtube#video
#
#                           etag       snippet.publishedAt  \
# 0  zUX2H4amXbJxvecYfsO-9mMha7c 2021-03-19 17:00:30+00:00
# 1  W_OcjSa0xjX5E8u4uZKGTkOVnek 2020-12-30 16:25:16+00:00
# 2  rz1_nfM8S8B8philEP9Y1CIt2fE 2019-04-28 16:13:50+00:00
# 3  JH06ceCKw9jT7K-EdPycpZ7_LaE 2021-12-05 13:19:52+00:00
# 4  NoIaeQvZ9WgkrjicJcz5wPlHiT4 2021-06-15 18:37:07+00:00
#
#           snippet.channelId  \
# 0  UC-NINtNMPM75eaqh07RCy_Q
# 1  UCNoGr_InOOlv0XhHO9KC3Hg
# 2  UC4L8zPgbx3ZATeWZ-iEIKiA
# 3  UCeooMl4PFAM9kLPHvavt2KQ
# 4  UCycYfOSLuPwdKJx4fLrlJgA
#
#                                        snippet.title  \
# ...

# %%
#create new column with the publised year
yt_data['year'] = pd.DatetimeIndex(yt_data['snippet.publishedAt']).year

# %%
yt_data.year.value_counts().sort_index()
# Out:
# 2008       3
# 2009      15
# 2010      14
# 2011      47
# 2012      20
# 2013      78
# 2014      59
# 2015      89
# 2016     329
# 2017     213
# 2018     407
# 2019     318
# 2020    1869
# 2021    3432
# Name: year, dtype: int64

# %%
# crate new dataframe for the year 2021:
year = 2021
yt_data_2021 = yt_data[yt_data['snippet.publishedAt'].dt.year == year]
# save dataframe to CSV file:
yt_data_2021.to_csv(folder_path+r'\youtube_data_2021.csv', index=None)
yt_data_2021 = None

# %%
# crate new dataframe for the year 2020:
year = 2020
yt_data_2020 = yt_data[yt_data['snippet.publishedAt'].dt.year == year]
# save dataframe to CSV file:
yt_data_2020.to_csv(folder_path+r'\youtube_data_2020.csv', index=None)
yt_data_2020 = None

# %%
# crate new dataframe for the year 2019:
year = 2019
yt_data_2019 = yt_data[yt_data['snippet.publishedAt'].dt.year == year]
# save dataframe to CSV file:
yt_data_2019.to_csv(folder_path+r'\youtube_data_2019.csv', index=None)
yt_data_2019 = None

# %%
# crate new dataframe for the year 2018:
year = 2018
yt_data_2018 = yt_data[yt_data['snippet.publishedAt'].dt.year == year]
# save dataframe to CSV file:
yt_data_2018.to_csv(folder_path+r'\youtube_data_2018.csv', index=None)
yt_data_2018 = None

# %%
# crate new dataframe for the year 2017:
year = 2017
yt_data_2017 = yt_data[yt_data['snippet.publishedAt'].dt.year == year]
# save dataframe to CSV file:
yt_data_2017.to_csv(folder_path+r'\youtube_data_2017.csv', index=None)
yt_data_2017 = None

# %%
# crate new dataframe for the year 2016:
year = 2016
yt_data_2016 = yt_data[yt_data['snippet.publishedAt'].dt.year == year]
# save dataframe to CSV file:
yt_data_2016.to_csv(folder_path+r'\youtube_data_2016.csv', index=None)
yt_data_2016 = None

# %%
# crate new dataframe for the years from 2008 to 2015:
years = [2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008]
yt_data_2008to2015 = pd.DataFrame()
for year in years:
    yt_data_2008to2015 = yt_data_2008to2015.append(yt_data[yt_data['snippet.publishedAt'].dt.year == year])
# save dataframe to CSV file:
yt_data_2008to2015.to_csv(folder_path+r'\youtube_data_2008to2015.csv', index=None)
yt_data_2008to2015 = None
