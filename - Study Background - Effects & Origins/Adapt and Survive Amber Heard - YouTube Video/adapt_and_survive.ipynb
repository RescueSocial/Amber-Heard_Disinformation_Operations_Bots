# %% [markdown]
# # Adapt and Survive Data

# %%
import pandas as pd

# %%
data_path = "../../[CSV] Combined by year [6893 videos](videos, comments and channels) (final 25Dec21)"

# %%
cd "../../[CSV] Combined by year [6893 videos](videos, comments and channels) (final 25Dec21)"
# Out:
# [WinError 2] The system cannot find the file specified: '../../[CSV] Combined by year [6893 videos](videos, comments and channels) (final 25Dec21)'
# D:\test\mapbox-android-sample-master\src\New folder\[CSV] Combined by year [6893 videos](videos, comments and channels) (final 25Dec21)

# %%
ls
# Out:
#  Volume in drive D has no label.
#  Volume Serial Number is 4623-EF98
#
#  Directory of D:\test\mapbox-android-sample-master\src\New folder\[CSV] Combined by year [6893 videos](videos, comments and channels) (final 25Dec21)
#
# 12/26/2021  02:01 PM    <DIR>          .
# 12/26/2021  02:01 PM    <DIR>          ..
# 12/26/2021  01:56 PM    <DIR>          Blocked users
# 12/26/2021  02:00 PM    <DIR>          combined channels info by year
# 12/20/2021  02:34 PM    <DIR>          combined files for videos by year
# 12/20/2021  03:22 PM    <DIR>          comments filter by year(based on comment year Not main video)
#                0 File(s)              0 bytes
#                6 Dir(s)  35,308,511,232 bytes free

# %%
df_videos = pd.read_csv(
    "combined files for videos by year/all_scrabed_data_for_34_files(filterd).csv"
)

# %%
df_videos[df_videos["snippet.title"].str.contains('adapt', case=True, regex=True)]["snippet.title"]
# Out:
# 2030                     amber mac: relentless adaptation
# 2929    the stand (2020): masud über stephen kings ser...
# 4698    amber heard vs bots swarm tech & influence ope...
# 6617       amber heard's 2020 takeaway: 'adapt & survive'
# Name: snippet.title, dtype: object

# %%
adapt_id = df_videos[df_videos.index == 6617].id.values[0]
adapt_id
# Out:
# 'uretrfMA-Io'

# %%
 df_videos[df_videos.index == 6617]["snippet.publishedAt"]
# Out:
# 6617    2020-12-15T04:54:59Z
# Name: snippet.publishedAt, dtype: object

# %% [markdown]
# #### As the video was published in 2020-12-15T04:54:59Z, we need only 2020 and 2021 data

# %%
ls "comments filter by year(based on comment year Not main video)"
# Out:
#  Volume in drive D has no label.
#  Volume Serial Number is 4623-EF98
#
#  Directory of D:\test\mapbox-android-sample-master\src\New folder\[CSV] Combined by year [6893 videos](videos, comments and channels) (final 25Dec21)\comments filter by year(based on comment year Not main video)
#
# 12/20/2021  03:22 PM    <DIR>          .
# 12/20/2021  03:22 PM    <DIR>          ..
# 12/20/2021  03:22 PM         9,841,482 comments_data_2008to2013.csv
# 12/20/2021  03:19 PM        32,276,649 comments_data_2014.csv
# 12/20/2021  03:19 PM        16,885,655 comments_data_2015.csv
# 12/20/2021  03:19 PM        41,047,393 comments_data_2016.csv
# 12/20/2021  03:19 PM        26,705,339 comments_data_2017.csv
# 12/20/2021  03:18 PM       128,381,987 comments_data_2018.csv
# 12/20/2021  03:18 PM        86,829,221 comments_data_2019.csv
# 12/20/2021  03:18 PM       711,647,145 comments_data_2020.csv
# 12/20/2021  03:15 PM       613,961,301 comments_data_2021.csv
# ...

# %%
df_comments_20 = pd.read_csv(
    "comments filter by year(based on comment year Not main video)/comments_data_2020.csv",
    low_memory=False
)

# %%
df_comments_21 = pd.read_csv(
    "comments filter by year(based on comment year Not main video)/comments_data_2021.csv",
    low_memory=False
)

# %%
df_comments_20.head(1)
# Out:
#    Unnamed: 0                   kind                         etag  \
# 0         0.0  youtube#commentThread  WravDADRj2DkMDO6UpH_bj7ZLRk
#
#                            id snippet.videoId snippet.topLevelComment.kind  \
# 0  Ugzoo_58ATK2o_8MKMt4AaABAg     _vfN675NT0k              youtube#comment
#
#   snippet.topLevelComment.etag  snippet.topLevelComment.id  \
# 0  fC6bDu-6NHX0XmKcEMENIfgYHMo  Ugzoo_58ATK2o_8MKMt4AaABAg
#
#   snippet.topLevelComment.snippet.videoId  \
# 0                             _vfN675NT0k
#
#          snippet.topLevelComment.snippet.textDisplay  ...  \
# 0  Johnny Depp is a wife beater . Eff him. Why wo...  ...
#
#   snippet.topLevelComment.snippet.canRate  \
# 0                                    True
#
#   snippet.topLevelComment.snippet.viewerRating  \
# 0                                         none
#
#   snippet.topLevelComment.snippet.likeCount  \
# 0                                       0.0
#
#   snippet.topLevelComment.snippet.publishedAt  \
# ...

# %%
adapt_20 = df_comments_20[df_comments_20["snippet.videoId"] == adapt_id]

# %%
adapt_21 = df_comments_21[df_comments_21["snippet.videoId"] == adapt_id]

# %%
adapt_comments = pd.concat([adapt_20, adapt_21]).drop(columns="Unnamed: 0").reset_index().drop(columns="index")

# %%
adapt_comments
# Out:
#                          kind                         etag  \
# 0       youtube#commentThread  dyaPYZyu2uj5SX9H0QdcWTKOV1Y
# 1       youtube#commentThread  XPINEj9jEnmAwezdof7po999JzY
# 2       youtube#commentThread  hLK39t77EyENRRODWjCEqIxWt1U
# 3       youtube#commentThread  TCJTOsdVl9aEh9_1-WRmnIBRTVY
# 4       youtube#commentThread  EwchcqjwHtM2T_CbUzjOULQ4ZD4
# ...                       ...                          ...
# 120495  youtube#commentThread  1DLOxeaYtA9yxWa4FHf5lKhNxyg
# 120496  youtube#commentThread  aCmSCh08qod9DNSrj03NxLwKZhI
# 120497  youtube#commentThread  zhiOOcTPi-CCF_a7YeQVoO98zSE
# 120498  youtube#commentThread  NDCGxfTvK0cYW17-3y2duaixs9Y
# 120499  youtube#commentThread  9jrxHx6Yr-0n_0xr8V6Z2JysiY0
#
#                                 id snippet.videoId  \
# 0       UgzbbSK1wV4jjzuKK-R4AaABAg     uretrfMA-Io
# 1       UgyETm2qxAepIxBp4hx4AaABAg     uretrfMA-Io
# 2       UgxlwTIXSb9A2TPF_vl4AaABAg     uretrfMA-Io
# ...

# %%
ls
# Out:
#  Volume in drive D has no label.
#  Volume Serial Number is 4623-EF98
#
#  Directory of D:\test\mapbox-android-sample-master\src\New folder\[CSV] Combined by year [6893 videos](videos, comments and channels) (final 25Dec21)
#
# 12/26/2021  02:01 PM    <DIR>          .
# 12/26/2021  02:01 PM    <DIR>          ..
# 12/26/2021  01:56 PM    <DIR>          Blocked users
# 12/26/2021  02:00 PM    <DIR>          combined channels info by year
# 12/20/2021  02:34 PM    <DIR>          combined files for videos by year
# 12/20/2021  03:22 PM    <DIR>          comments filter by year(based on comment year Not main video)
#                0 File(s)              0 bytes
#                6 Dir(s)  35,308,511,232 bytes free

# %%
path = "adapt/"

# %%
adapt_comments.to_csv(path + "adapt_comments.csv", index=False)

# %%
ls
# Out:
#  Volume in drive D has no label.
#  Volume Serial Number is 4623-EF98
#
#  Directory of D:\test\mapbox-android-sample-master\src\New folder\[CSV] Combined by year [6893 videos](videos, comments and channels) (final 25Dec21)
#
# 02/03/2022  09:54 PM    <DIR>          .
# 02/03/2022  09:54 PM    <DIR>          ..
# 02/03/2022  09:55 PM    <DIR>          adapt
# 12/26/2021  01:56 PM    <DIR>          Blocked users
# 12/26/2021  02:00 PM    <DIR>          combined channels info by year
# 12/20/2021  02:34 PM    <DIR>          combined files for videos by year
# 12/20/2021  03:22 PM    <DIR>          comments filter by year(based on comment year Not main video)
#                0 File(s)              0 bytes
#                7 Dir(s)  35,228,053,504 bytes free

# %%
adapt_comments.columns
# Out:
# Index(['kind', 'etag', 'id', 'snippet.videoId', 'snippet.topLevelComment.kind',
#        'snippet.topLevelComment.etag', 'snippet.topLevelComment.id',
#        'snippet.topLevelComment.snippet.videoId',
#        'snippet.topLevelComment.snippet.textDisplay',
#        'snippet.topLevelComment.snippet.textOriginal',
#        'snippet.topLevelComment.snippet.authorDisplayName',
#        'snippet.topLevelComment.snippet.authorProfileImageUrl',
#        'snippet.topLevelComment.snippet.authorChannelUrl',
#        'snippet.topLevelComment.snippet.authorChannelId.value',
#        'snippet.topLevelComment.snippet.canRate',
#        'snippet.topLevelComment.snippet.viewerRating',
#        'snippet.topLevelComment.snippet.likeCount',
#        'snippet.topLevelComment.snippet.publishedAt',
#        'snippet.topLevelComment.snippet.updatedAt', 'snippet.canReply',
#        'snippet.totalReplyCount', 'snippet.isPublic', 'replies.comments',
# ...

# %%
channls_adapt = adapt_comments["snippet.topLevelComment.snippet.authorChannelId.value"].drop_duplicates()

# %%
channls_adapt = pd.DataFrame(channls_adapt)

# %%
channls_adapt
# Out:
#        snippet.topLevelComment.snippet.authorChannelId.value
# 0                                UCOUuRVXETO3yfJ63FS_vomQ
# 1                                UCbIAiTAdm8LCIO_VGKDykuA
# 2                                UC1M2xKC-OeN_9RnFpSxUozg
# 3                                UC_4Z-mtb1mqH2txvaXk28Yw
# 4                                UCF0PA-ihU5zPPZquLKlrnXw
# ...                                                   ...
# 120494                           UCAfeLgdJjKgHpTTK5aTxTbQ
# 120495                           UCRsy-VV6E0gruf3TI1507eQ
# 120496                           UCfRix3Szs2PiEeXvDachUow
# 120498                           UCyJvfUqVLYo3Mg19U1qLb2w
# 120499                           UCcpGLgrd5Rgnk8y5u6olk4Q
#
# [111654 rows x 1 columns]

# %%
cd "combined channels info by year"
# Out:
# D:\test\mapbox-android-sample-master\src\New folder\[CSV] Combined by year [6893 videos](videos, comments and channels) (final 25Dec21)\combined channels info by year

# %%
ch1 = pd.read_csv("channles_info_2008-2013.csv")
ch2 = pd.read_csv("channles_info_2014.csv")
ch3 = pd.read_csv("channles_info_2015.csv")
ch4 = pd.read_csv("channles_info_2016.csv")
ch5 = pd.read_csv("channles_info_2017.csv")
ch6 = pd.read_csv("channles_info_2018.csv")
ch7 = pd.read_csv("channles_info_2019.csv")
ch8 = pd.read_csv("channles_info_2020.csv")
ch9 = pd.read_csv("channles_info_2021.csv")

# %%
channels = pd.concat([ch1,ch2,ch3,ch4,ch5,ch6,ch7,ch8,ch9])

# %%
channels
# Out:
#                    kind                         etag  \
# 0       youtube#channel  9xWBmgJRinhToZwPS8aicoZgDEY
# 1       youtube#channel  keNfPOTzrt8SBeRPvkAeX0JMKws
# 2       youtube#channel  o4YiXuwtwbBgAAJOudKvaU9EH8o
# 3       youtube#channel  1d-q4hifYCDuO2tl6zyuvsglKt0
# 4       youtube#channel  koU4v4cx_bfh5sxWClu4lDoQmL0
# ...                 ...                          ...
# 347613  youtube#channel  -dETwBGWUcXGn87otjwddaC72mQ
# 347614  youtube#channel  nhIHPRGzst71DGEwKBFUdeZ_gkw
# 347615  youtube#channel  cBQZ-R-eJAxFW371DjIt6p55lxw
# 347616  youtube#channel  pAOlNCi6RAd6xiD96kkqK8FNLqo
# 347617  youtube#channel  _dZCowjlfo-pPGFHb-PijgaJGLU
#
#                               id       snippet.title snippet.description  \
# 0       UC--0k43d5M8nmtdf319cEBw   This Side Of Life                 NaN
# 1       UC--88vmCfoADXKrbkr55QBQ         memberWinny                 NaN
# 2       UC--x-JoynEq-qzYTdsxkHog    yarinka collucci                 NaN
# ...

# %%
channls_adapt = channls_adapt.rename(columns={"snippet.topLevelComment.snippet.authorChannelId.value": "id"})

# %%
adapt_channels = pd.merge(channls_adapt, channels, right_on="id",
        left_on="id", how="inner")

# %%
cd ..
# Out:
# D:\test\mapbox-android-sample-master\src\New folder\[CSV] Combined by year [6893 videos](videos, comments and channels) (final 25Dec21)

# %%
adapt_channels
# Out:
#                               id             kind  \
# 0       UCOUuRVXETO3yfJ63FS_vomQ  youtube#channel
# 1       UCbIAiTAdm8LCIO_VGKDykuA  youtube#channel
# 2       UC1M2xKC-OeN_9RnFpSxUozg  youtube#channel
# 3       UC_4Z-mtb1mqH2txvaXk28Yw  youtube#channel
# 4       UCF0PA-ihU5zPPZquLKlrnXw  youtube#channel
# ...                          ...              ...
# 118467  UCAfeLgdJjKgHpTTK5aTxTbQ  youtube#channel
# 118468  UCRsy-VV6E0gruf3TI1507eQ  youtube#channel
# 118469  UCfRix3Szs2PiEeXvDachUow  youtube#channel
# 118470  UCyJvfUqVLYo3Mg19U1qLb2w  youtube#channel
# 118471  UCcpGLgrd5Rgnk8y5u6olk4Q  youtube#channel
#
#                                etag        snippet.title  \
# 0       kW67jYhN3ed_q5-y2mddtSA8QkQ       LondonPorrasze
# 1       0GOwchZ69zIJrMOX0Nf3HJr_rrI     Willjo Gameplays
# 2       u1cXuidAP-SFA8bDsyvrgFBng0k  The Human Algorithm
# 3       R0NqXlIgcIpn-qImKgNrptgOwMw        timea tamberi
# 4       uQQFc1jZFYirqdxzRZB4plvVdRU                 Oxo.
# ...

# %%
adapt_channels.to_csv(path + "adapt_channels.csv", index=False)
