# %% [markdown]
# # Read and clean comments details

# %%
import pandas as pd
import json
import requests
from io import StringIO
from csv import reader
import os
import glob

# %%
# read josn files and make a list with json files
# (make 1 change)
folder_name = 'JSON batch4-6'
path_to_json = r"C:\Users\David\Amber Heard Case\Youtube\Data\videos comments info - final -batch4/"+ folder_name
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]
json_files;  
len(json_files)
# Out:
# 343

# %%
# create a data frame with all json files:

df = pd.DataFrame()
for file in json_files:
    file_path = path_to_json+"/" + file
    with open(file_path) as data_file:    
        data = json.load(data_file)
        df = df.append(pd.json_normalize(data))
df.shape
# Out:
# (83887, 24)

# %%
df.shape
# Out:
# (83887, 24)

# %%
# save every 500 video comments to one file
save_url = r'C:\Users\David\Amber Heard Case\Youtube\Data\combined files for videos comments info batch {}\scraped comments- JSON -{} Batch-{}.csv'.format(list(folder_name)[10], folder_name.split('-')[1], list(folder_name)[10])
df.to_csv(save_url, index=None)

# %%
df.head()
# Out:
#                     kind                         etag  \
# 0  youtube#commentThread  z6hFHK4_zYi-Gm2EeOhFtcxIG0A
# 1  youtube#commentThread  mYZ_q2P-tLnz0iTmPXfUlgXLxwU
# 2  youtube#commentThread  0dTtvYtCI7DjoV159FNSO9cKnKE
# 3  youtube#commentThread  z6KjvUDbu6l9NHGIsy-Q38z9zeg
# 4  youtube#commentThread  qxTxM66CV_yJzcQJf10GeO2l0xo
#
#                            id snippet.videoId snippet.topLevelComment.kind  \
# 0  UgyVYpahPzzRpvfbi_V4AaABAg     -2hZb6Oiv5Y              youtube#comment
# 1  UgxlNn5AmU12Epa23D14AaABAg     -2hZb6Oiv5Y              youtube#comment
# 2  UgyDf0PUgX-WpD14Ut94AaABAg     -2hZb6Oiv5Y              youtube#comment
# 3  UgxzqGogqXliP8Ag_BZ4AaABAg     -2hZb6Oiv5Y              youtube#comment
# 4  Ugw7RJFhG04iErG6gzV4AaABAg     -2hZb6Oiv5Y              youtube#comment
#
#   snippet.topLevelComment.etag  snippet.topLevelComment.id  \
# 0  ATUC0WNN05mTofb6r_E7IA5okPw  UgyVYpahPzzRpvfbi_V4AaABAg
# 1  LFu1A6DmpG7mYI__bo33SxK9gZI  UgxlNn5AmU12Epa23D14AaABAg
# ...
