# %% [markdown]
# # Obtaining comments by video ID

# %%
import pandas as pd
import json
import requests
from csv import reader
import os
import glob
import requests
import sys

# %%
class YTstats:
    '''
    this class takes api_key and video id
    then obtain comments for the video
    '''    
  
    def __init__(self, api_key, video_id):
        self.api_key = api_key
        self.video_id = video_id
        self.video_statistics = None
  
    def get_video_statistics(self):
        url = f'https://youtube.googleapis.com/youtube/v3/commentThreads?part=replies&part=snippet&maxResults=900&videoId={self.video_id}&key={self.api_key}'
        json_url = requests.get(url)
        data = json.loads(json_url.text)
        nextPageToken = data.get("nextPageToken")
        
        i = 0
        a = ''
        if nextPageToken:
            while nextPageToken != a:
                a = nextPageToken
                i += 1
                url = f'https://youtube.googleapis.com/youtube/v3/commentThreads?part=replies&part=id&part=snippet&maxResults=100&videoId={self.video_id}&key={self.api_key}&pageToken={nextPageToken}'
                json_url = requests.get(url)
                data1 = json.loads(json_url.text)
                nextPageToken = data1.get("nextPageToken")
                data['items'] = data['items'] + data1['items']
                
                if nextPageToken is None:
                    break
                print('page number:', i+1)
              #  print(nextPageToken, len(data['items']))
            
            
        try:
            data = data["items"]#[0]["statistics"]
        except:
            data = None
  
        self.video_statistics = data
        return data
  
    def dump(self):
        if self.video_statistics is None:
            print('nothing happend')
            return 
  
        video_title = self.video_id
        video_title = video_title.replace(" ", "_")
  
        # generate a json file with all the statistics data of the youtube video
        file_name = video_title + '.json'
        with open(file_name, 'w') as f:
            json.dump(self.video_statistics, f, indent=4)
        print('file dumped')

# %% [markdown]
# # Read IDs and obtaining there comments

# %%
# Read vidos IDs to get comments of this videos
file_url = r'C:\Users\David\Amber Heard Case\Youtube\SNA-AH-Case-YouTube\scraping\videos_data\34- scraped ids by david  - amber heard playing victim.csv'
amber_heard = pd.read_csv(file_url)
amber_heard = list(amber_heard['id'])
len(amber_heard)
# Out:
# 76

# %%
# recive data using API and save it on PC

API_KEY1 = "---KEY---"
API_KEY2 = "---KEY---"
API_KEY3 = "---KEY---"
API_KEY4 = "---KEY---"


# paste the channel id here

while len(amber_heard) !=0:
    
    for video in amber_heard:
        print(video)
        yt = YTstats(API_KEY4, video)
        yt.get_video_statistics()
        yt.dump()
        amber_heard.remove(video)
        print(len(amber_heard))
# Out:
# QUQqXOMFtfk
# file dumped
# 75
# fWEn3lfmCKc
# file dumped
# 74
# LGpLOUjKgDs
# file dumped
# 73
# ELZYfdcAmac
# file dumped
# 72
# UBApuBdAYFY
# file dumped
# 71
# INbpxn4by14
# file dumped
# 70
# r8rcLTH0Fd0
# file dumped
# 69
# DAsoO0HI3u0
# file dumped
# 68
# VFU0GTifYiU
# file dumped
# 67
# vPwD_VgP_mg
# file dumped
# 66
# mehMlUJLgKo
# nothing happend
# 65
# wMcd1ywyiWI
# file dumped
# 64
# JGr8QBEGM38
# file dumped
# 63
# diEOWXOM65c
# file dumped
# 62
# GzMYx1-LhsM
# file dumped
# 61
# DhbaaA0Lu_4
# file dumped
# 60
# page number: 4
# page number: 5
# file dumped
# 5
# u6m6s7CAB9M
# file dumped
# 4
# Wsn4aXVptWU
# file dumped
# 3
# PSHM9k1iPqQ
# file dumped
# 2
# ZzgnnowuVZ4
# nothing happend
# 1
# cbJtCwEHY3o
# page number: 2
# page number: 3
# page number: 4
# page number: 5
# page number: 6
# page number: 7
# page number: 8
# file dumped
# 0

# %%
amber_heard.remove('k5gHYfKAi7k')

# %%
amber_heard
# Out:
# ['x959gsjWr2M',
#  'MrJgsZ4Ua3A',
#  'OZHnSIANwgQ',
#  'S9Xr4AfjFDQ',
#  'aQPwL1sNTeA',
#  'YI7PLVl9oik',
#  'fKmcioeO9Uw',
#  'uw4LyKOIbJw',
#  'HKGS72aXQec',
#  'I-MNgNEkaMc',
#  '4gmIvR-YaF4',
#  '7jwuzoI3O7Y',
#  'wMFlIvb_KpE',
#  'XaodMMhrFYg',
#  '_vT8OTiwBls',
#  '9TDEmIvl6PU',
#  'YpbZxsMDmrQ',
#  'x9JoMRNaZbg',
#  'knJZ7XcZN8g',
#  'o-3UAYI2AFM',
#  '0M4P-zhVuOM',
#  '-7kb8hWa92I',
#  'Cp4Xttacy94',
#  'L-jyadFjq-U',
#  '0y782wu5Urw',
#  'HglaqdI6dUQ',
#  'ugRc5jx80yg',
#  'sxWTK1-k20g',
#  'SQSg15sXdEQ',
#  'OYVeHmbpx9s',
#  'GXae6jK3Bfo',
#  'SkFYO9ZPL8k',
#  'Pq-F9F_qSdk',
#  'MCoSZbCb-fI',
#  'j_y88KAPKW0',
#  'xKM6rfywQ7g',
#  'YG52Bd9j-dc',
#  'ULGhiG0sysM',
#  '7uSGH_EgfuQ',
#  'ryH5cga0yUI',
#  'EAzEC_l44c8',
#  'Co2iCoxxmcQ',
#  'N56rGkoQ9-o',
#  'e0IzyESwcTw',
#  'wnUD7T5hQAs',
#  'U85KTBfUB9Y',
#  'OMD8hBsA-RI',
#  'ld3gFs4E69E',
#  'UI6x75e7iig',
#  'csZV3w_nscg',
#  'ZX5o2cHKGk8',
#  'ZJnRr_b1jYk',
#  'q4a9CKgLprQ',
#  'GfE3NGX47Vo',
#  'GFnzbfB--dw',
#  '9l9R8vwqiPk',
#  'ZCbTICNAwxM',
#  'sciKJUWCrI8',
#  'M3UdbDZHwX8',
#  'afDYPOiL5pY',
#  '4yAiEaCU-Y8',
#  'EnnoEnlCXJg',
#  'UxULfBGieKk',
#  '1zROheqfPr4',
#  '_LahxgFrn94',
#  'Zvj_U1JOOzA',
#  'AA3IuZX8hCo',
#  'it5XICr93wU',
#  'ZAKrb9b4s28',
#  'ms1MY9SP7f4',
#  'J5qeTQXn3r4',
#  'lYxyV4I2R_g',
#  '8FHuaRHc93s',
#  'QQcFKesQSQ4']

# %% [markdown]
# ## save the uncollected id to collect later

# %%
amber_heard_df = pd.DataFrame(amber_heard, columns=['id'])
amber_heard_df.to_csv('to_get_comments-batch-2-to continue.csv', index=None)
