# %%
import numpy as np
import pandas as pd
import os
import ast
# pd.set_option('display.max_columns', 500)

import helpers

# To Apply helpers updates without resarting the kernel
import importlib
importlib.reload(helpers)

# # To keep track of any module updates
# %load_ext autoreload
# %autoreload2
# Out:
# <module 'helpers' from '/Users/mnagy99/jupyter/AH/YouTube_Bot_Analysis/SNA-AH-Case-YouTube/YouTube Wrangling & Analysis /helpers.py'>

# %%
cd ../../
# Out:
# /Users/mnagy99/jupyter/AH/YouTube_Bot_Analysis

# %%
ls
# Out:
# Filtered Data/       SNA-AH-Case-YouTube/ Stackoverflow.ipynb*

# %%
cd "Filtered Data"
# Out:
# /Users/mnagy99/jupyter/AH/YouTube_Bot_Analysis/Filtered Data

# %%
ls
# Out:
# [CSV] Combined by year [6893 videos](videos, comments and channels) (final 25Dec21)/
# [CSV] Combined by year [6893 videos](videos, comments and channels) (final 25Dec21).rar*
# combined files for videos comments info batch 1.csv*
# combined files for videos comments info batch 2.csv*
# combined files for videos comments info batch 3.csv*
# combined files for videos comments info batch 4.csv*
# comments filter by year(based on comment year Not main video)/
# comments_cleaned/
# old/

# %%
cd "comments filter by year(based on comment year Not main video)"
# Out:
# /Users/mnagy99/jupyter/AH/YouTube_Bot_Analysis/Filtered Data/comments filter by year(based on comment year Not main video)

# %%
ls
# Out:
# comments_data_2008to2013.csv* comments_data_2018.csv*
# comments_data_2014.csv*       comments_data_2019.csv*
# comments_data_2015.csv*       comments_data_2020.csv*
# comments_data_2016.csv*       comments_data_2021.csv*
# comments_data_2017.csv*

# %%
data_files = [f for f in sorted(os.listdir()) if not f.startswith('.')]
data_files
# Out:
# ['comments_data_2008to2013.csv',
#  'comments_data_2014.csv',
#  'comments_data_2015.csv',
#  'comments_data_2016.csv',
#  'comments_data_2017.csv',
#  'comments_data_2018.csv',
#  'comments_data_2019.csv',
#  'comments_data_2020.csv',
#  'comments_data_2021.csv']

# %%
len(data_files)
# Out:
# 9

# %%
df_08_13 = pd.read_csv(data_files[0])

# %%
df_08_13.head(1)
# Out:
#    Unnamed: 0                   kind                         etag  \
# 0        72.0  youtube#commentThread  nqao31pRb3m5iwgtvpPFWnuVzvQ
#
#                      id snippet.videoId snippet.topLevelComment.kind  \
# 0  UgjyORuX3p35VXgCoAEC     DiXRVYRZchs              youtube#comment
#
#   snippet.topLevelComment.etag snippet.topLevelComment.id  \
# 0  mvtTos5huTqXhtAs-JPzt7mls_A       UgjyORuX3p35VXgCoAEC
#
#   snippet.topLevelComment.snippet.videoId  \
# 0                             DiXRVYRZchs
#
#   snippet.topLevelComment.snippet.textDisplay  ...  \
# 0                                  GOOD WORK!  ...
#
#   snippet.topLevelComment.snippet.canRate  \
# 0                                    True
#
#   snippet.topLevelComment.snippet.viewerRating  \
# 0                                         none
#
#   snippet.topLevelComment.snippet.likeCount  \
# 0                                       9.0
#
#   snippet.topLevelComment.snippet.publishedAt  \
# ...

# %%
df_14 = pd.read_csv(data_files[1], low_memory=False)
df_15 = pd.read_csv(data_files[2], low_memory=False)
df_16 = pd.read_csv(data_files[3], low_memory=False)
df_17 = pd.read_csv(data_files[4], low_memory=False)
df_18 = pd.read_csv(data_files[5], low_memory=False)
df_19 = pd.read_csv(data_files[6], low_memory=False)
df_20 = pd.read_csv(data_files[7], low_memory=False)
df_21 = pd.read_csv(data_files[8], low_memory=False)

# %%
dfs = [
    df_08_13,
    df_14,
    df_15,
    df_16,
    df_17,
    df_18,
    df_19,
    df_20,
    df_21,
]

# %% [markdown]
# https://stackoverflow.com/questions/20225110/comparing-two-dataframes-and-getting-the-differences

# %%
print(df_20.shape)
df_20.head()
# Out:
# (706348, 25)
#    Unnamed: 0                   kind                         etag  \
# 0         0.0  youtube#commentThread  WravDADRj2DkMDO6UpH_bj7ZLRk
# 1         1.0  youtube#commentThread  aFdXlARiuvcPvBRyRS-GYE3pTX0
# 2         2.0  youtube#commentThread  -bDVxgb_Rxcsl6dDR8QJE0RqMa8
# 3         3.0  youtube#commentThread  6pAVpB9htJDOBM0nLKQA_A11AYg
# 4         1.0  youtube#commentThread  gmrd4CjW-fKwStLSfoY-NX9elaM
#
#                            id snippet.videoId snippet.topLevelComment.kind  \
# 0  Ugzoo_58ATK2o_8MKMt4AaABAg     _vfN675NT0k              youtube#comment
# 1  UgyuTwDuRsYa0ssEhNR4AaABAg     _vfN675NT0k              youtube#comment
# 2  Ugx0XmX6Otg44OD0Lml4AaABAg     _vfN675NT0k              youtube#comment
# 3  UgxhMYQzYTQcDr1pvVt4AaABAg     _vfN675NT0k              youtube#comment
# 4  UgylSXpEo0-tlX9Gxul4AaABAg     Ugtl8D8XACE              youtube#comment
#
#   snippet.topLevelComment.etag  snippet.topLevelComment.id  \
# ...

# %%
print(df_21.shape)
df_21.head()
# Out:
# (591055, 25)
#    Unnamed: 0                   kind                         etag  \
# 0         0.0  youtube#commentThread  HWRVF49a2ObDyvftwuVdJKNhyD8
# 1         1.0  youtube#commentThread  PrKH0KyXiSAQLB1ZX7qNOX9prZ0
# 2         2.0  youtube#commentThread  uglOzbTgo8081oh4T849ZkVhL88
# 3         3.0  youtube#commentThread  U8GH-dInC-2tRoUO2rJE5Sp3Cww
# 4         4.0  youtube#commentThread  0YA-zulmTMUMgRIZbNLSTh1_jV4
#
#                            id snippet.videoId snippet.topLevelComment.kind  \
# 0  UgyWYCQS7evmvfmJS-N4AaABAg     14SUI93R_k8              youtube#comment
# 1  UgxueJBxNOJkXUtDLu94AaABAg     14SUI93R_k8              youtube#comment
# 2  Ugyj57EYQJn20ZVZhK54AaABAg     14SUI93R_k8              youtube#comment
# 3  UgxKsoVyNKnCNvSSzGt4AaABAg     14SUI93R_k8              youtube#comment
# 4  Ugzum6kk1s3god1OT-F4AaABAg     14SUI93R_k8              youtube#comment
#
#   snippet.topLevelComment.etag  snippet.topLevelComment.id  \
# ...

# %%
# (df_20 != df_21).sum()

# %% [markdown]
# #### Validate that all dfs have the same structure

# %%
for df in dfs:
    print(df.shape)
# Out:
# (15689, 25)
# (39560, 25)
# (22350, 25)
# (43175, 25)
# (36005, 25)
# (156043, 25)
# (91870, 25)
# (706348, 25)
# (591055, 25)

# %%
total_records = 0
for df in dfs:
    total_records += df.shape[0]

# %%
total_records
# Out:
# 1702095

# %% [markdown]
# #### Validate that  all years dfs have the same coulmns

# %%
columns = pd.DataFrame(
    {
        "old": df_08_13.columns,
        "14": df_14.columns,
        "15": df_15.columns,
        "16": df_16.columns,
        "17": df_17.columns,
        "18": df_18.columns,
        "19": df_19.columns,
        "20": df_20.columns,
        "21": df_21.columns,
    }
)

# %%
columns
# Out:
#                                                   old  \
# 0                                          Unnamed: 0
# 1                                                kind
# 2                                                etag
# 3                                                  id
# 4                                     snippet.videoId
# 5                        snippet.topLevelComment.kind
# 6                        snippet.topLevelComment.etag
# 7                          snippet.topLevelComment.id
# 8             snippet.topLevelComment.snippet.videoId
# 9         snippet.topLevelComment.snippet.textDisplay
# 10       snippet.topLevelComment.snippet.textOriginal
# 11  snippet.topLevelComment.snippet.authorDisplayName
# 12  snippet.topLevelComment.snippet.authorProfileI...
# 13   snippet.topLevelComment.snippet.authorChannelUrl
# 14  snippet.topLevelComment.snippet.authorChannelI...
# 15            snippet.topLevelComment.snippet.canRate
# ...

# %%
for col in columns.columns[1:]:
    if sum(columns["old"] == columns[col]) == columns.shape[0]:
        print( "same")
# Out:
# same
# same
# same
# same
# same
# same
# same
# same

# %% [markdown]
# ## The methadology is to gather all data, clean it, then filter them by year!

# %%
df_08_13_cleaned = df_08_13.copy()
df_14_cleaned = df_14.copy()
df_15_cleaned = df_15.copy()
df_16_cleaned_cleaned = df_16.copy()
df_17_cleaned = df_17.copy()
df_18_cleaned = df_18.copy()
df_19_cleaned = df_19.copy()
df_20_cleaned = df_20.copy()
df_21_cleaned = df_21.copy()

# %%
df_08_13_cleaned.head(2)
# Out:
#    Unnamed: 0                   kind                         etag  \
# 0        72.0  youtube#commentThread  nqao31pRb3m5iwgtvpPFWnuVzvQ
# 1      1300.0  youtube#commentThread  pMAfl478vrmhuA-RYpGVREwJMs0
#
#                      id snippet.videoId snippet.topLevelComment.kind  \
# 0  UgjyORuX3p35VXgCoAEC     DiXRVYRZchs              youtube#comment
# 1  UggV-BvKpFaaaHgCoAEC     VPUUrdgxIa8              youtube#comment
#
#   snippet.topLevelComment.etag snippet.topLevelComment.id  \
# 0  mvtTos5huTqXhtAs-JPzt7mls_A       UgjyORuX3p35VXgCoAEC
# 1  XpsHQJXeW3QznSOnkHg2LFrp-dU       UggV-BvKpFaaaHgCoAEC
#
#   snippet.topLevelComment.snippet.videoId  \
# 0                             DiXRVYRZchs
# 1                             VPUUrdgxIa8
#
#   snippet.topLevelComment.snippet.textDisplay  ...  \
# 0                                  GOOD WORK!  ...
# 1              fake lesbian career boost fail  ...
#
#   snippet.topLevelComment.snippet.canRate  \
# ...

# %%
df_all = pd.concat(dfs)

# %%
df_all.shape
# Out:
# (1702095, 25)

# %%
total_records
# Out:
# 1702095

# %%
df_all_cleaned = df_all.copy()

# %%
df_all_cleaned.head(2)
# Out:
#    Unnamed: 0                   kind                         etag  \
# 0        72.0  youtube#commentThread  nqao31pRb3m5iwgtvpPFWnuVzvQ
# 1      1300.0  youtube#commentThread  pMAfl478vrmhuA-RYpGVREwJMs0
#
#                      id snippet.videoId snippet.topLevelComment.kind  \
# 0  UgjyORuX3p35VXgCoAEC     DiXRVYRZchs              youtube#comment
# 1  UggV-BvKpFaaaHgCoAEC     VPUUrdgxIa8              youtube#comment
#
#   snippet.topLevelComment.etag snippet.topLevelComment.id  \
# 0  mvtTos5huTqXhtAs-JPzt7mls_A       UgjyORuX3p35VXgCoAEC
# 1  XpsHQJXeW3QznSOnkHg2LFrp-dU       UggV-BvKpFaaaHgCoAEC
#
#   snippet.topLevelComment.snippet.videoId  \
# 0                             DiXRVYRZchs
# 1                             VPUUrdgxIa8
#
#   snippet.topLevelComment.snippet.textDisplay  ...  \
# 0                                  GOOD WORK!  ...
# 1              fake lesbian career boost fail  ...
#
#   snippet.topLevelComment.snippet.canRate  \
# ...

# %%
df_all_cleaned["Unnamed: 0"].value_counts()
# Out:
# 0.0        1343
# 1.0        1268
# 2.0        1228
# 3.0        1202
# 4.0        1178
#            ...
# 49733.0       1
# 49732.0       1
# 49731.0       1
# 49730.0       1
# 13534.0       1
# Name: Unnamed: 0, Length: 120500, dtype: int64

# %%
extraneous_columns = ["Unnamed: 0"]

# %%
extraneous_columns
# Out:
# ['Unnamed: 0']

# %%
df_all_cleaned.kind.value_counts()
# Out:
# youtube#commentThread    1702095
# Name: kind, dtype: int64

# %%
# drop kind columns as all values are youtube#commentThread
extraneous_columns.append("kind")

# %%
df_all_cleaned.etag.value_counts()
# Out:
# bRrUkecsSg-J5fwbSOqQsQRq7Pw    2
# E3d_mzsaN-_m-bl-gm3UMPkvDk0    2
# R-ahKw6nPNbFXc2VmgypGuTjOnY    2
# paClcKwQpao9jse7b563FK81gnE    2
# fVK8DLD4oJfnkPCS9Qx-R_XbWNU    2
#                               ..
# r9ZOCRelMe4EPfL0cTdhOtD3Jg4    1
# n-bAW44UaarsX9Vv2icKkjUizMs    1
# CnsPQWunc81Xgm_uKV3PcjwAr3g    1
# jFESlgXr1GjzN5HR8Z7UmIsyA-U    1
# JCGAM22lKBVTwxBHoFZmkuZMdiE    1
# Name: etag, Length: 1693524, dtype: int64

# %%
df_all_cleaned[df_all_cleaned.etag == "N-uBAViKrNP2QJgiWs6jwLgexA4"]
# Out:
#         Unnamed: 0                   kind                         etag  \
# 701160         NaN  youtube#commentThread  N-uBAViKrNP2QJgiWs6jwLgexA4
# 701210         NaN  youtube#commentThread  N-uBAViKrNP2QJgiWs6jwLgexA4
#
#                                 id snippet.videoId  \
# 701160  Ugx6V-udhIKLeQ-hFcd4AaABAg     hnKYtXxMVU8
# 701210  Ugx6V-udhIKLeQ-hFcd4AaABAg     hnKYtXxMVU8
#
#        snippet.topLevelComment.kind snippet.topLevelComment.etag  \
# 701160              youtube#comment  IYWLrJNHu08AUwV9J71Z0bYDxo4
# 701210              youtube#comment  IYWLrJNHu08AUwV9J71Z0bYDxo4
#
#         snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 701160  Ugx6V-udhIKLeQ-hFcd4AaABAg                             hnKYtXxMVU8
# 701210  Ugx6V-udhIKLeQ-hFcd4AaABAg                             hnKYtXxMVU8
#
#               snippet.topLevelComment.snippet.textDisplay  ...  \
# 701160  At the end of the day $7m will be deducted fro...  ...
# ...

# %%
df_all_cleaned[df_all_cleaned.duplicated()].sort_values("etag")
# Out:
#         Unnamed: 0                   kind                         etag  \
# 589675         NaN  youtube#commentThread  --kaQ5tkjaQJAKnObeK07Asgkx4
# 705418         NaN  youtube#commentThread  -05nDckprPboakFttDa5jyrLlLE
# 43083          NaN  youtube#commentThread  -0M3Lp4vxCC2jVllKMjlndsYjMA
# 533875         NaN  youtube#commentThread  -0mtEILzZRJ357XSfK0J311nLF4
# 705340         NaN  youtube#commentThread  -15JFtFcT14WK7Kw2XawxP6TghU
# ...            ...                    ...                          ...
# 524814         NaN  youtube#commentThread  zw7FK03MfHqgcdBatOB0Ckl9QAo
# 525591         NaN  youtube#commentThread  zxJt5ydWVcJvUdRToaQJU0Y2mVM
# 554392         NaN  youtube#commentThread  zxu4vky430qGewZC2WOM13YRkZA
# 35978          NaN  youtube#commentThread  zyDKoP-EPPtD-LRoFi8Il4fddq0
# 524651         NaN  youtube#commentThread  zyL9clMI6bpiiKilAaPu6MGAVbc
#
#                                 id snippet.videoId  \
# 589675  UgyBQN02jyRh3gAtjqd4AaABAg     yNsBNU9JDUk
# ...

# %%
# drop duplicates
df_all_cleaned.drop_duplicates(inplace=True)

# %%
df_all_cleaned[df_all_cleaned.etag == "N-uBAViKrNP2QJgiWs6jwLgexA4"]
# Out:
#         Unnamed: 0                   kind                         etag  \
# 701160         NaN  youtube#commentThread  N-uBAViKrNP2QJgiWs6jwLgexA4
#
#                                 id snippet.videoId  \
# 701160  Ugx6V-udhIKLeQ-hFcd4AaABAg     hnKYtXxMVU8
#
#        snippet.topLevelComment.kind snippet.topLevelComment.etag  \
# 701160              youtube#comment  IYWLrJNHu08AUwV9J71Z0bYDxo4
#
#         snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 701160  Ugx6V-udhIKLeQ-hFcd4AaABAg                             hnKYtXxMVU8
#
#               snippet.topLevelComment.snippet.textDisplay  ...  \
# 701160  At the end of the day $7m will be deducted fro...  ...
#
#        snippet.topLevelComment.snippet.canRate  \
# 701160                                    True
#
#        snippet.topLevelComment.snippet.viewerRating  \
# 701160                                         none
#
#        snippet.topLevelComment.snippet.likeCount  \
# ...

# %%
df_all_cleaned.etag.value_counts()
# Out:
# ju3oKrUyr-mL7-NtCvR2CLkvwQs    2
# CbqH379sT9e9D3UJUPetZTdnP9A    2
# V6ZQtxfLgjZreVedTXjsQ_3nWuI    2
# QKGhZ6XCENNNuZwZCRQ4ynjBVQ4    2
# KtREilakqUIIR3Xw7co_5_g42k0    2
#                               ..
# eaAo9oSHILFLFx6x1uxB-o-w_v8    1
# ct9-HRnsoOLkr_u4C9D_HNDN4y0    1
# 0qGwu9z9tCgViU7F2kBFXyqUgUQ    1
# cweXyAAKQRQfQqztPfK7QYyZN5k    1
# JCGAM22lKBVTwxBHoFZmkuZMdiE    1
# Name: etag, Length: 1693524, dtype: int64

# %%
df_all_cleaned[df_all_cleaned.etag == "JkNZMf61_kvsDEVzgybrLAQulAU"]
# Out:
#         Unnamed: 0                   kind                         etag  \
# 242815      1053.0  youtube#commentThread  JkNZMf61_kvsDEVzgybrLAQulAU
# 405685         NaN  youtube#commentThread  JkNZMf61_kvsDEVzgybrLAQulAU
#
#                                 id snippet.videoId  \
# 242815  Ugx6fCU0AQvvh2g7b7h4AaABAg     -sKyN0_D_ec
# 405685  Ugx6fCU0AQvvh2g7b7h4AaABAg     -sKyN0_D_ec
#
#        snippet.topLevelComment.kind snippet.topLevelComment.etag  \
# 242815              youtube#comment  3Lf4_tDg8XE3ajwE2BI8GKdsFjo
# 405685              youtube#comment  3Lf4_tDg8XE3ajwE2BI8GKdsFjo
#
#         snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 242815  Ugx6fCU0AQvvh2g7b7h4AaABAg                             -sKyN0_D_ec
# 405685  Ugx6fCU0AQvvh2g7b7h4AaABAg                             -sKyN0_D_ec
#
#          snippet.topLevelComment.snippet.textDisplay  ...  \
# 242815  This is totally how I act when I&#39;m lying  ...
# ...

# %%
df_all_cleaned.drop(columns=extraneous_columns, inplace=True)

# %%
# drop duplicates
df_all_cleaned.drop_duplicates(inplace=True)

# %%
df_all_cleaned[df_all_cleaned.etag == "JkNZMf61_kvsDEVzgybrLAQulAU"]
# Out:
#                                etag                          id  \
# 242815  JkNZMf61_kvsDEVzgybrLAQulAU  Ugx6fCU0AQvvh2g7b7h4AaABAg
#
#        snippet.videoId snippet.topLevelComment.kind  \
# 242815     -sKyN0_D_ec              youtube#comment
#
#        snippet.topLevelComment.etag  snippet.topLevelComment.id  \
# 242815  3Lf4_tDg8XE3ajwE2BI8GKdsFjo  Ugx6fCU0AQvvh2g7b7h4AaABAg
#
#        snippet.topLevelComment.snippet.videoId  \
# 242815                             -sKyN0_D_ec
#
#          snippet.topLevelComment.snippet.textDisplay  \
# 242815  This is totally how I act when I&#39;m lying
#
#        snippet.topLevelComment.snippet.textOriginal  \
# 242815     This is totally how I act when I'm lying
#
#        snippet.topLevelComment.snippet.authorDisplayName  ...  \
# 242815                                    specialshockey  ...
#
#        snippet.topLevelComment.snippet.canRate  \
# 242815                                    True
#
# ...

# %%
df_all_cleaned.etag.value_counts()
# Out:
# nqao31pRb3m5iwgtvpPFWnuVzvQ    1
# ticQyIzAUEPrswVX7M7zvEZJPHI    1
# nkVOjO1ysqkJzz6DG-U09rad3_0    1
# mnydqmxgtdKU8jZw3LIPa4ri8yI    1
# wgT80Ol7v9FOofBe4ziO8RDijvs    1
#                               ..
# 9P0YH2KMWilNSnJpKrZq-WD6PPY    1
# OAM8eKA3muofLlDp2cWMI7GBa8o    1
# t-ZXj29OhZ8qesXVZHZBESPXk_Y    1
# iC_VvbIDpdB0_IYYKma5ZMsWgRw    1
# JCGAM22lKBVTwxBHoFZmkuZMdiE    1
# Name: etag, Length: 1693524, dtype: int64

# %%
df_all_cleaned.etag.nunique()
# Out:
# 1693524

# %%
df_all_cleaned.shape[0]
# Out:
# 1693524

# %% [markdown]
# ##### eTag is clean Now!

# %%
df_all_cleaned.id.value_counts()
# Out:
# UgxGOP1H238HaI_O-8R4AaABAg    2
# UgxGeOxH09N-10Whlah4AaABAg    2
# UgxwlrXgNGVUsvU1yux4AaABAg    2
# UgzXVhEZXbe2vm3XbwZ4AaABAg    2
# Ugz6ZgRlSk_al-txfQ94AaABAg    2
#                              ..
# UgxqSLI5Ki9h65gTcgN4AaABAg    1
# Ugyd9umnQ_B7FDARQJp4AaABAg    1
# UgxXmmbYycYvHxeE2yh4AaABAg    1
# UgySK37jLnsWvHwF_SR4AaABAg    1
# UgyLcrLMaZ4kSRHVafR4AaABAg    1
# Name: id, Length: 1693341, dtype: int64

# %%
df_all_cleaned[df_all_cleaned.id == "UgysWd1sMR-f3kJ9VEt4AaABAg"]
# Out:
#                                etag                          id  \
# 244020  S88fEnKepQoTXzOBaujrC2kFAZc  UgysWd1sMR-f3kJ9VEt4AaABAg
# 539989  9Jx7Bk1E2FmjNan-y1REweChACQ  UgysWd1sMR-f3kJ9VEt4AaABAg
#
#        snippet.videoId snippet.topLevelComment.kind  \
# 244020     -XI7pxiK2L8              youtube#comment
# 539989     -XI7pxiK2L8              youtube#comment
#
#        snippet.topLevelComment.etag  snippet.topLevelComment.id  \
# 244020  tetJPr4osvV18SvRnUAGhTDSWUk  UgysWd1sMR-f3kJ9VEt4AaABAg
# 539989  O5olo5zFakebmb4Gn2Dto9JGhDQ  UgysWd1sMR-f3kJ9VEt4AaABAg
#
#        snippet.topLevelComment.snippet.videoId  \
# 244020                             -XI7pxiK2L8
# 539989                             -XI7pxiK2L8
#
#               snippet.topLevelComment.snippet.textDisplay  \
# 244020  She abused him and then played the victim. Hor...
# 539989  She abused him and then played the victim. Hor...
#
#              snippet.topLevelComment.snippet.textOriginal  \
# ...

# %%
df_all_cleaned["snippet.videoId"].value_counts()
# Out:
# uretrfMA-Io    120500
# wT3RhIJZu4k     85268
# WDkg3h8PCVU     59051
# uVfBxa57Kno     37695
# uC9qU3X1JgM     31239
#                 ...
# tvTUuNTK0Dw         1
# zDTyxgnDfaQ         1
# pPq7wg8FsKQ         1
# WRtRA-sdhmI         1
# gQpr2HIXABs         1
# Name: snippet.videoId, Length: 5314, dtype: int64

# %%
def rename(old, new):
    df_all_cleaned.rename(columns={old: new}, inplace=True)

# %%
rename("snippet.videoId", "video_id")

# %%
df_all_cleaned.head(2)
# Out:
#                           etag                    id     video_id  \
# 0  nqao31pRb3m5iwgtvpPFWnuVzvQ  UgjyORuX3p35VXgCoAEC  DiXRVYRZchs
# 1  pMAfl478vrmhuA-RYpGVREwJMs0  UggV-BvKpFaaaHgCoAEC  VPUUrdgxIa8
#
#   snippet.topLevelComment.kind snippet.topLevelComment.etag  \
# 0              youtube#comment  mvtTos5huTqXhtAs-JPzt7mls_A
# 1              youtube#comment  XpsHQJXeW3QznSOnkHg2LFrp-dU
#
#   snippet.topLevelComment.id snippet.topLevelComment.snippet.videoId  \
# 0       UgjyORuX3p35VXgCoAEC                             DiXRVYRZchs
# 1       UggV-BvKpFaaaHgCoAEC                             VPUUrdgxIa8
#
#   snippet.topLevelComment.snippet.textDisplay  \
# 0                                  GOOD WORK!
# 1              fake lesbian career boost fail
#
#   snippet.topLevelComment.snippet.textOriginal  \
# 0                                   GOOD WORK!
# 1               fake lesbian career boost fail
#
#   snippet.topLevelComment.snippet.authorDisplayName  ...  \
# ...

# %%
df_all_cleaned["snippet.topLevelComment.kind"].value_counts()
# Out:
# youtube#comment    1693524
# Name: snippet.topLevelComment.kind, dtype: int64

# %%
def drop(columns):
     df_all_cleaned.drop(columns=columns, inplace=True)

# %%
drop(["snippet.topLevelComment.kind"])

# %%
df_all_cleaned["snippet.topLevelComment.etag"].value_counts()
# Out:
# SgSwwZg7t8JukuvdZVtLXo169xo    2
# uS0XDvuRzzWuSaw9HAe2vw8Vmtc    2
# Cxo6oDZe24S_9k_GptdBRVcb7pE    2
# BWrcRlwGIqNejEsEdBpizKfprmI    2
# r-_ufao1CXdJoi1KiUl7HmfvuiM    2
#                               ..
# 71cPHCS2Dh4p71v7obvf7_B2BEI    1
# Ar-Nzto9lLutG7SZv-0M5V9my9g    1
# 2rOLkFRvsHNCKXuw4gXdgEsx1JU    1
# 6nN2OxDi92ciYdLsfNgCdRccUVg    1
# CGe_-9G-A_4Wg9M8BClmIX3laiM    1
# Name: snippet.topLevelComment.etag, Length: 1693479, dtype: int64

# %%
df_all_cleaned[df_all_cleaned["snippet.topLevelComment.etag"] == "al6EemMKzjpciCqdATaJTTLI460"]
# Out:
#                                etag                          id     video_id  \
# 185888  K8GCXTSRykqnoZxrUb__Y_5F5og  Ugw1chsxMot00VMLpVp4AaABAg  -mIU5PYWfzs
# 440111  GScW0kSmdaGe4BLs-xhcuvkNJiI  Ugw1chsxMot00VMLpVp4AaABAg  -mIU5PYWfzs
#
#        snippet.topLevelComment.etag  snippet.topLevelComment.id  \
# 185888  al6EemMKzjpciCqdATaJTTLI460  Ugw1chsxMot00VMLpVp4AaABAg
# 440111  al6EemMKzjpciCqdATaJTTLI460  Ugw1chsxMot00VMLpVp4AaABAg
#
#        snippet.topLevelComment.snippet.videoId  \
# 185888                             -mIU5PYWfzs
# 440111                             -mIU5PYWfzs
#
#               snippet.topLevelComment.snippet.textDisplay  \
# 185888  Yo le creo a Amber!!! Muchos de los golpeadore...
# 440111  Yo le creo a Amber!!! Muchos de los golpeadore...
#
#              snippet.topLevelComment.snippet.textOriginal  \
# 185888  Yo le creo a Amber!!! Muchos de los golpeadore...
# 440111  Yo le creo a Amber!!! Muchos de los golpeadore...
#
# ...

# %%
df_all_cleaned.iloc[:,1:][df_all_cleaned.iloc[:,1:].duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, video_id, snippet.topLevelComment.etag, snippet.topLevelComment.id, snippet.topLevelComment.snippet.videoId, snippet.topLevelComment.snippet.textDisplay, snippet.topLevelComment.snippet.textOriginal, snippet.topLevelComment.snippet.authorDisplayName, snippet.topLevelComment.snippet.authorProfileImageUrl, snippet.topLevelComment.snippet.authorChannelUrl, snippet.topLevelComment.snippet.authorChannelId.value, snippet.topLevelComment.snippet.canRate, snippet.topLevelComment.snippet.viewerRating, snippet.topLevelComment.snippet.likeCount, snippet.topLevelComment.snippet.publishedAt, snippet.topLevelComment.snippet.updatedAt, snippet.canReply, snippet.totalReplyCount, snippet.isPublic, replies.comments, snippet.topLevelComment.snippet.moderationStatus]
# Index: []
#
# [0 rows x 21 columns]

# %%
rename("snippet.topLevelComment.etag", "tl_etag")

# %%
rename("snippet.topLevelComment.id", "tl_id")

# %%
df_all_cleaned.shape[0] - sum(df_all_cleaned["video_id"] == df_all_cleaned["snippet.topLevelComment.snippet.videoId"]  )
# Out:
# 0

# %%
drop("snippet.topLevelComment.snippet.videoId")

# %%
df_all_cleaned.head(2)
# Out:
#                           etag                    id     video_id  \
# 0  nqao31pRb3m5iwgtvpPFWnuVzvQ  UgjyORuX3p35VXgCoAEC  DiXRVYRZchs
# 1  pMAfl478vrmhuA-RYpGVREwJMs0  UggV-BvKpFaaaHgCoAEC  VPUUrdgxIa8
#
#                        tl_etag                 tl_id  \
# 0  mvtTos5huTqXhtAs-JPzt7mls_A  UgjyORuX3p35VXgCoAEC
# 1  XpsHQJXeW3QznSOnkHg2LFrp-dU  UggV-BvKpFaaaHgCoAEC
#
#   snippet.topLevelComment.snippet.textDisplay  \
# 0                                  GOOD WORK!
# 1              fake lesbian career boost fail
#
#   snippet.topLevelComment.snippet.textOriginal  \
# 0                                   GOOD WORK!
# 1               fake lesbian career boost fail
#
#   snippet.topLevelComment.snippet.authorDisplayName  \
# 0                                     Shocka Delica
# 1                                      Vincent Lyle
#
#   snippet.topLevelComment.snippet.authorProfileImageUrl  \
# 0  https://yt3.ggpht.com/ytc/AKedOLQc7dx7eTNlZFkv...
# ...

# %%
df_all_cleaned.shape[0] - sum(
    df_all_cleaned["snippet.topLevelComment.snippet.textDisplay"]
    == df_all_cleaned["snippet.topLevelComment.snippet.textOriginal"]
)
# Out:
# 610442

# %%
df_all_cleaned.shape[0] - sum(
    df_all_cleaned["snippet.topLevelComment.snippet.textDisplay"].str.lower()
    == df_all_cleaned["snippet.topLevelComment.snippet.textOriginal"].str.lower()
)
# Out:
# 610442

# %%
df_all_cleaned[~(df_all_cleaned[
    "snippet.topLevelComment.snippet.textDisplay"
].str.lower() == df_all_cleaned[
    "snippet.topLevelComment.snippet.textOriginal"
].str.lower())]
# Out:
#                                etag                          id     video_id  \
# 2       YNBBsYsDbB3qZUItz8bchn2oGMg        Ugio47Mc-eG0dHgCoAEC  VPUUrdgxIa8
# 4       rqe0qUIynNlpNUfMrkkzGMB5qpE        Ughdfu9Z390BW3gCoAEC  VPUUrdgxIa8
# 5       K_8bXK5ZKn3FdBStqN8tT7bGBro        UgjeKNrivRjLVXgCoAEC  VPUUrdgxIa8
# 6       -6ySQeEGKvbjCtjqN2U6fbUcYLQ        Ugiym9FMqTmRwXgCoAEC  VPUUrdgxIa8
# 8       ZHexEhn5Ge3zxeycQEdu9Rt2M_c        UggH7PP7lHbYv3gCoAEC  VPUUrdgxIa8
# ...                             ...                         ...          ...
# 591043  u4ELP0HfZvh5elWhxAiySI_bUUY  Ugyo6PkYk0mz4GbSdCh4AaABAg  6ZhuwlKgdzA
# 591044  CK_YZ1LsV7ph2otnm9Bz-uRvobw  UgyD1vSHMCxWC1QdvNV4AaABAg  6ZhuwlKgdzA
# 591047  YrV538ejcbr1QNkzT_p6UwDOfeU  UgyxnSrUU9TymktC-hR4AaABAg  6ZhuwlKgdzA
# 591048  N_J50COrofYRzSQ5Glr-9zQDFB0  UgxX5qoZvLLdccs5jcV4AaABAg  6ZhuwlKgdzA
# 591052  qdfDncLw3i_Dw67XWyQ23JRCZWc  UgxbhWjZvFAUccljYld4AaABAg  6ZhuwlKgdzA
#
# ...

# %%
drop("snippet.topLevelComment.snippet.textDisplay")

# %%
rename("snippet.topLevelComment.snippet.textOriginal", "tl_text")

# %%
rename("snippet.topLevelComment.snippet.authorDisplayName", "tl_username")

# %%
drop("snippet.topLevelComment.snippet.authorProfileImageUrl")

# %%
drop(["snippet.topLevelComment.snippet.authorChannelUrl"])

# %%
rename("snippet.topLevelComment.snippet.authorChannelId.value", "tl_author_ch_id")

# %%
df_all_cleaned["snippet.topLevelComment.snippet.canRate"].value_counts()
# Out:
# True    1693524
# Name: snippet.topLevelComment.snippet.canRate, dtype: int64

# %%
drop(["snippet.topLevelComment.snippet.canRate"])

# %%
df_all_cleaned["snippet.topLevelComment.snippet.viewerRating"].value_counts()
# Out:
# none    1693524
# Name: snippet.topLevelComment.snippet.viewerRating, dtype: int64

# %%
drop("snippet.topLevelComment.snippet.viewerRating")

# %%
rename("snippet.topLevelComment.snippet.likeCount", "tl_nlikes")

# %%
rename("snippet.topLevelComment.snippet.publishedAt", "tl_p_dtime")

# %%
df_all_cleaned.reset_index(inplace=True)

# %%
df_all_cleaned["tl_p_dtime"][0]
# Out:
# '2013-11-29 05:18:47+00:00'

# %%
df_all_cleaned["tl_p_dtime"] = pd.to_datetime(df_all_cleaned["tl_p_dtime"])

# %%
rename("snippet.topLevelComment.snippet.updatedAt", "tl_u_dtime")

# %%
df_all_cleaned["snippet.canReply"].value_counts()
# Out:
# True     1693523
# False          1
# Name: snippet.canReply, dtype: int64

# %%
drop(["snippet.canReply"])

# %%
rename("snippet.totalReplyCount", "tl_nreplies")

# %%
df_all_cleaned.shape[0] - sum(df_all_cleaned["snippet.isPublic"])
# Out:
# 0

# %%
drop(["snippet.isPublic"])

# %%
df_all_cleaned["snippet.topLevelComment.snippet.moderationStatus"].value_counts()
# Out:
# likelySpam    1664
# Name: snippet.topLevelComment.snippet.moderationStatus, dtype: int64

# %%
rename("snippet.topLevelComment.snippet.moderationStatus", "tl_moderation_status")

# %%
drop("index")

# %%
df_all_cleaned["tl_u_dtime"] = pd.to_datetime(df_all_cleaned["tl_u_dtime"])

# %%
rename('replies.comments', "replies_data")

# %% [markdown]
# <br>

# %% [markdown]
# ### Check for duplicates

# %%
df_all_cleaned.duplicated().sum()
# Out:
# 0

# %%
df_all_cleaned.duplicated(subset=['tl_etag']).sum()
# Out:
# 45

# %%
df_all_cleaned.duplicated(subset=['etag']).sum()
# Out:
# 0

# %%
# Note: Some the repeated ids are for the updated comments --> 
# I think each updated comment has the same original comment id but a different etag
(df_all_cleaned.tl_p_dtime != df_all_cleaned.tl_u_dtime).sum()
# Out:
# 113025

# %%
df_all_cleaned.duplicated(subset=['tl_id']).sum()
# Out:
# 183

# %%
df_duplicated = df_all_cleaned[df_all_cleaned.duplicated(subset=['tl_id'])]
(df_duplicated.tl_p_dtime != df_duplicated.tl_u_dtime).sum()
# Out:
# 29

# %%
df_all_cleaned[df_all_cleaned.duplicated(subset=['tl_id'])].head(60)
# Out:
#                                etag                          id     video_id  \
# 774136  1TNizE-yW2jaOkAGYqiiXnESRZI  UgyPvI8GuAoS4Iy-DVJ4AaABAg  -elJS12UOnI
# 774137  86Mtmwv3UebwBL2q17aMtkj9BBA  Ugyf87krUXokGW4Jv1t4AaABAg  -elJS12UOnI
# 774138  i-z16P9DcVPEqDQo7_DvAPrFroE  UgwyYbL-H1ftJcApQkN4AaABAg  -elJS12UOnI
# 774139  syQSYmilwKKdEoauzw4tMfNcrFc  UgzeKxsaqvWjuFiBvaN4AaABAg  -elJS12UOnI
# 774140  EA5Bg8K7dje2surrsKMR3ihRz3k  UgxozucbP5isuwjbfp94AaABAg  -elJS12UOnI
# 774141  -kKoblr_HImr7v2O6m8WBtYMoto  Ugw0t-IjsAaD2RQ3hXl4AaABAg  -elJS12UOnI
# 774142  ezVi_qj4PFBKjKc1DDqcr4tztPo  Ugz1Fx5Aj05mLLIpUTl4AaABAg  -elJS12UOnI
# 774143  puQLkUnciQ7XqzuFHolHdjEjCIU  UgxMn8C6KQlfDw9pMq54AaABAg  -elJS12UOnI
# 774144  hZUdBHenazuMaeK542KF924mc38  UgwDlX-zx-IE-qO4cah4AaABAg  -elJS12UOnI
# 808443  tFeCvtbcTVeu735otLhV6eubK6w  UgyTfni1p6iNv72zOP14AaABAg  -sKyN0_D_ec
# 808444  AoIgXatm0Gj7xtp6cvNiDP8NWAw  UgzO71hLw-YZjCFcU_F4AaABAg  -sKyN0_D_ec
# ...

# %%
print('\nNote: Some of the repeated ids are for the updated comments --> \
I think each updated comment has the same original comment id but a different etag\n')

df_all_cleaned[df_all_cleaned['tl_id'] == 'Ugz1Fx5Aj05mLLIpUTl4AaABAg']
# Out:
# Note: Some of the repeated ids are for the updated comments --> I think each updated comment has the same original comment id but a different etag
#                                etag                          id     video_id  \
# 405068  g3P5FB7c4HgYP95f1k02ma2alDM  Ugz1Fx5Aj05mLLIpUTl4AaABAg  -elJS12UOnI
# 774142  ezVi_qj4PFBKjKc1DDqcr4tztPo  Ugz1Fx5Aj05mLLIpUTl4AaABAg  -elJS12UOnI
#
#                             tl_etag                       tl_id  \
# 405068  ZWWADoeW-0ZCydppDbiFrxrgMTo  Ugz1Fx5Aj05mLLIpUTl4AaABAg
# 774142  _kVa9zNWc2E6Cvv2hD2T8RJwrP0  Ugz1Fx5Aj05mLLIpUTl4AaABAg
#
#                                                   tl_text tl_username  \
# 405068  Is Sue going to divorce Reed to prove that she...   Wajie Lui
# 774142  Is Sue going to divorce Reed to prove that she...   Wajie Lui
#
#                  tl_author_ch_id  tl_nlikes                tl_p_dtime  \
# 405068  UCR2iRZsUs1UzRIb95kzjONQ        3.0 2020-11-23 04:38:44+00:00
# ...

# %%
df_all_cleaned[df_all_cleaned['tl_id'] == 'Ugz1Fx5Aj05mLLIpUTl4AaABAg'].replies_data[405068]
# Out:
# "[{'kind': 'youtube#comment', 'etag': '9h3713dzuOgs6LKlQi4OnNcDbLo', 'id': 'Ugz1Fx5Aj05mLLIpUTl4AaABAg.9GOOoDpRRcY9GOSFR_k-Jd', 'snippet': {'videoId': '-elJS12UOnI', 'textDisplay': 'They will make her the lead scientist, discovering everything, and Reed is just a dumb grunt...  Oh wait, that was Lost in Space reboot (which otherwise was a decent show).', 'textOriginal': 'They will make her the lead scientist, discovering everything, and Reed is just a dumb grunt...  Oh wait, that was Lost in Space reboot (which otherwise was a decent show).', 'parentId': 'Ugz1Fx5Aj05mLLIpUTl4AaABAg', 'authorDisplayName': 'Paulafan5', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLSu_Wz0xNkh9rBZy_xUes-nZZYb9OTUSzSfqA=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCGbbgn_Fl3JvgTILYCYaCwg', 'authorChannelId': {'value': 'UCGbbgn_Fl3JvgTILYCYaCwg'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 1, 'publishedAt': '2020-11-23T05:08:48Z', 'updatedAt': '202
# ...

# %%
df_all_cleaned[df_all_cleaned['tl_id'] == 'Ugz1Fx5Aj05mLLIpUTl4AaABAg'].replies_data[774142]
# Out:
# "[{'kind': 'youtube#comment', 'etag': '9h3713dzuOgs6LKlQi4OnNcDbLo', 'id': 'Ugz1Fx5Aj05mLLIpUTl4AaABAg.9GOOoDpRRcY9GOSFR_k-Jd', 'snippet': {'videoId': '-elJS12UOnI', 'textDisplay': 'They will make her the lead scientist, discovering everything, and Reed is just a dumb grunt...  Oh wait, that was Lost in Space reboot (which otherwise was a decent show).', 'textOriginal': 'They will make her the lead scientist, discovering everything, and Reed is just a dumb grunt...  Oh wait, that was Lost in Space reboot (which otherwise was a decent show).', 'parentId': 'Ugz1Fx5Aj05mLLIpUTl4AaABAg', 'authorDisplayName': 'Paulafan5', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLSu_Wz0xNkh9rBZy_xUes-nZZYb9OTUSzSfqA=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCGbbgn_Fl3JvgTILYCYaCwg', 'authorChannelId': {'value': 'UCGbbgn_Fl3JvgTILYCYaCwg'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 1, 'publishedAt': '2020-11-23T05:08:48Z', 'updatedAt': '202
# ...

# %%
df_all_cleaned.drop_duplicates(subset=['tl_id'], inplace=True)

# %%
df_all_cleaned.duplicated(subset=['tl_id']).sum()
# Out:
# 0

# %%
df_all_cleaned.duplicated(subset=['tl_etag']).sum()
# Out:
# 0

# %%
print(df_all_cleaned.shape)
df_all_cleaned.head()
# Out:
# (1693341, 14)
#                           etag                    id     video_id  \
# 0  nqao31pRb3m5iwgtvpPFWnuVzvQ  UgjyORuX3p35VXgCoAEC  DiXRVYRZchs
# 1  pMAfl478vrmhuA-RYpGVREwJMs0  UggV-BvKpFaaaHgCoAEC  VPUUrdgxIa8
# 2  YNBBsYsDbB3qZUItz8bchn2oGMg  Ugio47Mc-eG0dHgCoAEC  VPUUrdgxIa8
# 3  yGfNlzwRMYy7AQDwrto3ULpIZ0w  Ugj0tLP9hfrMkXgCoAEC  VPUUrdgxIa8
# 4  rqe0qUIynNlpNUfMrkkzGMB5qpE  Ughdfu9Z390BW3gCoAEC  VPUUrdgxIa8
#
#                        tl_etag                 tl_id  \
# 0  mvtTos5huTqXhtAs-JPzt7mls_A  UgjyORuX3p35VXgCoAEC
# 1  XpsHQJXeW3QznSOnkHg2LFrp-dU  UggV-BvKpFaaaHgCoAEC
# 2  VRefhV-4H8413hvRHP5-zKWyNuQ  Ugio47Mc-eG0dHgCoAEC
# 3  auBUVEx3Zm2I35CN0iASII7-3V4  Ugj0tLP9hfrMkXgCoAEC
# 4  6NhfYEJJ6zK5ieP-jD9dB25SC-k  Ughdfu9Z390BW3gCoAEC
#
#                                              tl_text  \
# 0                                         GOOD WORK!
# 1                     fake lesbian career boost fail
# 2  So during movie shoots, some actresses use dil...
# ...

# %% [markdown]
# <br>

# %%
df_all_cleaned[df_all_cleaned['tl_nreplies'] == 3].head(3)
# Out:
#                             etag                          id     video_id  \
# 3    yGfNlzwRMYy7AQDwrto3ULpIZ0w        Ugj0tLP9hfrMkXgCoAEC  VPUUrdgxIa8
# 220  3Dn7zCJNjZZ1oLO1Zzeun4rrGq4        UgiHZioFxgbSWHgCoAEC  R8KblG1S0_A
# 315  lt2D5jd9SbxSZm4P961IV7wIFtc  Ugy5lAkBp-rN_-M8Ag94AaABAg  VKsZGKlcJB4
#
#                          tl_etag                       tl_id  \
# 3    auBUVEx3Zm2I35CN0iASII7-3V4        Ugj0tLP9hfrMkXgCoAEC
# 220  NM7dobwPKtUFvRHyhnPeby-sXCE        UgiHZioFxgbSWHgCoAEC
# 315  AVDZjrBZTBc8iDGFe-ddGGGlAgA  Ugy5lAkBp-rN_-M8Ag94AaABAg
#
#                                                tl_text      tl_username  \
# 3    God, Liam Hemsworth looks insanely a lot like ...    Chris Andreev
# 220                          Johnny depp Is Good Actor  Joseph Parianto
# 315  Not very good interview. Why are you mostly as...       putkimies3
#
#               tl_author_ch_id  tl_nlikes                tl_p_dtime  \
# ...

# %%
# Replies Count 
sum(df_all_cleaned.tl_nreplies)
# Out:
# 935868.0

# %%
df_all_cleaned.tl_nreplies.describe()
# Out:
# count    1.693341e+06
# mean     5.526755e-01
# std      4.769337e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      5.000000e+02
# Name: tl_nreplies, dtype: float64

# %%
df_all_cleaned[df_all_cleaned['tl_nreplies'] == 500].head(3)
# Out:
#                                etag                          id     video_id  \
# 624377  AfTEF0Wom9b0fKdbFsrva8RsVHM  Ugx5aRkdh0i92HAA0UN4AaABAg  gcIYyGrQFTk
#
#                             tl_etag                       tl_id  \
# 624377  0NXV3SZrvLvWwC3MdgEAOecRCf8  Ugx5aRkdh0i92HAA0UN4AaABAg
#
#                                                   tl_text tl_username  \
# 624377  Say it with me kids: The Abuser Isn't Determin...   May Jones
#
#                  tl_author_ch_id  tl_nlikes                tl_p_dtime  \
# 624377  UCnqga9sBpmHkvdCqLVmxo0g    27866.0 2020-11-12 16:27:03+00:00
#
#                       tl_u_dtime  tl_nreplies  \
# 624377 2020-11-12 16:27:10+00:00        500.0
#
#                                              replies_data tl_moderation_status
# 624377  [{'kind': 'youtube#comment', 'etag': '8qJ6ENVD...                  NaN

# %%
print('\n Note that this is only a sample of the replies (Not All replies are included)')
reply = df_all_cleaned.replies_data[624377]
reply_list = ast.literal_eval(reply)
pd.json_normalize(reply_list)
# Out:
#  Note that this is only a sample of the replies (Not All replies are included)
#               kind                         etag  \
# 0  youtube#comment  8qJ6ENVDcsOu2NdWyvlPkKV0Ixs
# 1  youtube#comment  hpBHeq_HfWHUn7-PNRPwWVKfSjo
# 2  youtube#comment  bmYIINHLtPHZZlO5_SYr27n4Efg
# 3  youtube#comment  hRdsOuL9ufpWtjyZ_uXvu-MQlYg
# 4  youtube#comment  qfsE3Ku9gr_4AvbzyFRW0o4hPLY
#
#                                                   id snippet.videoId  \
# 0  Ugx5aRkdh0i92HAA0UN4AaABAg.9FyL7N65Czq9UCg18_uXW-     gcIYyGrQFTk
# 1  Ugx5aRkdh0i92HAA0UN4AaABAg.9FyL7N65Czq9U7k9fAb7_p     gcIYyGrQFTk
# 2  Ugx5aRkdh0i92HAA0UN4AaABAg.9FyL7N65Czq9U6ovcolN7r     gcIYyGrQFTk
# 3  Ugx5aRkdh0i92HAA0UN4AaABAg.9FyL7N65Czq9U6nAgIdwNM     gcIYyGrQFTk
# 4  Ugx5aRkdh0i92HAA0UN4AaABAg.9FyL7N65Czq9U6kzeMeRwI     gcIYyGrQFTk
#
#                                  snippet.textDisplay  \
# 0  The Abuser Isn&#39;t Determined By The Gender....
# 1      THE ABUSER ISN&#39;T DETERMINED BY THE GENDER
# ...

# %% [markdown]
# <br>

# %% [markdown]
# ### Extracting The replies.comments Data

# %%
reply = df_all_cleaned['replies_data'][3]
reply
# Out:
# '[{\'kind\': \'youtube#comment\', \'etag\': \'QYX3QPM1LtUu0wlmdpHRIwW3iJM\', \'id\': \'Ugj0tLP9hfrMkXgCoAEC.7-H0Z7-8JBq70dHFqqoBXt\', \'snippet\': {\'videoId\': \'VPUUrdgxIa8\', \'textDisplay\': \'It was sarcasm because of course they look alike they&#39;re brothers lol\', \'textOriginal\': "It was sarcasm because of course they look alike they\'re brothers lol", \'parentId\': \'Ugj0tLP9hfrMkXgCoAEC\', \'authorDisplayName\': \'powderhounds77\', \'authorProfileImageUrl\': \'https://yt3.ggpht.com/ytc/AKedOLR5A6MpSzzCUJUeBI_Q-F1vYQi4uoM-ubSpu_o6=s48-c-k-c0x00ffffff-no-rj\', \'authorChannelUrl\': \'http://www.youtube.com/channel/UCRJUkXBVIc9CYtYyUE0lppg\', \'authorChannelId\': {\'value\': \'UCRJUkXBVIc9CYtYyUE0lppg\'}, \'canRate\': True, \'viewerRating\': \'none\', \'likeCount\': 0, \'publishedAt\': \'2014-01-10T18:42:32Z\', \'updatedAt\': \'2014-01-10T18:42:32Z\'}}, {\'kind\': \'youtube#comment\', \'etag\': \'x3erx04uEQOW2OK1o1iIupyypB8\', \'id\': \'Ugj0tLP9hfrMkXgCoAEC.7-H0Z7-8JBq70ZUU
# ...

# %%
reply_list = ast.literal_eval(reply)
reply_list
# Out:
# [{'kind': 'youtube#comment',
#   'etag': 'QYX3QPM1LtUu0wlmdpHRIwW3iJM',
#   'id': 'Ugj0tLP9hfrMkXgCoAEC.7-H0Z7-8JBq70dHFqqoBXt',
#   'snippet': {'videoId': 'VPUUrdgxIa8',
#    'textDisplay': 'It was sarcasm because of course they look alike they&#39;re brothers lol',
#    'textOriginal': "It was sarcasm because of course they look alike they're brothers lol",
#    'parentId': 'Ugj0tLP9hfrMkXgCoAEC',
#    'authorDisplayName': 'powderhounds77',
#    'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLR5A6MpSzzCUJUeBI_Q-F1vYQi4uoM-ubSpu_o6=s48-c-k-c0x00ffffff-no-rj',
#    'authorChannelUrl': 'http://www.youtube.com/channel/UCRJUkXBVIc9CYtYyUE0lppg',
#    'authorChannelId': {'value': 'UCRJUkXBVIc9CYtYyUE0lppg'},
#    'canRate': True,
#    'viewerRating': 'none',
#    'likeCount': 0,
#    'publishedAt': '2014-01-10T18:42:32Z',
#    'updatedAt': '2014-01-10T18:42:32Z'}},
#  {'kind': 'youtube#comment',
#   'etag': 'x3erx04uEQOW2OK1o1iIupyypB8',
# ...

# %%
pd.DataFrame(reply_list)
# Out:
#               kind                         etag  \
# 0  youtube#comment  QYX3QPM1LtUu0wlmdpHRIwW3iJM
# 1  youtube#comment  x3erx04uEQOW2OK1o1iIupyypB8
# 2  youtube#comment  DM3exrIzVmoGeaj41nV8h_8dqVY
#
#                                             id  \
# 0  Ugj0tLP9hfrMkXgCoAEC.7-H0Z7-8JBq70dHFqqoBXt
# 1  Ugj0tLP9hfrMkXgCoAEC.7-H0Z7-8JBq70ZUUoOljer
# 2  Ugj0tLP9hfrMkXgCoAEC.7-H0Z7-8JBq70ZQCkAybUK
#
#                                              snippet
# 0  {'videoId': 'VPUUrdgxIa8', 'textDisplay': 'It ...
# 1  {'videoId': 'VPUUrdgxIa8', 'textDisplay': 'Yea...
# 2  {'videoId': 'VPUUrdgxIa8', 'textDisplay': 'It&...

# %%
pd.DataFrame(reply_list[0]['snippet'])
# Out:
#            videoId                                        textDisplay  \
# value  VPUUrdgxIa8  It was sarcasm because of course they look ali...
#
#                                             textOriginal  \
# value  It was sarcasm because of course they look ali...
#
#                    parentId authorDisplayName  \
# value  Ugj0tLP9hfrMkXgCoAEC    powderhounds77
#
#                                    authorProfileImageUrl  \
# value  https://yt3.ggpht.com/ytc/AKedOLR5A6MpSzzCUJUe...
#
#                                         authorChannelUrl  \
# value  http://www.youtube.com/channel/UCRJUkXBVIc9CYt...
#
#                 authorChannelId  canRate viewerRating  likeCount  \
# value  UCRJUkXBVIc9CYtYyUE0lppg     True         none          0
#
#                 publishedAt             updatedAt
# value  2014-01-10T18:42:32Z  2014-01-10T18:42:32Z

# %%
pd.json_normalize(reply_list)
# Out:
#               kind                         etag  \
# 0  youtube#comment  QYX3QPM1LtUu0wlmdpHRIwW3iJM
# 1  youtube#comment  x3erx04uEQOW2OK1o1iIupyypB8
# 2  youtube#comment  DM3exrIzVmoGeaj41nV8h_8dqVY
#
#                                             id snippet.videoId  \
# 0  Ugj0tLP9hfrMkXgCoAEC.7-H0Z7-8JBq70dHFqqoBXt     VPUUrdgxIa8
# 1  Ugj0tLP9hfrMkXgCoAEC.7-H0Z7-8JBq70ZUUoOljer     VPUUrdgxIa8
# 2  Ugj0tLP9hfrMkXgCoAEC.7-H0Z7-8JBq70ZQCkAybUK     VPUUrdgxIa8
#
#                                  snippet.textDisplay  \
# 0  It was sarcasm because of course they look ali...
# 1                Yeah, I kinda said that myself... ?
# 2   It&#39;s like they&#39;re brothers or something.
#
#                                 snippet.textOriginal      snippet.parentId  \
# 0  It was sarcasm because of course they look ali...  Ugj0tLP9hfrMkXgCoAEC
# 1                Yeah, I kinda said that myself... ?  Ugj0tLP9hfrMkXgCoAEC
# ...

# %% [markdown]
# https://stackoverflow.com/questions/22551403/python-pandas-filtering-out-nan-from-a-data-selection-of-a-column-of-strings

# %%
df_filterd = df_all_cleaned[df_all_cleaned['replies_data'].notnull()]

replies_list = [] 
for reply in df_filterd['replies_data']:
    reply_list = ast.literal_eval(reply)
    replies_list += reply_list # Sine we cannot append more than one element at a time

# %%
pd.DataFrame(replies_list).head(1)
# Out:
#               kind                         etag  \
# 0  youtube#comment  7hl0Pwkr9M3i7-MAOI4-ISAjBTA
#
#                                             id  \
# 0  UgjyORuX3p35VXgCoAEC.7-H0Z7-OrF471JBSkR_8pb
#
#                                              snippet
# 0  {'videoId': 'DiXRVYRZchs', 'textDisplay': 'Tha...

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.json_normalize.html

# %%
df = pd.json_normalize(replies_list)
print(df.shape)
df.head()
# Out:
# (483585, 17)
#               kind                         etag  \
# 0  youtube#comment  7hl0Pwkr9M3i7-MAOI4-ISAjBTA
# 1  youtube#comment  C5b9LhGqdlxBiATj6pM4NODGF7k
# 2  youtube#comment  mBq3oA8toHGe4wLvnaWItKfifos
# 3  youtube#comment  zRUflcWHRNUOyLEg7Y6ht6QwtfA
# 4  youtube#comment  Z5CnEsGopchsxSkWtq1QVWExJxY
#
#                                             id snippet.videoId  \
# 0  UgjyORuX3p35VXgCoAEC.7-H0Z7-OrF471JBSkR_8pb     DiXRVYRZchs
# 1  Ugio47Mc-eG0dHgCoAEC.7-H0Z7-L9qF8u0ixRncDiz     VPUUrdgxIa8
# 2  Ugio47Mc-eG0dHgCoAEC.7-H0Z7-L9qF8tR-ysLcjRH     VPUUrdgxIa8
# 3  Ugio47Mc-eG0dHgCoAEC.7-H0Z7-L9qF8tQnNtIY-q9     VPUUrdgxIa8
# 4  Ugio47Mc-eG0dHgCoAEC.7-H0Z7-L9qF8rArSU6o1N1     VPUUrdgxIa8
#
#                                  snippet.textDisplay  \
# 0                                         Thanks! :)
# 1                                      Soup Bro lmao
# 2  Charles Hubbard <br>Wtf<br>I found another wei...
# 3                                       ًںک‚ًںک‚ًںک‚
# ...

# %%
sum(df['snippet.publishedAt'] == df['snippet.updatedAt'])
# Out:
# 463298

# %%
sum(df['snippet.textDisplay'] == df['snippet.textOriginal'])
# Out:
# 319913

# %%
df.kind.nunique()
# Out:
# 1

# %%
df['snippet.moderationStatus'].value_counts()
# Out:
# likelySpam    581
# Name: snippet.moderationStatus, dtype: int64

# %%
df['snippet.viewerRating'].value_counts()
# Out:
# none    483585
# Name: snippet.viewerRating, dtype: int64

# %%
df['snippet.canRate'].value_counts()
# Out:
# True    483585
# Name: snippet.canRate, dtype: int64

# %%
drop_list = ['kind', 'snippet.viewerRating', 'snippet.canRate']
df.drop(columns=drop_list, inplace=True)

# %%
df_all_cleaned.rename(columns={'etag': 'etag0'}, inplace=True)

# %%
print(df_all_cleaned.shape)
df_all_cleaned.head(1)
# Out:
# (1693341, 14)
#                          etag0                    id     video_id  \
# 0  nqao31pRb3m5iwgtvpPFWnuVzvQ  UgjyORuX3p35VXgCoAEC  DiXRVYRZchs
#
#                        tl_etag                 tl_id     tl_text  \
# 0  mvtTos5huTqXhtAs-JPzt7mls_A  UgjyORuX3p35VXgCoAEC  GOOD WORK!
#
#      tl_username           tl_author_ch_id  tl_nlikes  \
# 0  Shocka Delica  UC6cJzw3ChENHVREKzpx1e3Q        9.0
#
#                  tl_p_dtime                tl_u_dtime  tl_nreplies  \
# 0 2013-11-29 05:18:47+00:00 2013-11-29 05:18:47+00:00          1.0
#
#                                         replies_data tl_moderation_status
# 0  [{'kind': 'youtube#comment', 'etag': '7hl0Pwkr...                  NaN

# %%
sum(df_all_cleaned['id'] == df_all_cleaned['tl_id'])
# Out:
# 1693341

# %%
df_all_cleaned.drop(columns='id', inplace=True)

# %%
print(df.shape)
df.head(1)
# Out:
# (483585, 14)
#                           etag                                           id  \
# 0  7hl0Pwkr9M3i7-MAOI4-ISAjBTA  UgjyORuX3p35VXgCoAEC.7-H0Z7-OrF471JBSkR_8pb
#
#   snippet.videoId snippet.textDisplay snippet.textOriginal  \
# 0     DiXRVYRZchs          Thanks! :)           Thanks! :)
#
#        snippet.parentId snippet.authorDisplayName  \
# 0  UgjyORuX3p35VXgCoAEC               neideavelar
#
#                        snippet.authorProfileImageUrl  \
# 0  https://yt3.ggpht.com/ytc/AKedOLRT_061ha8lniFw...
#
#                             snippet.authorChannelUrl  \
# 0  http://www.youtube.com/channel/UCLV1Jw4IZVGbOR...
#
#   snippet.authorChannelId.value  snippet.likeCount   snippet.publishedAt  \
# 0      UCLV1Jw4IZVGbOR-z9ZgKp-Q                  2  2014-01-18T18:35:18Z
#
#       snippet.updatedAt snippet.moderationStatus
# 0  2014-01-18T18:35:18Z                      NaN

# %%
df.rename(columns={'snippet.videoId': 'video_id', 
                   'snippet.parentId': 'tl_id', 
                   'snippet.textDisplay': 'text_display', 
                   'snippet.textOriginal': 'text_original', 
                   'snippet.authorDisplayName': 'username', 
                   'snippet.authorProfileImageUrl': 'author_profile_image', 
                   'snippet.authorChannelUrl': 'author_ch_url', 
                   'snippet.authorChannelId.value': 'author_ch_id', 
                   'snippet.likeCount': 'nlikes', 
                   'snippet.publishedAt': 'p_dtime', 
                   'snippet.updatedAt': 'u_dtime', 
                   'snippet.moderationStatus': 'moderation_status'}
          , inplace=True)

# %%
print(df.shape)
df.head(1)
# Out:
# (483585, 14)
#                           etag                                           id  \
# 0  7hl0Pwkr9M3i7-MAOI4-ISAjBTA  UgjyORuX3p35VXgCoAEC.7-H0Z7-OrF471JBSkR_8pb
#
#       video_id text_display text_original                 tl_id     username  \
# 0  DiXRVYRZchs   Thanks! :)    Thanks! :)  UgjyORuX3p35VXgCoAEC  neideavelar
#
#                                 author_profile_image  \
# 0  https://yt3.ggpht.com/ytc/AKedOLRT_061ha8lniFw...
#
#                                        author_ch_url  \
# 0  http://www.youtube.com/channel/UCLV1Jw4IZVGbOR...
#
#                author_ch_id  nlikes               p_dtime  \
# 0  UCLV1Jw4IZVGbOR-z9ZgKp-Q       2  2014-01-18T18:35:18Z
#
#                 u_dtime moderation_status
# 0  2014-01-18T18:35:18Z               NaN

# %%
df.id.duplicated().sum()
# Out:
# 0

# %%
df.etag.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <br>

# %% [markdown]
# # Creating a DailyCreation DataFrame
# <font color='red'>Wrong Method</font>

# %%
df.p_dtime = pd.to_datetime(df.p_dtime)
df.p_dtime.dt.date.min(), df.p_dtime.dt.date.max()
# Out:
# (datetime.date(2013, 11, 15), datetime.date(2021, 12, 8))

# %%
df_all_cleaned.tl_p_dtime.dt.date.min(), df_all_cleaned.tl_p_dtime.dt.date.max()
# Out:
# (datetime.date(2008, 3, 26), datetime.date(2021, 12, 8))

# %% [markdown]
# <font color='red'>The nreplies dates are different from the parent comment date</font>
# <font color='red'>Note: Not All replies are included (only a sample of the replies)</font>

# %%
# Create a data frame with the number of comments in each date
df_ncomments = df_all_cleaned.groupby([df_all_cleaned.tl_p_dtime.dt.date]).agg({'tl_text':'count', 'tl_nreplies': 'sum'}).reset_index(
).rename(columns={'tl_p_dtime':'date', 'tl_text':'n_tlcomments', 'tl_nreplies':'nreplies'}).sort_values('n_tlcomments', ascending=False)

df_ncomments["date"] = pd.to_datetime(df_ncomments["date"])
df_ncomments.head(1)
# Out:
#            date  n_tlcomments  nreplies
# 3220 2018-07-22         21112    9623.0

# %%
df_ncomments['year'] = df_ncomments['date'].dt.year
df_ncomments['month'] = df_ncomments['date'].dt.strftime('%b')
df_ncomments['dayofmonth'] = df_ncomments['date'].dt.day

df_ncomments.head(1)
# Out:
#            date  n_tlcomments  nreplies  year month  dayofmonth
# 3220 2018-07-22         21112    9623.0  2018   Jul          22

# %%
df_ncomments['ncomments'] = df_ncomments['n_tlcomments'] + df_ncomments['nreplies']
df_ncomments.head(1)
# Out:
#            date  n_tlcomments  nreplies  year month  dayofmonth  ncomments
# 3220 2018-07-22         21112    9623.0  2018   Jul          22    30735.0

# %%
df_ncomments.drop(columns=['n_tlcomments', 'nreplies'], inplace=True)
df_ncomments.head(1)
# Out:
#            date  year month  dayofmonth  ncomments
# 3220 2018-07-22  2018   Jul          22    30735.0

# %%
df_ncomments.ncomments = df_ncomments.ncomments.astype('int')

# %%
df_ncomments.sort_values('ncomments', ascending=False, inplace=True)
df_ncomments.head(15)
# Out:
#            date  year month  dayofmonth  ncomments
# 3220 2018-07-22  2018   Jul          22      30735
# 3219 2018-07-21  2018   Jul          21      23650
# 4105 2020-12-23  2020   Dec          23      22476
# 3782 2020-02-04  2020   Feb           4      19874
# 4109 2020-12-27  2020   Dec          27      19214
# 4104 2020-12-22  2020   Dec          22      17676
# 4106 2020-12-24  2020   Dec          24      17614
# 3785 2020-02-07  2020   Feb           7      16813
# 3781 2020-02-03  2020   Feb           3      15449
# 4108 2020-12-26  2020   Dec          26      14753
# 3783 2020-02-05  2020   Feb           5      13254
# 3786 2020-02-08  2020   Feb           8      12842
# 4110 2020-12-28  2020   Dec          28      12785
# 3295 2018-10-05  2018   Oct           5      12507
# 3951 2020-07-22  2020   Jul          22      12283

# %%
# df_ncomments.to_csv("../comments_cleaned/daily_creations.csv", index=False)

# %% [markdown]
# <br>

# %% [markdown]
# ### Merging both the TopLevel and Replies DataFrames

# %%
# df.tl_id.duplicated().sum()

# %%
# df_merged = pd.merge(df_all_cleaned, df, on=['video_id', 'tl_id'], how='outer')

# %%
# print(df_merged.shape)
# df_merged.head(10)

# %%
# # Drop columns from the merged dataframe
# df_merged.drop(columns=['replies_data', 'text_display'], inplace=True)

# %%
# df_merged.rename(columns={'text_original': 'text'}, inplace=True)

# %%
# df_merged.etag0.duplicated().sum()

# %%
# df_merged.tl_etag.duplicated().sum()

# %%
# df_merged.tl_id.duplicated().sum()

# %% [markdown]
# <br>

# %% [markdown]
# # Preparing For Restructring the data

# %% [markdown]
# ### df_all_cleaned

# %%
print(df_all_cleaned.shape)
df_all_cleaned.head(1)
# Out:
# (1693341, 13)
#                          etag0     video_id                      tl_etag  \
# 0  nqao31pRb3m5iwgtvpPFWnuVzvQ  DiXRVYRZchs  mvtTos5huTqXhtAs-JPzt7mls_A
#
#                   tl_id     tl_text    tl_username           tl_author_ch_id  \
# 0  UgjyORuX3p35VXgCoAEC  GOOD WORK!  Shocka Delica  UC6cJzw3ChENHVREKzpx1e3Q
#
#    tl_nlikes                tl_p_dtime                tl_u_dtime  tl_nreplies  \
# 0        9.0 2013-11-29 05:18:47+00:00 2013-11-29 05:18:47+00:00          1.0
#
#                                         replies_data tl_moderation_status
# 0  [{'kind': 'youtube#comment', 'etag': '7hl0Pwkr...                  NaN

# %%
print(df.shape)
df.head(1)
# Out:
# (483585, 14)
#                           etag                                           id  \
# 0  7hl0Pwkr9M3i7-MAOI4-ISAjBTA  UgjyORuX3p35VXgCoAEC.7-H0Z7-OrF471JBSkR_8pb
#
#       video_id text_display text_original                 tl_id     username  \
# 0  DiXRVYRZchs   Thanks! :)    Thanks! :)  UgjyORuX3p35VXgCoAEC  neideavelar
#
#                                 author_profile_image  \
# 0  https://yt3.ggpht.com/ytc/AKedOLRT_061ha8lniFw...
#
#                                        author_ch_url  \
# 0  http://www.youtube.com/channel/UCLV1Jw4IZVGbOR...
#
#                author_ch_id  nlikes                   p_dtime  \
# 0  UCLV1Jw4IZVGbOR-z9ZgKp-Q       2 2014-01-18 18:35:18+00:00
#
#                 u_dtime moderation_status
# 0  2014-01-18T18:35:18Z               NaN

# %%
# Add a Column to Classify after concatenating
df_all_cleaned['comment_reply'] = 'comment'

# %%
df_all_cleaned['parent_id'] = 'none'

# %%
df_all_cleaned['author_ch_url'] = 'none'

# %%
df_all_cleaned['author_profile_image'] = 'none'

# %%
# Drop
df_all_cleaned.drop(columns=['etag0', 'replies_data'], inplace=True)

# %%
# Rename
df_all_cleaned.rename(columns={'tl_etag': 'comment_etag', 
                   'tl_id': 'comment_id', 
                   'tl_text': 'text', 
                   'tl_username': 'username', 
                   'tl_author_ch_id': 'author_ch_id', 
                   'tl_nlikes': 'nlikes', 
                   'tl_p_dtime': 'p_dtime', 
                   'tl_u_dtime': 'u_dtime', 
                   'tl_nreplies': 'nreplies', 
                   'tl_moderation_status': 'moderation_status'}
          , inplace=True)

# %%
print(df_all_cleaned.shape)
df_all_cleaned.head(1)
# Out:
# (1693341, 15)
#       video_id                 comment_etag            comment_id        text  \
# 0  DiXRVYRZchs  mvtTos5huTqXhtAs-JPzt7mls_A  UgjyORuX3p35VXgCoAEC  GOOD WORK!
#
#         username              author_ch_id  nlikes                   p_dtime  \
# 0  Shocka Delica  UC6cJzw3ChENHVREKzpx1e3Q     9.0 2013-11-29 05:18:47+00:00
#
#                     u_dtime  nreplies moderation_status comment_reply  \
# 0 2013-11-29 05:18:47+00:00       1.0               NaN       comment
#
#   parent_id author_ch_url author_profile_image
# 0      none          none                 none

# %% [markdown]
# <br>

# %% [markdown]
# ### df

# %%
print(df.shape)
df.head(1)
# Out:
# (483585, 14)
#                           etag                                           id  \
# 0  7hl0Pwkr9M3i7-MAOI4-ISAjBTA  UgjyORuX3p35VXgCoAEC.7-H0Z7-OrF471JBSkR_8pb
#
#       video_id text_display text_original                 tl_id     username  \
# 0  DiXRVYRZchs   Thanks! :)    Thanks! :)  UgjyORuX3p35VXgCoAEC  neideavelar
#
#                                 author_profile_image  \
# 0  https://yt3.ggpht.com/ytc/AKedOLRT_061ha8lniFw...
#
#                                        author_ch_url  \
# 0  http://www.youtube.com/channel/UCLV1Jw4IZVGbOR...
#
#                author_ch_id  nlikes                   p_dtime  \
# 0  UCLV1Jw4IZVGbOR-z9ZgKp-Q       2 2014-01-18 18:35:18+00:00
#
#                 u_dtime moderation_status
# 0  2014-01-18T18:35:18Z               NaN

# %%
# Add a Column to Classify after concatenating
df['comment_reply'] = 'reply'

# %%
df['nreplies'] = 0

# %%
# Drop
df.drop(columns=['text_display'], inplace=True)

# %%
# Rename
df.rename(columns={'etag': 'comment_etag', 
                   'tl_id': 'parent_id', 
                   'id': 'comment_id', 
                   'text_original': 'text'}
          , inplace=True)

# %%
print(df.shape)
df.head(1)
# Out:
# (483585, 15)
#                   comment_etag                                   comment_id  \
# 0  7hl0Pwkr9M3i7-MAOI4-ISAjBTA  UgjyORuX3p35VXgCoAEC.7-H0Z7-OrF471JBSkR_8pb
#
#       video_id        text             parent_id     username  \
# 0  DiXRVYRZchs  Thanks! :)  UgjyORuX3p35VXgCoAEC  neideavelar
#
#                                 author_profile_image  \
# 0  https://yt3.ggpht.com/ytc/AKedOLRT_061ha8lniFw...
#
#                                        author_ch_url  \
# 0  http://www.youtube.com/channel/UCLV1Jw4IZVGbOR...
#
#                author_ch_id  nlikes                   p_dtime  \
# 0  UCLV1Jw4IZVGbOR-z9ZgKp-Q       2 2014-01-18 18:35:18+00:00
#
#                 u_dtime moderation_status comment_reply  nreplies
# 0  2014-01-18T18:35:18Z               NaN         reply         0

# %%
# get the symmetric difference between the two dataframes columns
set(df.columns) ^ set(df_all_cleaned.columns)
# Out:
# set()

# %% [markdown]
# <br>

# %% [markdown]
# # Merging the Structured DataFrames

# %% [markdown]
# https://stackoverflow.com/questions/30840128/how-to-stack-data-frames-on-top-of-each-other-in-pandas

# %%
df_final = pd.concat( (df_all_cleaned, df), ignore_index = True)

# %%
print(df_final.shape)
df_final.head()
# Out:
# (2176926, 15)
#       video_id                 comment_etag            comment_id  \
# 0  DiXRVYRZchs  mvtTos5huTqXhtAs-JPzt7mls_A  UgjyORuX3p35VXgCoAEC
# 1  VPUUrdgxIa8  XpsHQJXeW3QznSOnkHg2LFrp-dU  UggV-BvKpFaaaHgCoAEC
# 2  VPUUrdgxIa8  VRefhV-4H8413hvRHP5-zKWyNuQ  Ugio47Mc-eG0dHgCoAEC
# 3  VPUUrdgxIa8  auBUVEx3Zm2I35CN0iASII7-3V4  Ugj0tLP9hfrMkXgCoAEC
# 4  VPUUrdgxIa8  6NhfYEJJ6zK5ieP-jD9dB25SC-k  Ughdfu9Z390BW3gCoAEC
#
#                                                 text  \
# 0                                         GOOD WORK!
# 1                     fake lesbian career boost fail
# 2  So during movie shoots, some actresses use dil...
# 3  God, Liam Hemsworth looks insanely a lot like ...
# 4                     I'd watch her day and night...
#
#                                            username              author_ch_id  \
# 0                                     Shocka Delica  UC6cJzw3ChENHVREKzpx1e3Q
# ...

# %% [markdown]
# <br>

# %% [markdown]
# # Some Text Adjustments for the Analysis

# %%
df_final.text = df_final.text.str.lower()

# %%
helpers.isnull(df_final)
# Out:
# The number of NaNs in video_id: 0
# The number of NaNs in comment_etag: 0
# The number of NaNs in comment_id: 0
# The number of NaNs in text: 383
# The number of NaNs in username: 46
# The number of NaNs in author_ch_id: 23
# The number of NaNs in nlikes: 0
# The number of NaNs in p_dtime: 0
# The number of NaNs in u_dtime: 0
# The number of NaNs in nreplies: 0
# The number of NaNs in moderation_status: 2174681
# The number of NaNs in comment_reply: 0
# The number of NaNs in parent_id: 0
# The number of NaNs in author_ch_url: 0
# The number of NaNs in author_profile_image: 0

# %%
df_final.dropna(subset=['text'], inplace=True)

# %%
#ValueError: Cannot mask with non-boolean array containing NA / NaN value --> Solution: Dropna
df_victim = df_final[df_final.text.str.contains('victim')]
print(df_victim.text.nunique())
# Out:
# 51653

# %%
df_victim.text.value_counts().head(60)
# Out:
# â€œthey wonâ€™t believe you, because you are a manâ€‌\n\nshe is not a victim.                                                                       13523
# "they won't believe you, because you are a man"\n\nshe is not a victim.                                                                              3903
# â€œthey wonâ€™t believe you, because you are a manâ€‌\n\nshe is not a victim                                                                         2620
# "they won't believe you, because you are a man"\n\nshe is not a victim                                                                               2031
# â€œthey wonâ€™t believe you, because youâ€™re a man.â€‌\n\nshe is not a victim.                                                                      1261
# â€œthey wonâ€™t believe you, because youâ€™re a manâ€‌\n\nshe is not a victim.                                                                       1249
# ...

# %% [markdown]
# https://stackoverflow.com/questions/1342000/how-to-make-the-python-interpreter-correctly-handle-non-ascii-characters-in-stri

# %%
df_final.text = df_final.text.str.replace('â€œ', '"')
df_final.text = df_final.text.str.replace('â€™', "'")
df_final.text = df_final.text.str.replace('â€‌ ', '"')
df_final.text = df_final.text.str.replace('â€‌', '"')
df_final.text = df_final.text.str.replace('â€ک', "")
df_final.text = df_final.text.str.replace('â€', '"')
df_final.text = df_final.text.str.replace("man'", "man")

df_final.text = df_final.text.str.replace('\n\n\n', ' ')
df_final.text = df_final.text.str.replace('\n\n', " ")
df_final.text = df_final.text.str.replace('\n', ' ')


df_final.text = df_final.text.str.replace('آ«آ ', '')
df_final.text = df_final.text.str.replace('آ«آ', '')
df_final.text = df_final.text.str.replace('آ آ»', '')
df_final.text = df_final.text.str.replace('آ آ» ', '')
df_final.text = df_final.text.str.replace('آ« ', '')
df_final.text = df_final.text.str.replace('آ«', '')
df_final.text = df_final.text.str.replace('آ» ', '')
df_final.text = df_final.text.str.replace('آ»', '')
df_final.text = df_final.text.str.replace('آ ', '')


df_final.text = df_final.text.str.replace("you're", 'you are')
df_final.text = df_final.text.str.replace("she's", 'she is')

df_final.text = df_final.text.str.replace('"', '')
df_final.text = df_final.text.str.replace('.', '')
df_final.text = df_final.text.str.replace(',', '')
df_final.text = df_final.text.str.replace('-', ' ')


df_final.text = df_final.text.str.replace('\t', ' ')
df_final.text = df_final.text.str.replace('   ', ' ')
df_final.text = df_final.text.str.replace('  ', ' ')

# %%
df_victim = df_final[df_final.text.str.contains('victim')]
print(df_victim.text.nunique())
# Out:
# 44396

# %%
df_victim.text.value_counts().head(20)
# Out:
# they won't believe you because you are a man she is not a victim                                                                     43368
# they won't believe you because you are a man amber heard she is not a victim                                                          1598
# they won't believe you because you are a man she is not the victim                                                                    1343
# she is not a victim                                                                                                                   1110
# they wont believe you because you are a man she is not a victim                                                                       1020
# they won't believe you because your a man she is not a victim                                                                         1012
# they won't believe you because you are a man she is not a victim!                                                                      929
# ...

# %% [markdown]
# <br>

# %% [markdown]
# ### Extracting A year Column To filter later on

# %%
df_final["p_dtime"] = pd.to_datetime(df_final["p_dtime"], utc=True)

# %%
df_final['year'] = df_final['p_dtime'].dt.year
df_final['date'] = df_final['p_dtime'].dt.date
df_final['month'] = df_final['p_dtime'].dt.strftime('%b')
df_final['dayofmonth'] = df_final['p_dtime'].dt.day
df_final['hour'] = df_final['p_dtime'].dt.hour

# %% [markdown]
# | column  | Description  | New Name  |
# |:--|:--|:--|
# | etag | comment entity tag **UNIQUE** | - |
# | id | comment id | - |
# | snippet.videoId | The ID of the video that the comments refer to, if any. If this property is not present or does not have a value, then the thread applies to the channel and not to a specific video. | video_id |
# | snippet.topLevelComment.etag | etag of the top level ccomment | tl_etag |
# | snippet.topLevelComment.id | ID of the top level ccomment | tl_id |
# | snippet.topLevelComment.snippet.textOriginal  | The original, raw text of the comment as it was initially posted or last updated. The original text is only returned if it is accessible to the authenticated user, which is only guaranteed if the user is the comment's author. | tl_text |
# |snippet.topLevelComment.snippet.authorDisplayName | The display name of the user who posted the comment. | tl_username |
# |snippet.topLevelComment.snippet.authorChannelId.value | The ID of the comment author's YouTube channel, if available.| tl_author_ch_id |
# | snippet.topLevelComment.snippet.likeCoun | Top Level comment Likes | tl_nlikes |
# | snippet.topLevelComment.snippet.publishedAt | The date and time when the comment was orignally published. The value is specified in ISO 8601 format. | tl_p_dtime |
# | snippet.topLevelComment.snippet.updatedAt | The date and time when the comment was last updated. The value is specified in ISO 8601 format. | tl_u_dtime |
# | snippet.totalReplyCount | The total number of replies that have been submitted in response to the top-level comment.| tl_nreplies |
# | snippet.topLevelComment.snippet.moderationStatus | The comment's moderation status. This property is only returned if the API request was authorized by the owner of the channel or the video on which the requested comments were made. In addition, note that this property is not set if the API request used the id filter parameter. Valid values for this property are: - heldForReview - likelySpam - published- rejected | tl_moderation_status

# %%
df_final_20 = df_final.query(" year==2020 ")

# %%
print(df_final_20.shape)
df_final_20.head()
# Out:
# (893315, 20)
#            video_id                 comment_etag                  comment_id  \
# 404326  _vfN675NT0k  fC6bDu-6NHX0XmKcEMENIfgYHMo  Ugzoo_58ATK2o_8MKMt4AaABAg
# 404327  _vfN675NT0k  Cl3dKAEbAoKWrXFcbGDnyJ4qQAI  UgyuTwDuRsYa0ssEhNR4AaABAg
# 404328  _vfN675NT0k  -sG5mxd2EQbga53tqMQOlLRQi_E  Ugx0XmX6Otg44OD0Lml4AaABAg
# 404329  _vfN675NT0k  1IE38kEDaZP_ppPPxZaDXBGCnQI  UgxhMYQzYTQcDr1pvVt4AaABAg
# 404330  Ugtl8D8XACE  gFGCOpTMGQgtGP3cSnwenc8Mhk0  UgylSXpEo0-tlX9Gxul4AaABAg
#
#                                                      text        username  \
# 404326  johnny depp is a wife beater eff him why would...   MegaPodTastic
# 404327  i've followed this a little throughout the pas...     vascoe myer
# 404328  https://wwwyoutubecom/watch?v=xrexnry04ik&t=7s...             Maj
# 404329  the whole situation with amber heard and johnn...     Kevin Jones
# 404330  aww she is my friend the granny i love how she...  Susan Franklin
#
# ...

# %%
helpers.isnull(df_final)
# Out:
# The number of NaNs in video_id: 0
# The number of NaNs in comment_etag: 0
# The number of NaNs in comment_id: 0
# The number of NaNs in text: 0
# The number of NaNs in username: 46
# The number of NaNs in author_ch_id: 23
# The number of NaNs in nlikes: 0
# The number of NaNs in p_dtime: 0
# The number of NaNs in u_dtime: 0
# The number of NaNs in nreplies: 0
# The number of NaNs in moderation_status: 2174298
# The number of NaNs in comment_reply: 0
# The number of NaNs in parent_id: 0
# The number of NaNs in author_ch_url: 0
# The number of NaNs in author_profile_image: 0
# The number of NaNs in year: 0
# The number of NaNs in date: 0
# The number of NaNs in month: 0
# The number of NaNs in dayofmonth: 0
# The number of NaNs in hour: 0

# %%
df_final.iloc[7402]
# Out:
# video_id                                rB7ONnfIjaI
# comment_etag            rViPkBz37Jl_xRxDWO0SoDljf5c
# comment_id               UgwfyozrDLNCu9H-r6J4AaABAg
# text
# username                         K I N G Khadishmal
# author_ch_id               UChL36y28dDE_jlrjEdGKZRw
# nlikes                                          0.0
# p_dtime                   2013-01-14 00:53:38+00:00
# u_dtime                   2013-01-14 00:53:38+00:00
# nreplies                                        0.0
# moderation_status                               NaN
# comment_reply                               comment
# parent_id                                      none
# author_ch_url                                  none
# author_profile_image                           none
# year                                           2013
# date                                     2013-01-14
# month                                           Jan
# dayofmonth                                       14
# ...

# %%
# df_final.to_csv("comments_cleaned/comments_cleaned.csv", index=False)

# %%
# df_final.to_csv("comments_cleaned/comments_cleaned_zipped.csv", compression="zip", index=False)

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# https://stackoverflow.com/questions/33998740/error-in-reading-a-csv-file-in-pandascparsererror-error-tokenizing-data-c-err

# %%
df_comments = pd.read_csv("comments_cleaned/comments_cleaned_zipped.csv", compression="zip", 
                          low_memory=False, lineterminator='\n')
print(df_comments.shape)
df_comments.head()
# Out:
# (2176543, 20)
#       video_id                 comment_etag            comment_id  \
# 0  DiXRVYRZchs  mvtTos5huTqXhtAs-JPzt7mls_A  UgjyORuX3p35VXgCoAEC
# 1  VPUUrdgxIa8  XpsHQJXeW3QznSOnkHg2LFrp-dU  UggV-BvKpFaaaHgCoAEC
# 2  VPUUrdgxIa8  VRefhV-4H8413hvRHP5-zKWyNuQ  Ugio47Mc-eG0dHgCoAEC
# 3  VPUUrdgxIa8  auBUVEx3Zm2I35CN0iASII7-3V4  Ugj0tLP9hfrMkXgCoAEC
# 4  VPUUrdgxIa8  6NhfYEJJ6zK5ieP-jD9dB25SC-k  Ughdfu9Z390BW3gCoAEC
#
#                                                 text  \
# 0                                         good work!
# 1                     fake lesbian career boost fail
# 2  so during movie shoots some actresses use dild...
# 3  god liam hemsworth looks insanely a lot like h...
# 4                        i'd watch her day and night
#
#                                            username              author_ch_id  \
# 0                                     Shocka Delica  UC6cJzw3ChENHVREKzpx1e3Q
# ...

# %%
helpers.isnull(df_comments)
# Out:
# The number of NaNs in video_id: 0
# The number of NaNs in comment_etag: 0
# The number of NaNs in comment_id: 0
# The number of NaNs in text: 532
# The number of NaNs in username: 49
# The number of NaNs in author_ch_id: 23
# The number of NaNs in nlikes: 0
# The number of NaNs in p_dtime: 0
# The number of NaNs in u_dtime: 0
# The number of NaNs in nreplies: 0
# The number of NaNs in moderation_status: 2174298
# The number of NaNs in comment_reply: 0
# The number of NaNs in parent_id: 0
# The number of NaNs in author_ch_url: 0
# The number of NaNs in author_profile_image: 0
# The number of NaNs in year: 0
# The number of NaNs in date: 0
# The number of NaNs in month: 0
# The number of NaNs in dayofmonth: 0
# The number of NaNs in hour: 0

# %%
df_comments[df_comments['text'].isnull()].head(1)
# Out:
#          video_id                 comment_etag                  comment_id  \
# 7402  rB7ONnfIjaI  rViPkBz37Jl_xRxDWO0SoDljf5c  UgwfyozrDLNCu9H-r6J4AaABAg
#
#      text            username              author_ch_id  nlikes  \
# 7402  NaN  K I N G Khadishmal  UChL36y28dDE_jlrjEdGKZRw     0.0
#
#                         p_dtime                    u_dtime  nreplies  \
# 7402  2013-01-14 00:53:38+00:00  2013-01-14 00:53:38+00:00       0.0
#
#      moderation_status comment_reply parent_id author_ch_url  \
# 7402               NaN       comment      none          none
#
#      author_profile_image  year        date month  dayofmonth  hour
# 7402                 none  2013  2013-01-14   Jan          14     0

# %%
df_comments.iloc[7402]
# Out:
# video_id                                rB7ONnfIjaI
# comment_etag            rViPkBz37Jl_xRxDWO0SoDljf5c
# comment_id               UgwfyozrDLNCu9H-r6J4AaABAg
# text                                            NaN
# username                         K I N G Khadishmal
# author_ch_id               UChL36y28dDE_jlrjEdGKZRw
# nlikes                                          0.0
# p_dtime                   2013-01-14 00:53:38+00:00
# u_dtime                   2013-01-14 00:53:38+00:00
# nreplies                                        0.0
# moderation_status                               NaN
# comment_reply                               comment
# parent_id                                      none
# author_ch_url                                  none
# author_profile_image                           none
# year                                           2013
# date                                     2013-01-14
# month                                           Jan
# ...

# %%
df_comments.text.fillna('isnan', inplace=True)

# %% [markdown]
# <br>

# %% [markdown]
# # Language Detection & Translation of Threat comments

# %%
# Threat Comments In Other Languages
threat_others = {'pagar', 'matar', 'muerte', 'morir', 'infierno', 'muere', 'muerta', 'inferno', 'morire', 'prigione'}
df_threat_others = df_comments[df_comments.text.str.contains('|'.join(threat_others))]

# %%
# Add A Language-Detection Column
import icu
from polyglot.detect import Detector
from polyglot.detect.base import logger as polyglot_logger
polyglot_logger.setLevel("ERROR")

def det(x):
    try:
        poly_obj = Detector(x, quiet=True)
        lang = icu.Locale.getDisplayName(poly_obj.language.locale)
    except:
        lang = 'Other'
    return lang

# %%
# poly_obj = Detector('hola', quiet=True)
# lang = icu.Locale.getDisplayName(poly_obj.language.locale)
# lang

# %%
import time
t0 = time.time()
df_threat_others['language'] = df_threat_others.text.apply(lambda x: det(x)) 
time.time() - t0
# Out:
# 0.11813807487487793

# %%
# Add A Translation Column
import mtranslate

def translate(x):
    try:
        translated = mtranslate.translate(x,"en","auto")
    except:
        translated = 'not_translated'
    return translated

# %%
t0 = time.time()
df_threat_others['translated'] = df_threat_others.text.apply(lambda x: translate(x))
(time.time() - t0) /60
# Out:
# 921.2648787498474

# %%
df_threat_others.to_csv("comments_cleaned/other_languages.csv", index=False)

# %%
# df_threat_others = pd.read_csv("comments_cleaned/other_languages.csv", low_memory=False, lineterminator='\n')
# df_threat_others.head(1)

# %%
df_threat_others.language.value_counts()
# Out:
# Spanish              1801
# English               244
# Portuguese            157
# Italian                26
# Indonesian             11
# Uzbek                   6
# Arabic                  5
# Danish                  4
# Norwegian Nynorsk       3
# German                  2
# Rundi                   2
# Haitian Creole          2
# Morisyen                2
# Romansh                 1
# Dutch                   1
# Oromo                   1
# Catalan                 1
# Western Frisian         1
# Turkmen                 1
# Guarani                 1
# Hausa                   1
# Kinyarwanda             1
# Waray                   1
# Afrikaans               1
# Estonian                1
# Turkish                 1
# Sango                   1
# Name: language, dtype: int64

# %%
df_threat_others[df_threat_others.translated == 'not_translated']
# Out:
#         video_id                 comment_etag                  comment_id  \
# 699  mLZlCpzw46E  EfB1Y3oam40w3faLba6D76yoaOM  UgzbBClLoii0i0gLP0Z4AaABAg
#
#                                                   text   username  \
# 699  oi oًںڈ›ًں™…چâ™€ï¸ڈًں™…چâ™€ï¸ڈًں™…چâ™€ï¸ڈًں™…چ...  Sofia Val
#
#                  author_ch_id  nlikes                    p_dtime  \
# 699  UCF7d_hTcNZg0ezxg40WsUNg     0.0  2020-08-28 18:09:41+00:00
#
#                        u_dtime  nreplies  ... parent_id author_ch_url  \
# 699  2020-08-28 18:09:41+00:00       0.0  ...      none          none
#
#     author_profile_image  year        date  month dayofmonth hour    language  \
# 699                 none  2020  2020-08-28    Aug         28   18  Portuguese
#
#          translated
# 699  not_translated
#
# [1 rows x 22 columns]

# %% [markdown]
# <br>

# %% [markdown]
# # Creating a DailyCreation DataFrame

# %%
df.p_dtime = pd.to_datetime(df.p_dtime)
df.p_dtime.dt.date.min(), df.p_dtime.dt.date.max()
# Out:
# (datetime.date(2013, 11, 15), datetime.date(2021, 12, 8))

# %%
df_all_cleaned.p_dtime.dt.date.min(), df_all_cleaned.p_dtime.dt.date.max()
# Out:
# (datetime.date(2008, 3, 26), datetime.date(2021, 12, 8))

# %%
df_final.p_dtime.dt.date.min(), df_final.p_dtime.dt.date.max()
# Out:
# (datetime.date(2008, 3, 26), datetime.date(2021, 12, 8))

# %% [markdown]
# <font color='red'>The nreplies dates are different from the parent comment date</font>
# <font color='red'>Note: Not All replies are included (only a sample of the replies)</font>

# %%
# Create a data frame with the number of comments in each date
df_creations = df_final.groupby(['date', 'year', 'month', 'dayofmonth', 'hour']).agg(
    {'text':'count', 'nreplies': 'sum', 'nlikes': 'sum'}).reset_index().rename(
    columns={'text':'ncomments'}).sort_values('ncomments', ascending=False)

df_creations["date"] = pd.to_datetime(df_creations["date"])
df_creations.head(1)
# Out:
#             date  year month  dayofmonth  hour  ncomments  nreplies   nlikes
# 46973 2018-07-21  2018   Jul          21    20       6998    2994.0  38909.0

# %%
df_creations.ncomments = df_creations.ncomments.astype('int')
df_creations.nreplies = df_creations.nreplies.astype('int')
df_creations.nlikes = df_creations.nlikes.astype('int')

# %%
df_creations.sort_values('ncomments', ascending=False, inplace=True)
df_creations.head(15)
# Out:
#             date  year month  dayofmonth  hour  ncomments  nreplies  nlikes
# 46973 2018-07-21  2018   Jul          21    20       6998      2994   38909
# 46972 2018-07-21  2018   Jul          21    19       4877      2181   30351
# 66763 2020-10-24  2020   Oct          24     8       4404      1121   24569
# 46974 2018-07-21  2018   Jul          21    21       3153      1087   16811
# 49871 2018-11-19  2018   Nov          19    17       2673      1775   21042
# 48791 2018-10-05  2018   Oct           5    16       2527       986   14083
# 48792 2018-10-05  2018   Oct           5    17       1988       738   10297
# 67303 2020-11-15  2020   Nov          15    20       1951      1828   65089
# 46975 2018-07-21  2018   Jul          21    22       1932       994   14051
# 46978 2018-07-22  2018   Jul          22     1       1790       801    6471
# 49872 2018-11-19  2018   Nov          19    18       1760       965    8984
# ...

# %%
df_creations.date.min(), df_creations.date.max()
# Out:
# (Timestamp('2008-03-26 00:00:00'), Timestamp('2021-12-08 00:00:00'))

# %%
# df_creations.to_csv("comments_cleaned/daily_creations.csv", index=False)
