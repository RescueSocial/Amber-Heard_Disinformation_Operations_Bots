# %%
from helpers import (
    URLS,
    get_urls,
    urls_df,
    one_link_df,
    one_link_urls,
    one_link_urls_with_count,
    df_more_than_link, more_than_one_link_with_count
)
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # YouTube Data URLs

# %%
yt_filter_path =  "../urls"

# %% [markdown]
# ## Table of Contents
# <ul>
# <li><a href="#Comments"><b>Comments</b></a></li>
# <li><a href="#Videos">Videos</a></li>
# </ul>

# %% [markdown]
# <a id='Comments'></a>
#
# ## Comments
#
#
# ><ul>
#  <li><a href="#4">4 Months</a></li>
#  <li><a href="#12">December</a></li>
#
#  </ul>

# %%
yt_comments_path = "../../youtube/[CSV] Combined by year [6893 videos](videos, comments and channels) (final 25Dec21)/comments filter by year(based on comment year Not main video)/"

# %%
df_comments21 = pd.read_csv(yt_comments_path + "comments_data_2021.csv")

# %%
df_comments20 = pd.read_csv(yt_comments_path + "comments_data_2020.csv")

# %%
df_comments21.head(1)
# Out:
#    Unnamed: 0                   kind                         etag  \
# 0         0.0  youtube#commentThread  HWRVF49a2ObDyvftwuVdJKNhyD8
#
#                            id snippet.videoId snippet.topLevelComment.kind  \
# 0  UgyWYCQS7evmvfmJS-N4AaABAg     14SUI93R_k8              youtube#comment
#
#   snippet.topLevelComment.etag  snippet.topLevelComment.id  \
# 0  Iovx9zUM7fOXxqPCM-3iKToEaKw  UgyWYCQS7evmvfmJS-N4AaABAg
#
#   snippet.topLevelComment.snippet.videoId  \
# 0                             14SUI93R_k8
#
#   snippet.topLevelComment.snippet.textDisplay  ...  \
# 0             Are you going to see Aquaman 2?  ...
#
#   snippet.topLevelComment.snippet.canRate  \
# 0                                    True
#
#   snippet.topLevelComment.snippet.viewerRating  \
# 0                                         none
#
#   snippet.topLevelComment.snippet.likeCount  \
# 0                                      94.0
#
#   snippet.topLevelComment.snippet.publishedAt  \
# ...

# %%
df_comments20.head(1)
# Out:
#    Unnamed: 0                   kind                         etag  \
# 0         0.0  youtube#commentThread  WravDADRj2DkMDO6UpH_bj7ZLRk
#
#                            id snippet.videoId snippet.topLevelComment.kind  \
# 0  Ugzoo_58ATK2o_8MKMt4AaABAg     _vfN675NT0k              youtube#comment
#
#   snippet.topLevelComment.etag  snippet.topLevelComment.id  \
# 0  fC6bDu-6NHX0XmKcEMENIfgYHMo  Ugzoo_58ATK2o_8MKMt4AaABAg
#
#   snippet.topLevelComment.snippet.videoId  \
# 0                             _vfN675NT0k
#
#          snippet.topLevelComment.snippet.textDisplay  ...  \
# 0  Johnny Depp is a wife beater . Eff him. Why wo...  ...
#
#   snippet.topLevelComment.snippet.canRate  \
# 0                                    True
#
#   snippet.topLevelComment.snippet.viewerRating  \
# 0                                         none
#
#   snippet.topLevelComment.snippet.likeCount  \
# 0                                       0.0
#
#   snippet.topLevelComment.snippet.publishedAt  \
# ...

# %%
df_comments20.columns
# Out:
# Index(['Unnamed: 0', 'kind', 'etag', 'id', 'snippet.videoId',
#        'snippet.topLevelComment.kind', 'snippet.topLevelComment.etag',
#        'snippet.topLevelComment.id', 'snippet.topLevelComment.snippet.videoId',
#        'snippet.topLevelComment.snippet.textDisplay',
#        'snippet.topLevelComment.snippet.textOriginal',
#        'snippet.topLevelComment.snippet.authorDisplayName',
#        'snippet.topLevelComment.snippet.authorProfileImageUrl',
#        'snippet.topLevelComment.snippet.authorChannelUrl',
#        'snippet.topLevelComment.snippet.authorChannelId.value',
#        'snippet.topLevelComment.snippet.canRate',
#        'snippet.topLevelComment.snippet.viewerRating',
#        'snippet.topLevelComment.snippet.likeCount',
#        'snippet.topLevelComment.snippet.publishedAt',
#        'snippet.topLevelComment.snippet.updatedAt', 'snippet.canReply',
#        'snippet.totalReplyCount', 'snippet.isPublic', 'replies.comments',
# ...

# %%
cu20 = URLS(df_comments20)
cu21 = URLS(df_comments21)

# %%
# 4 months data
df_comments_4_months = cu21.months_filteration(
    datetime_column="snippet.topLevelComment.snippet.publishedAt", start="2021-01-01 00:00:00", end="2021-05-01 00:00:00"
)

# dec data
df_comments_dec = cu20.months_filteration(
    datetime_column="snippet.topLevelComment.snippet.publishedAt", start="2020-12-01 00:00:00", end="2021-01-01 00:00:00"
)

# %%
df_comments_4_months[
    "snippet.topLevelComment.snippet.publishedAt"
].min(), df_comments_4_months["snippet.topLevelComment.snippet.publishedAt"].max()
# Out:
# ('2021-01-01 00:00:19+00:00', '2021-04-30 23:59:24+00:00')

# %%
df_comments_dec[
    "snippet.topLevelComment.snippet.publishedAt"
].min(), df_comments_dec["snippet.topLevelComment.snippet.publishedAt"].max()
# Out:
# ('2020-12-01 00:00:20+00:00', '2020-12-31 23:59:44+00:00')

# %% [markdown]
# ### 4 Months
# <a id='4'></a>
#
#
# ><ul>
#  <li><a href="#one4">One Link</a></li>
#  <li><a href="#more4">More Than One Link</a></li>
#
#  </ul>

# %%
df_comments_4_months["urls"] = df_comments_4_months[
    "snippet.topLevelComment.snippet.textOriginal"
].apply(lambda x: get_urls(x))

# %%
df_comments_4_months
# Out:
#         Unnamed: 0                   kind                         etag  \
# 0              0.0  youtube#commentThread  HWRVF49a2ObDyvftwuVdJKNhyD8
# 1              6.0  youtube#commentThread  PzEL8-eTSA65LFvuXi9JDnqCm9A
# 2              7.0  youtube#commentThread  iY1kwxwrMKv5M0EhkdBxPIwKBEw
# 3              8.0  youtube#commentThread  stqlyr38DAI_LIPh9ZfXPtdsLxE
# 4              9.0  youtube#commentThread  1UNP418JrN4kCCyNixCHxgz5eJI
# ...            ...                    ...                          ...
# 268140         NaN  youtube#commentThread  lwYucAibDuerAgUZLQ3_tHi-oK8
# 268141         NaN  youtube#commentThread  ZpKTz8xaDjoJpQFqOkqvN9mnUBQ
# 268142         NaN  youtube#commentThread  qdfDncLw3i_Dw67XWyQ23JRCZWc
# 268143         NaN  youtube#commentThread  mfSy9fPvkc9MbdLbonIsa0urDRk
# 268144         NaN  youtube#commentThread  JCGAM22lKBVTwxBHoFZmkuZMdiE
#
#                                 id snippet.videoId  \
# 0       UgyWYCQS7evmvfmJS-N4AaABAg     14SUI93R_k8
# ...

# %%
df_comments_4_months["n_urls"] = df_comments_4_months.urls.apply(lambda x: len(x))

# %%
df_comments_4_months_urls = urls_df(df_comments_4_months)

# %%
df_comments_4_months_urls.head()
# Out:
#    Unnamed: 0                   kind                         etag  \
# 0       246.0  youtube#commentThread  qdoqrw3cE0__VDupjhlNX__WB70
# 1       581.0  youtube#commentThread  Lqjl09_00lntIayGERX0cPOU94k
# 2       169.0  youtube#commentThread  aoGsiOtUNxW85JWtxXmG_2zbhTI
# 3         0.0  youtube#commentThread  aM5LTyEXF6r5xHVcBFxzTTFyXcE
# 4      2623.0  youtube#commentThread  X81a7y5hUylWKcpNO4gPhFOK-Xg
#
#                            id snippet.videoId snippet.topLevelComment.kind  \
# 0  UgzMkTI7AmxUZWcWj5B4AaABAg     QBCEXSVjBrM              youtube#comment
# 1  Ugy0Iuxm_HBo0KIgMRZ4AaABAg     QBCEXSVjBrM              youtube#comment
# 2  Ugwg0TKo9-znyW9wAnh4AaABAg     H-Gdg4c4v80              youtube#comment
# 3  Ugyk6JTDgmgpWGatnep4AaABAg     nk62Q2ve1Ck              youtube#comment
# 4  UgxFPbafYqFOemIJ8zZ4AaABAg     tybOcw3gQzc              youtube#comment
#
#   snippet.topLevelComment.etag  snippet.topLevelComment.id  \
# ...

# %%
df_comments_4_months_urls.shape[0]
# Out:
# 1065

# %%
df_comments_4_months.shape[0]
# Out:
# 268145

# %%
# # save data
# df_comments_4_months_urls.to_csv(
#     yt_filter_path + "df_comments_4_months_urls.csv", index=False
# )

# %%
df_comments_4_months_urls["urls"]
# Out:
# 0                          [https://youtu.be/mw3IiyXZJds]
# 1       [https://www.change.org/p/dc-entertainment-rem...
# 2       [https://youtube.com/channel/UCEFfB8EGTj3EL6ut...
# 3       [https://bit.ly/3txAgy1, https://youtu.be/YVPy...
# 4       [https://www.google.com/amp/s/www.throwbacks.c...
#                               ...
# 1060    [https://t.co/yWkf2d2APp?amp=1, https://referr...
# 1061    [https://www.change.org/p/dc-entertainment-rem...
# 1062    [https://www.youtube.com/watch?v=FdM479D1s4o&t...
# 1063    [https://youtube.com/playlist?list=PL0zUoY_CXU...
# 1064        [https://www.youtube.com/watch?v=VjQ2t_yNHQs]
# Name: urls, Length: 1065, dtype: object

# %%
df_comments_4_months_urls.n_urls.value_counts()
# Out:
# 1     1003
# 2       24
# 7       20
# 3        5
# 5        5
# 8        4
# 10       1
# 20       1
# 4        1
# 6        1
# Name: n_urls, dtype: int64

# %% [markdown]
# <a id='one4'></a>
# #### One Link
#
# ><ul>
#  <li><a href="#one4">One Link</a></li>
#  <li><a href="#more4">More Than One Link</a></li>
#
#  </ul>

# %%
df_comments_4_months_urls_1_link = one_link_df(df_comments_4_months_urls)

# %%
df_comments_4_months_urls_1_link.head(1)
# Out:
#    Unnamed: 0                   kind                         etag  \
# 0       246.0  youtube#commentThread  qdoqrw3cE0__VDupjhlNX__WB70
#
#                            id snippet.videoId snippet.topLevelComment.kind  \
# 0  UgzMkTI7AmxUZWcWj5B4AaABAg     QBCEXSVjBrM              youtube#comment
#
#   snippet.topLevelComment.etag  snippet.topLevelComment.id  \
# 0  A_cfWgYhmBQ9QUCuztUvQz2_KWg  UgzMkTI7AmxUZWcWj5B4AaABAg
#
#   snippet.topLevelComment.snippet.videoId  \
# 0                             QBCEXSVjBrM
#
#          snippet.topLevelComment.snippet.textDisplay  ...  \
# 0  <a href="https://youtu.be/mw3IiyXZJds">https:/...  ...
#
#   snippet.topLevelComment.snippet.publishedAt  \
# 0                   2021-02-03 16:34:18+00:00
#
#   snippet.topLevelComment.snippet.updatedAt snippet.canReply  \
# 0                      2021-02-03T16:34:18Z             True
#
#   snippet.totalReplyCount snippet.isPublic  replies.comments  \
# ...

# %%
df_comments_4_months_urls_1_link.columns
# Out:
# Index(['Unnamed: 0', 'kind', 'etag', 'id', 'snippet.videoId',
#        'snippet.topLevelComment.kind', 'snippet.topLevelComment.etag',
#        'snippet.topLevelComment.id', 'snippet.topLevelComment.snippet.videoId',
#        'snippet.topLevelComment.snippet.textDisplay',
#        'snippet.topLevelComment.snippet.textOriginal',
#        'snippet.topLevelComment.snippet.authorDisplayName',
#        'snippet.topLevelComment.snippet.authorProfileImageUrl',
#        'snippet.topLevelComment.snippet.authorChannelUrl',
#        'snippet.topLevelComment.snippet.authorChannelId.value',
#        'snippet.topLevelComment.snippet.canRate',
#        'snippet.topLevelComment.snippet.viewerRating',
#        'snippet.topLevelComment.snippet.likeCount',
#        'snippet.topLevelComment.snippet.publishedAt',
#        'snippet.topLevelComment.snippet.updatedAt', 'snippet.canReply',
#        'snippet.totalReplyCount', 'snippet.isPublic', 'replies.comments',
# ...

# %%
list_comments_4_months_urls_1_link = one_link_urls(df_comments_4_months_urls_1_link)

# %%
list_comments_4_months_urls_1_link
# Out:
# array([list(['https://youtu.be/mw3IiyXZJds']),
#        list(['https://www.change.org/p/dc-entertainment-remove-amber-heard-from-aquaman-2']),
#        list(['https://youtube.com/channel/UCEFfB8EGTj3EL6utWXTN0CQ']),
#        ...,
#        list(['https://www.change.org/p/dc-entertainment-remove-amber-heard-from-aquaman-2/w']),
#        list(['https://youtube.com/playlist?list=PL0zUoY_CXUlQ6TVrNAI8YDd3CVdYAiKBx']),
#        list(['https://www.youtube.com/watch?v=VjQ2t_yNHQs'])],
#       dtype=object)

# %%
df_comments_4_months_urls_1_link.head(1)
# Out:
#    Unnamed: 0                   kind                         etag  \
# 0       246.0  youtube#commentThread  qdoqrw3cE0__VDupjhlNX__WB70
#
#                            id snippet.videoId snippet.topLevelComment.kind  \
# 0  UgzMkTI7AmxUZWcWj5B4AaABAg     QBCEXSVjBrM              youtube#comment
#
#   snippet.topLevelComment.etag  snippet.topLevelComment.id  \
# 0  A_cfWgYhmBQ9QUCuztUvQz2_KWg  UgzMkTI7AmxUZWcWj5B4AaABAg
#
#   snippet.topLevelComment.snippet.videoId  \
# 0                             QBCEXSVjBrM
#
#          snippet.topLevelComment.snippet.textDisplay  ...  \
# 0  <a href="https://youtu.be/mw3IiyXZJds">https:/...  ...
#
#   snippet.topLevelComment.snippet.publishedAt  \
# 0                   2021-02-03 16:34:18+00:00
#
#   snippet.topLevelComment.snippet.updatedAt snippet.canReply  \
# 0                      2021-02-03T16:34:18Z             True
#
#   snippet.totalReplyCount snippet.isPublic  replies.comments  \
# ...

# %%
def one_link_urls_with_count_(one_link_df, user_column, url_column="url"):
    users = []
    u = []
    for url in one_link_df[url_column].values:
        nn = tuple(set(one_link_df[one_link_df.url == url][user_column]))
        n = one_link_df[one_link_df.url == url][user_column].nunique()
        if n != 0:
            users.append(n)
            u.append(nn)

    one_link_df["n_users"] = users
    one_link_df["users"] = u
    temp_urls = []
    for i in one_link_df[["url", "n_users", "users"]].values:
        temp_urls.append((i[0], i[1], i[2]))
    data_last = dict(Counter(temp_urls))
    links_last = []
    nusers_last = []
    count_last = []
    users_last = []
    for url_users, count in data_last.items():
        links_last.append(url_users[0])
        count_last.append(count)
        nusers_last.append(url_users[1])
        users_last.append(url_users[2])

    return (
        pd.DataFrame({"link": links_last, "count": count_last, "n_users": nusers_last, "users": users_last})
        .sort_values("n_users", ascending=False)
        .reset_index()
        .drop(columns="index")
    )

# %%
from collections import Counter

# %%
df_comments_4_months_urls_1_link_ith_users_count = one_link_urls_with_count_(
    df_comments_4_months_urls_1_link, user_column="snippet.topLevelComment.snippet.authorChannelId.value", url_column="url"
)

# %%
df_comments_4_months_urls_1_link_ith_users_count
# Out:
#                                                   link  count  n_users  \
# 0                         https://youtu.be/hBH5O1ukpq8     11        7
# 1    https://www.change.org/p/dc-entertainment-remo...     10        7
# 2    https://www.change.org/p/dc-entertainment-remo...     15        5
# 3      playmovieoncinemax.blogspot.com/tt0974015/plyon      9        5
# 4     watchanddownloadnow.blogspot.com/tt0974015/wandw      6        5
# ..                                                 ...    ...      ...
# 690  https://www.youtube.com/watch?v=t9QGgo2HvE0&t=74s      1        1
# 691        https://www.youtube.com/watch?v=yOCMGkKkhnM      1        1
# 692                       https://youtu.be/9jZSrxs3mrs      1        1
# 693        https://www.youtube.com/watch?v=Y8FwSj8IH4o      1        1
# 694        https://www.youtube.com/watch?v=VjQ2t_yNHQs      1        1
#
#                                                  users
# 0    (UCxvfMZaw79EewtnFFw1T47g, UCWJRWgl9PpMReKTWro...
# ...

# %%
df_comments_4_months_urls_1_link_ith_users_count[df_comments_4_months_urls_1_link_ith_users_count.n_users == 7].users[0]
# Out:
# ('UCxvfMZaw79EewtnFFw1T47g',
#  'UCWJRWgl9PpMReKTWro8eJbg',
#  'UCJjOIuv9zS5QJDZs1VWmR7Q',
#  'UCZ80wTVpuQtEG7kifw8PY5Q',
#  'UCnuR-hKnQXoWn5YB-0cTt5Q',
#  'UC_iPNFxGu2Uh2etsbU9okkw',
#  'UCSv37cw6HsYWszG7nODGshg')

# %%
df_comments_4_months_urls_1_link_ith_users_count[
    df_comments_4_months_urls_1_link_ith_users_count.n_users == 7
].users[0] == df_comments_4_months_urls_1_link_ith_users_count[
    df_comments_4_months_urls_1_link_ith_users_count.n_users == 7
].users[
    1
]
# Out:
# False

# %%
def same_users(t1, t2):
    if set(t1) == set(t2):
        return True
    else:
        return False

# %%
same_users(
    df_comments_4_months_urls_1_link_ith_users_count[
        df_comments_4_months_urls_1_link_ith_users_count.n_users == 7
    ].users[0],
    df_comments_4_months_urls_1_link_ith_users_count[
        df_comments_4_months_urls_1_link_ith_users_count.n_users == 7
    ].users[1],
)
# Out:
# False

# %%
same_users((1,2,3), (3,1,2))
# Out:
# True

# %%
df_comments_4_months_urls_1_link_ith_users_count[df_comments_4_months_urls_1_link_ith_users_count.n_users == 7].users[0]
# Out:
# ('UCxvfMZaw79EewtnFFw1T47g',
#  'UCWJRWgl9PpMReKTWro8eJbg',
#  'UCJjOIuv9zS5QJDZs1VWmR7Q',
#  'UCZ80wTVpuQtEG7kifw8PY5Q',
#  'UCnuR-hKnQXoWn5YB-0cTt5Q',
#  'UC_iPNFxGu2Uh2etsbU9okkw',
#  'UCSv37cw6HsYWszG7nODGshg')

# %%
df_comments_4_months_urls_1_link_ith_users_count["n_urls"] = 1

# %%
df_comments_4_months_urls_1_link_ith_users_count[
    "n_urls"
] = df_comments_4_months_urls_1_link_ith_users_count["n_urls"].apply(lambda x: {x})

# %%
df_comments_4_months_urls_1_link_ith_users_count
# Out:
#                                                   link  count  n_users  \
# 0                         https://youtu.be/hBH5O1ukpq8     11        7
# 1    https://www.change.org/p/dc-entertainment-remo...     10        7
# 2    https://www.change.org/p/dc-entertainment-remo...     15        5
# 3      playmovieoncinemax.blogspot.com/tt0974015/plyon      9        5
# 4     watchanddownloadnow.blogspot.com/tt0974015/wandw      6        5
# ..                                                 ...    ...      ...
# 690  https://www.youtube.com/watch?v=t9QGgo2HvE0&t=74s      1        1
# 691        https://www.youtube.com/watch?v=yOCMGkKkhnM      1        1
# 692                       https://youtu.be/9jZSrxs3mrs      1        1
# 693        https://www.youtube.com/watch?v=Y8FwSj8IH4o      1        1
# 694        https://www.youtube.com/watch?v=VjQ2t_yNHQs      1        1
#
#                                                  users n_urls
# ...

# %%
# df_comments_4_months_urls_1_link_ith_users_count.to_csv(
#     yt_filter_path
#     + "df_comments_4_months_urls_1_link.csv",
#     index=False,
# )

# %% [markdown]
# <a id='more4'></a>
# #### More Than One Link
#
# ><ul>
#  <li><a href="#one4">One Link</a></li>
#  <li><a href="#more4">More Than One Link</a></li>
#
#  </ul>

# %%
df_comments_4_months_urls_more = df_more_than_link(df_comments_4_months_urls)

# %%
def more_than_one_link_with_count(df, column_user, column_urls):
    user_link_m = []
    n_urls = []
    for user_links in df[[column_user, column_urls]].values:

        for link in user_links[1]:
            user_link_m.append((user_links[0], link, len(user_links[1])))
    temp = pd.DataFrame(
        {
            "link": [i[1] for i in user_link_m],
            "user": [i[0] for i in user_link_m],
            "n_urls": [i[2] for i in user_link_m],
        }
    )
    links = temp["link"].unique()
    last_links = []
    last_u = []
    last_c = []
    last_n = []
    last_nu = []
    for link in links:
        last_c.append(temp[temp["link"] == link].shape[0])
        last_u.append(temp[temp["link"] == link]["user"].nunique())
        last_nu.append(set((temp[temp["link"] == link]["user"].unique())))
        last_n.append(set(temp[temp["link"] == link]["n_urls"].values))
        last_links.append(link)

    return pd.DataFrame(
        {
            "link": last_links,
            "count": last_c,
            "n_users": last_u,
            "users": last_nu,
            "n_urls": last_n,
        }
    )

# %%
df_comments_4_months_urls_more_link_with_users_count = more_than_one_link_with_count(
    df_comments_4_months_urls_more,
    "snippet.topLevelComment.snippet.authorChannelId.value",
    "urls",
)

# %%
df_comments_4_months_urls_more_link_with_users_count
# Out:
#                                                   link  count  n_users  \
# 0                               https://bit.ly/3txAgy1      3        1
# 1                         https://youtu.be/YVPyBraRags      1        1
# 2                        https://t.co/yWkf2d2APp?amp=1     18        1
# 3        https://referral.rumble.com/dszVtP5hNXYLXqL89     22        1
# 4    https://www.youtube.com/channel/UCt4dtZ67qO3xW...     24        1
# ..                                                 ...    ...      ...
# 109                       https://youtu.be/wYYHIQulxIg      1        1
# 110                       https://youtu.be/jWqHBv9IXI4      1        1
# 111                       https://youtu.be/lJSb_VH-P_c      1        1
# 112  https://www.youtube.com/watch?v=FdM479D1s4o&t=...      1        1
# 113           https://www.instagram.com/p/CJEdjaNDQe5/      1        1
#
#                           users     n_urls
# 0    {UCpf78xcANIGhaCqX65dZbEA}        {2}
# ...

# %%
saving = "URLs_Data/Youtube/"

# %%
df_comments_4_months_urls.to_csv(saving + "df_comments_4_months_urls.csv", index=False)

# %%
df_comments_4_months_urls_1_link_ith_users_count.head(2)
# Out:
#                                                 link  count  n_users  \
# 0                       https://youtu.be/hBH5O1ukpq8     11        7
# 1  https://www.change.org/p/dc-entertainment-remo...     10        7
#
#                                                users n_urls
# 0  (UCxvfMZaw79EewtnFFw1T47g, UCWJRWgl9PpMReKTWro...    {1}
# 1  (UCRhOnSeQrFi26ZqyhMT46Sw, UCrKT7YkiQmbbJMK3AU...    {1}

# %%
# df_comments_4_months_urls_1_link_ith_users_count.to_csv(
#     saving + "df_comments_4_months_urls_1_link_with_users_count.csv", index=False
# )

# %%
df_comments_4_months_urls_more_link_with_users_count.head(2)
# Out:
#                            link  count  n_users                       users  \
# 0        https://bit.ly/3txAgy1      3        1  {UCpf78xcANIGhaCqX65dZbEA}
# 1  https://youtu.be/YVPyBraRags      1        1  {UCpf78xcANIGhaCqX65dZbEA}
#
#   n_urls
# 0    {2}
# 1    {2}

# %%
df_comments_4_months_urls_with_users_count = pd.concat(
    [
        df_comments_4_months_urls_1_link_ith_users_count,
        df_comments_4_months_urls_more_link_with_users_count,
    ]
).sort_values("count", ascending=False)

# %%
df_comments_4_months_urls_with_users_count.to_csv(
    saving + "df_comments_4_months_urls_with_users_count.csv", index=False
)

# %%
df_comments_4_months_urls_with_users_count
# Out:
#                                                   link  count  n_users  \
# 7              https://www.patreon.com/user?u=21542407     24        1
# 4    https://www.youtube.com/channel/UCt4dtZ67qO3xW...     24        1
# 5       https://www.bitchute.com/channel/a3WbPaAzRKWN/     24        1
# 8     https://www.subscribestar.com/nerdettesnewsstand     24        1
# 6    https://www.youtube.com/channel/UC8AGq7bm-x4te...     24        1
# ..                                                 ...    ...      ...
# 296  https://www.therichest.com/world-entertainment...      1        1
# 297  https://pagesix.com/2020/11/02/how-johnny-depp...      1        1
# 298  https://www.courttv.com/news/amber-heard-witne...      1        1
# 299                       https://youtu.be/ZUa11ih4abM      1        1
# 113           https://www.instagram.com/p/CJEdjaNDQe5/      1        1
#
#                            users     n_urls
# 7     {UC8AGq7bm-x4teGcvQonvnPw}  {8, 6, 7}
# ...

# %%
# df_comments_4_months_urls_more_link_with_users_count.to_csv(
#     yt_filter_path
#     + "df_comments_4_months_urls_more.csv",
#     index=False,
# )

# %% [markdown]
# ### December
# <a id='12'></a>
#
#
# ><ul>
#  <li><a href="#one12">One Link</a></li>
#  <li><a href="#more12">More Than One Link</a></li>
#
#  </ul>

# %% [markdown]
# <a id='one12'></a>
# #### One Link
#
# ><ul>
#  <li><a href="#one12">One Link</a></li>
#  <li><a href="#more12">More Than One Link</a></li>
#
#  </ul>

# %%
df_comments_dec["urls"] = df_comments_dec[
    "snippet.topLevelComment.snippet.textOriginal"
].apply(lambda x: get_urls(x))

# %%
df_comments_dec.head(2)
# Out:
#    Unnamed: 0                   kind                         etag  \
# 0         3.0  youtube#commentThread  3zjB6fncclwM6wDcH0ZqYn72nGo
# 1         4.0  youtube#commentThread  AN1UcpP0T8D4uEJUsSfusd7P2ow
#
#                            id snippet.videoId snippet.topLevelComment.kind  \
# 0  UgwlYeNl9rWPcvxVB914AaABAg     ht92feHGR9M              youtube#comment
# 1  UgyYnH9QmQJep_zoZ6x4AaABAg     ht92feHGR9M              youtube#comment
#
#   snippet.topLevelComment.etag  snippet.topLevelComment.id  \
# 0  LlMSpcBCT8ZQkacocUa0dInznew  UgwlYeNl9rWPcvxVB914AaABAg
# 1  j-SLTZmX-QijCYKkZAjaqMb97mE  UgyYnH9QmQJep_zoZ6x4AaABAg
#
#   snippet.topLevelComment.snippet.videoId  \
# 0                             ht92feHGR9M
# 1                             ht92feHGR9M
#
#          snippet.topLevelComment.snippet.textDisplay  ...  \
# 0  Where&#39;s the site or link to remove her? I ...  ...
# 1  When they will remove Amber Heard &quot;Mera&q...  ...
#
# ...

# %%
df_comments_dec["n_urls"] = df_comments_dec.urls.apply(lambda x: len(x))

# %%
df_comments_dec_urls = urls_df(df_comments_dec)

# %%
df_comments_dec_urls_1_link = one_link_df(df_comments_dec_urls)

# %%
df_comments_dec_urls_1_link.head(1)
# Out:
#    Unnamed: 0                   kind                         etag  \
# 0         6.0  youtube#commentThread  KwMpoBaKzBBFyS9u8XPxOv_n6pQ
#
#                            id snippet.videoId snippet.topLevelComment.kind  \
# 0  UgyWJu8MWyEHbEPk9p14AaABAg     ZgdOxbOLDU8              youtube#comment
#
#   snippet.topLevelComment.etag  snippet.topLevelComment.id  \
# 0  FMDuFkf4ElbHBu7iLtrmwds5ncU  UgyWJu8MWyEHbEPk9p14AaABAg
#
#   snippet.topLevelComment.snippet.videoId  \
# 0                             ZgdOxbOLDU8
#
#          snippet.topLevelComment.snippet.textDisplay  ...  \
# 0  Support Jhonny depp for being jack sparrow bac...  ...
#
#   snippet.topLevelComment.snippet.publishedAt  \
# 0                   2020-12-15 04:01:24+00:00
#
#   snippet.topLevelComment.snippet.updatedAt snippet.canReply  \
# 0                      2020-12-15T04:01:24Z             True
#
#   snippet.totalReplyCount snippet.isPublic  replies.comments  \
# ...

# %%
list_comments_dec_urls_1_link = one_link_urls(df_comments_dec_urls_1_link)

# %%
list_comments_dec_urls_1_link
# Out:
# array([list(['http://chng.it/QVWDqD8mRW']),
#        list(['https://youtu.be/FIaH83l0QAg']),
#        list(['https://www.change.org/p/dc-entertainment-remove-amber-heard-from-aquaman-2?recruiter=1104861260&utm_source=share_petition&utm_medium=copylink&utm_campaign=share_petition']),
#        list(['https://youtu.be/gHS-9N2i0pg']),
#        list(['https://www.youtube.com/watch?v=upBP2UYyRZU']),
#        list(['https://youtu.be/ffbN7YwLXTc']),
#        list(['http://chng.it/7NHt9NTppj']),
#        list(['https://www.youtube.com/watch?v=Akl3k1kcPvY']),
#        list(['https://youtu.be/WmCtnA8-eT8']),
#        list(['https://www.youtube.com/watch?v=LHYRYKCIDxk']),
#        list(['https://www.youtube.com/watch?v=uretrfMA-Io&ab_channel=Access']),
#        list(['https://www.cdc.gov/violenceprevention/datasources/nisvs/men-ipvsvandstalking.html']),
#        list(['http://chng.it/F82CP2Mbrx']),
#        list(['https://www.youtube.com/watch?v=GccCWo_eZdw']),
# ...

# %%
df_comments_dec_urls_1_link_ith_users_count = one_link_urls_with_count_(
    df_comments_dec_urls_1_link,
    user_column="snippet.topLevelComment.snippet.authorChannelId.value",
    url_column="url",
)

# %%
df_comments_dec_urls_1_link_ith_users_count.head(2)
# Out:
#                                                 link  count  n_users  \
# 0  https://www.change.org/p/dc-entertainment-remo...     27       17
# 1  https://www.change.org/p/dc-entertainment-remo...     25        8
#
#                                                users
# 0  (UCRhOnSeQrFi26ZqyhMT46Sw, UCy_gFHCCUKvZwxmjO8...
# 1  (UCU2M0iVIvIE-WDrr7Zq1UTw, UCdN2Cdc4yVq0n6VJAd...

# %%
df_comments_dec_urls_1_link_ith_users_count["n_urls"] = 1

# %%
df_comments_dec_urls_1_link_ith_users_count[
    "n_urls"
] = df_comments_dec_urls_1_link_ith_users_count["n_urls"].apply(lambda x: {x})

# %%
df_comments_dec_urls_1_link_ith_users_count.head(2)
# Out:
#                                                 link  count  n_users  \
# 0  https://www.change.org/p/dc-entertainment-remo...     27       17
# 1  https://www.change.org/p/dc-entertainment-remo...     25        8
#
#                                                users n_urls
# 0  (UCRhOnSeQrFi26ZqyhMT46Sw, UCy_gFHCCUKvZwxmjO8...    {1}
# 1  (UCU2M0iVIvIE-WDrr7Zq1UTw, UCdN2Cdc4yVq0n6VJAd...    {1}

# %% [markdown]
# <a id='more4'></a>
# #### More Than One Link
#
# ><ul>
#  <li><a href="#one4">One Link</a></li>
#  <li><a href="#more4">More Than One Link</a></li>
#
#  </ul>

# %%
df_comments_dec_urls_urls_more = df_more_than_link(df_comments_dec_urls)

# %%
df_comments_dec_urls_urls_more.head(2)
# Out:
#    Unnamed: 0                   kind                         etag  \
# 0        45.0  youtube#commentThread  vrjHSvKbOnocmVhHX6Fcia0NPZU
# 1        46.0  youtube#commentThread  2KoPBnkGH6Wxq7H-6mUO3mDacgM
#
#                            id snippet.videoId snippet.topLevelComment.kind  \
# 0  Ugxe640u7xqHIhsJMal4AaABAg     8oNYOv4o8zM              youtube#comment
# 1  Ugzs4VDTeHlhveLnxDV4AaABAg     8oNYOv4o8zM              youtube#comment
#
#   snippet.topLevelComment.etag  snippet.topLevelComment.id  \
# 0  -Dlurk_GGOv0PcxR_VTAV_q2Dv4  Ugxe640u7xqHIhsJMal4AaABAg
# 1  dPa_GyhMX36RHy9to96h1cqjpMc  Ugzs4VDTeHlhveLnxDV4AaABAg
#
#   snippet.topLevelComment.snippet.videoId  \
# 0                             8oNYOv4o8zM
# 1                             8oNYOv4o8zM
#
#          snippet.topLevelComment.snippet.textDisplay  ...  \
# 0  Sign this petition to rid Amber Heard off AQUA...  ...
# 1  The evidence is out there, free too look.. <a ...  ...
#
# ...

# %%
df_comments_dec_urls_urls_more.head(2)
# Out:
#    Unnamed: 0                   kind                         etag  \
# 0        45.0  youtube#commentThread  vrjHSvKbOnocmVhHX6Fcia0NPZU
# 1        46.0  youtube#commentThread  2KoPBnkGH6Wxq7H-6mUO3mDacgM
#
#                            id snippet.videoId snippet.topLevelComment.kind  \
# 0  Ugxe640u7xqHIhsJMal4AaABAg     8oNYOv4o8zM              youtube#comment
# 1  Ugzs4VDTeHlhveLnxDV4AaABAg     8oNYOv4o8zM              youtube#comment
#
#   snippet.topLevelComment.etag  snippet.topLevelComment.id  \
# 0  -Dlurk_GGOv0PcxR_VTAV_q2Dv4  Ugxe640u7xqHIhsJMal4AaABAg
# 1  dPa_GyhMX36RHy9to96h1cqjpMc  Ugzs4VDTeHlhveLnxDV4AaABAg
#
#   snippet.topLevelComment.snippet.videoId  \
# 0                             8oNYOv4o8zM
# 1                             8oNYOv4o8zM
#
#          snippet.topLevelComment.snippet.textDisplay  ...  \
# 0  Sign this petition to rid Amber Heard off AQUA...  ...
# 1  The evidence is out there, free too look.. <a ...  ...
#
# ...

# %%
df_comments_dec_urls_urls_more_with_users_count = more_than_one_link_with_count(
    df_comments_dec_urls_urls_more,
    "snippet.topLevelComment.snippet.authorChannelId.value",
    "urls",
)

# %%
df_comments_dec_urls_urls_more_with_users_count
# Out:
#                                                   link  count  n_users  \
# 0                              http://chng.it/JDQLmRqM      6        1
# 1                              http://chng.it/kDLjcZR8      6        1
# 2                https://www.nickwallis.com/depp-trial      7        2
# 3    www.courttv.com/news/amber-heard-witness-state...      6        1
# 4                         https://youtu.be/ajWdkuvrT6s      1        1
# ..                                                 ...    ...      ...
# 134                       https://youtu.be/-WJoxStLvsM      1        1
# 135         https://www.bitchute.com/video/-WJoxStLvsM      1        1
# 136  https://www.facebook.com/Steven.Work/posts/102...      1        1
# 137                       https://youtu.be/ew3XxEowAA8      1        1
# 138                       https://youtu.be/rVYo2cz6_ME      1        1
#
#                                                  users n_urls
# ...

# %%
df_comments_dec_urls_with_users_count = pd.concat(
    [
        df_comments_dec_urls_1_link_ith_users_count,
        df_comments_dec_urls_urls_more_with_users_count,
    ]
).sort_values("count", ascending=False)

# %%
df_comments_dec_urls_with_users_count.to_csv(
    saving + "df_comments_dec_urls_with_users_count.csv", index=False
)

# %% [markdown]
# <a id='Videos'></a>
#
# ## Videos
#
#
# ><ul>
#  <li><a href="#4v">4 Months</a></li>
#  <li><a href="#12v">December</a></li>
#
#  </ul>

# %%
yt_videos_path = "../../youtube/[CSV] Combined by year [6893 videos](videos, comments and channels) (final 25Dec21)/combined files for videos by year/"

# %%
df_videos_20 = pd.read_csv(yt_videos_path + "youtube_data_2020.csv")
df_videos_21 = pd.read_csv(yt_videos_path + "youtube_data_2021.csv")

# %%
df_videos_20.head(1)
# Out:
#    Unnamed: 0           id  Unnamed: 0.1           kind  \
# 0           1  9rC1gEB5wSk           0.0  youtube#video
#
#                           etag        snippet.publishedAt  \
# 0  W_OcjSa0xjX5E8u4uZKGTkOVnek  2020-12-30 16:25:16+00:00
#
#           snippet.channelId  \
# 0  UCNoGr_InOOlv0XhHO9KC3Hg
#
#                                        snippet.title snippet.description  \
# 0  solving a rubik's cube everyday until amber he...  fire amber heard 😡
#
#                    snippet.thumbnails.default.url  ...  statistics.viewCount  \
# 0  https://i.ytimg.com/vi/9rC1gEB5wSk/default.jpg  ...                     4
#
#    statistics.likeCount statistics.dislikeCount  statistics.favoriteCount  \
# 0                   2.0                     0.0                         0
#
#    statistics.commentCount snippet.defaultLanguage  \
# 0                      0.0                     NaN
#
#    contentDetails.contentRating.ytRating  \
# 0                                    NaN
#
# ...

# %%
df_videos_21.head(1)
# Out:
#    Unnamed: 0           id  Unnamed: 0.1           kind  \
# 0           0  14SUI93R_k8           0.0  youtube#video
#
#                           etag        snippet.publishedAt  \
# 0  zUX2H4amXbJxvecYfsO-9mMha7c  2021-03-19 17:00:30+00:00
#
#           snippet.channelId  \
# 0  UC-NINtNMPM75eaqh07RCy_Q
#
#                                        snippet.title  \
# 0  jason momoa defends amber heard after aquaman ...
#
#                                  snippet.description  \
# 0  jason momoa defends amber heard after aquaman ...
#
#                    snippet.thumbnails.default.url  ...  statistics.viewCount  \
# 0  https://i.ytimg.com/vi/14SUI93R_k8/default.jpg  ...                 32001
#
#    statistics.likeCount statistics.dislikeCount  statistics.favoriteCount  \
# 0                1394.0                    71.0                         0
#
#    statistics.commentCount snippet.defaultLanguage  \
# 0                    942.0                     NaN
#
# ...

# %%
len(df_comments_4_months["snippet.videoId"].unique())
# Out:
# 2164

# %%
df_videos_id_4_months = pd.DataFrame(
    {"id": df_comments_4_months["snippet.videoId"].unique()}
)

# %%
df_videos_id_4_months
# Out:
#                id
# 0     14SUI93R_k8
# 1     Dvh09e0TPJ4
# 2     I7GfS45bcwA
# 3     Ugtl8D8XACE
# 4     FMpQwj2OT8Q
# ...           ...
# 2159  hFkRoI97TfE
# 2160  QgMabpFX9OU
# 2161  635rHs3I4U8
# 2162  6ZhuwlKgdzA
# 2163  89Bg1GryUKw
#
# [2164 rows x 1 columns]

# %%
df_videos_21.head(1)
# Out:
#    Unnamed: 0           id  Unnamed: 0.1           kind  \
# 0           0  14SUI93R_k8           0.0  youtube#video
#
#                           etag        snippet.publishedAt  \
# 0  zUX2H4amXbJxvecYfsO-9mMha7c  2021-03-19 17:00:30+00:00
#
#           snippet.channelId  \
# 0  UC-NINtNMPM75eaqh07RCy_Q
#
#                                        snippet.title  \
# 0  jason momoa defends amber heard after aquaman ...
#
#                                  snippet.description  \
# 0  jason momoa defends amber heard after aquaman ...
#
#                    snippet.thumbnails.default.url  ...  statistics.viewCount  \
# 0  https://i.ytimg.com/vi/14SUI93R_k8/default.jpg  ...                 32001
#
#    statistics.likeCount statistics.dislikeCount  statistics.favoriteCount  \
# 0                1394.0                    71.0                         0
#
#    statistics.commentCount snippet.defaultLanguage  \
# 0                    942.0                     NaN
#
# ...

# %%
len(set(df_videos_21.id.unique()).intersection(set(df_comments_4_months["snippet.videoId"].unique())))
# Out:
# 732

# %%
df_videos_4_months = pd.merge(df_videos_id_4_months, df_videos_21, left_on="id", right_on="id", how="inner")

# %%
df_videos_4_months.head(1)
# Out:
#             id  Unnamed: 0  Unnamed: 0.1           kind  \
# 0  14SUI93R_k8           0           0.0  youtube#video
#
#                           etag        snippet.publishedAt  \
# 0  zUX2H4amXbJxvecYfsO-9mMha7c  2021-03-19 17:00:30+00:00
#
#           snippet.channelId  \
# 0  UC-NINtNMPM75eaqh07RCy_Q
#
#                                        snippet.title  \
# 0  jason momoa defends amber heard after aquaman ...
#
#                                  snippet.description  \
# 0  jason momoa defends amber heard after aquaman ...
#
#                    snippet.thumbnails.default.url  ...  statistics.viewCount  \
# 0  https://i.ytimg.com/vi/14SUI93R_k8/default.jpg  ...                 32001
#
#    statistics.likeCount statistics.dislikeCount  statistics.favoriteCount  \
# 0                1394.0                    71.0                         0
#
#    statistics.commentCount snippet.defaultLanguage  \
# 0                    942.0                     NaN
#
# ...

# %%
df_videos_4_months.columns
# Out:
# Index(['id', 'Unnamed: 0', 'Unnamed: 0.1', 'kind', 'etag',
#        'snippet.publishedAt', 'snippet.channelId', 'snippet.title',
#        'snippet.description', 'snippet.thumbnails.default.url',
#        'snippet.thumbnails.default.width', 'snippet.thumbnails.default.height',
#        'snippet.thumbnails.medium.url', 'snippet.thumbnails.medium.width',
#        'snippet.thumbnails.medium.height', 'snippet.thumbnails.high.url',
#        'snippet.thumbnails.high.width', 'snippet.thumbnails.high.height',
#        'snippet.thumbnails.standard.url', 'snippet.thumbnails.standard.width',
#        'snippet.thumbnails.standard.height', 'snippet.thumbnails.maxres.url',
#        'snippet.thumbnails.maxres.width', 'snippet.thumbnails.maxres.height',
#        'snippet.channelTitle', 'snippet.tags', 'snippet.categoryId',
#        'snippet.liveBroadcastContent', 'snippet.localized.title',
#        'snippet.localized.description', 'snippet.defaultAudioLanguage',
# ...

# %%
df_videos_4_months["snippet.localized.description"]
# Out:
# 0      Jason Momoa Defends Amber Heard After Aquaman ...
# 1      Due to all the drama caused by the divorce of ...
# 2      In today's video we are going to share what em...
# 3      CANCELLED! Aquaman spinoff CANNED! Aquaman 2 a...
# 4      Amber Heard Officially FIRED From Aquaman 2 Ro...
#                              ...
# 727    Amber Heard Blocks Literally EVERYONE on Twitt...
# 728    Today Amber Heard first statement on social me...
# 729    "You Saved Me" Johnny Depp Thanks His Supporte...
# 730    Does Amber Heard Treat this Horse Good or Bad?...
# 731                                             Enjoy. 🤣
# Name: snippet.localized.description, Length: 732, dtype: object

# %%
df_videos_4_months["urls"] = df_videos_4_months["snippet.localized.description"].astype(str).apply(lambda x: get_urls(x))

# %%
df_videos_4_months["n_urls"] = df_videos_4_months["urls"].apply(lambda x: len(x))

# %%
df_videos_4_months
# Out:
#               id  Unnamed: 0  Unnamed: 0.1           kind  \
# 0    14SUI93R_k8           0           0.0  youtube#video
# 1    Dvh09e0TPJ4           6           0.0  youtube#video
# 2    I7GfS45bcwA          17           0.0  youtube#video
# 3    FMpQwj2OT8Q          45           0.0  youtube#video
# 4    QBCEXSVjBrM          65           0.0  youtube#video
# ..           ...         ...           ...            ...
# 727  1j4fHKp8Yms         762           NaN  youtube#video
# 728  ri0kM4nr2nI        1514           NaN  youtube#video
# 729  QgMabpFX9OU        4814           NaN  youtube#video
# 730  6ZhuwlKgdzA        4448           NaN  youtube#video
# 731  89Bg1GryUKw        3241           NaN  youtube#video
#
#                             etag        snippet.publishedAt  \
# 0    zUX2H4amXbJxvecYfsO-9mMha7c  2021-03-19 17:00:30+00:00
# 1    4u7I4SS34RQx1C6unGTM6QVxt8I  2021-02-19 22:52:43+00:00
# 2    IWILnyzb7PQqy06rWpID_RJrZSc  2021-02-20 20:15:16+00:00
# ...

# %%
df_videos_4_months.to_csv(saving + "df_videos_urls_4_months.csv", index=False)

# %% [markdown]
# <a id='one4v'></a>
# #### One Link
#
# ><ul>
#  <li><a href="#one4v">One Link</a></li>
#  <li><a href="#more4v">More Than One Link</a></li>
#
#  </ul>

# %%
df_videos_4_months_urls_1_link = one_link_df(df_videos_4_months)

# %%
df_videos_4_months_urls_1_link.head(1)
# Out:
#             id  Unnamed: 0  Unnamed: 0.1           kind  \
# 0  Dvh09e0TPJ4           6           0.0  youtube#video
#
#                           etag        snippet.publishedAt  \
# 0  4u7I4SS34RQx1C6unGTM6QVxt8I  2021-02-19 22:52:43+00:00
#
#           snippet.channelId                                  snippet.title  \
# 0  UCgvSv4X_fb6fbZQR6kqTyWQ  amber heard replaced in the aquaman 2 movie?!
#
#                                  snippet.description  \
# 0  due to all the drama caused by the divorce of ...
#
#                    snippet.thumbnails.default.url  ...  \
# 0  https://i.ytimg.com/vi/Dvh09e0TPJ4/default.jpg  ...
#
#    statistics.favoriteCount  statistics.commentCount snippet.defaultLanguage  \
# 0                         0                     92.0                     NaN
#
#    contentDetails.contentRating.ytRating  \
# 0                                    NaN
#
#    contentDetails.regionRestriction.blocked  \
# 0                                       NaN
#
# ...

# %%
list_videos_4_months_urls_1_link = one_link_urls(df_videos_4_months_urls_1_link)

# %%
list_videos_4_months_urls_1_link
# Out:
# array([list(['https://www.instagram.com/celebrity23insider/']),
#        list(['http://bit.ly/32rc7vI']), list(['https://bit.ly/3kzplQd']),
#        list(['https://www.youtube.com/c/TuCOSMOPOLIS']),
#        list(['http://youtube.com/channel/UCylyoo597NuFFyJS_HwHubQ?sub_confirmation=1']),
#        list(['https://bit.ly/30kR4eB']),
#        list(['http://youtube.com/channel/UCylyoo597NuFFyJS_HwHubQ?sub_confirmation=1']),
#        list(['https://bit.ly/3vX5q2R']),
#        list(['https://mypetstrendy.com']),
#        list(['www.phoenixspringtarot.com']),
#        list(['https://www.instagram.com/celebrity23insider/']),
#        list(['https://movieburnerentertainment.org']),
#        list(['https://www.patreon.com/martindecoder']),
#        list(['https://support.google.com/youtube/an']),
#        list(['https://www.instagram.com/8pm.tube/']),
#        list(['https://www.youtube.com/channel/UCAmaiEYnoTgj-dmjp8DpepQ?sub_confirmation=1']),
# ...

# %%
df_videos_4_months_urls_1_link.head(1)
# Out:
#             id  Unnamed: 0  Unnamed: 0.1           kind  \
# 0  Dvh09e0TPJ4           6           0.0  youtube#video
#
#                           etag        snippet.publishedAt  \
# 0  4u7I4SS34RQx1C6unGTM6QVxt8I  2021-02-19 22:52:43+00:00
#
#           snippet.channelId                                  snippet.title  \
# 0  UCgvSv4X_fb6fbZQR6kqTyWQ  amber heard replaced in the aquaman 2 movie?!
#
#                                  snippet.description  \
# 0  due to all the drama caused by the divorce of ...
#
#                    snippet.thumbnails.default.url  ...  \
# 0  https://i.ytimg.com/vi/Dvh09e0TPJ4/default.jpg  ...
#
#    statistics.favoriteCount  statistics.commentCount snippet.defaultLanguage  \
# 0                         0                     92.0                     NaN
#
#    contentDetails.contentRating.ytRating  \
# 0                                    NaN
#
#    contentDetails.regionRestriction.blocked  \
# 0                                       NaN
#
# ...

# %%
df_videos_4_months_urls_1_link_with_users_count = one_link_urls_with_count_(
    df_videos_4_months_urls_1_link, user_column="snippet.channelId", url_column="url"
)

# %%
df_videos_4_months_urls_1_link_with_users_count
# Out:
#                                                  link  count  n_users  \
# 0              https://www.youtube.com/c/TuCOSMOPOLIS      2        2
# 1               https://support.google.com/youtube/an      3        2
# 2       https://www.instagram.com/celebrity23insider/      6        1
# 3            https://www.patreon.com/lowcarbdownunder      1        1
# 4                      https://www.washingtonexec.com      1        1
# 5         https://www.youtube.com/watch?v=GhwxJfqI3tE      1        1
# 6   https://www.youtube.com/channel/UCJEY8C5wd0K99...      1        1
# 7   https://www.youtube.com/channel/UCWHvqSU3G3d0R...      1        1
# 8                        https://youtu.be/-t-1wygFTWs      1        1
# 9                           https://bit.ly/mannixplus      1        1
# 10  https://www.nykaa.com/l-oreal-paris-infallible...      1        1
# 11              https://www.youtube.com/channel/UCPI3      1        1
# ...

# %%
df_videos_4_months_urls_1_link_with_users_count["n_urls"] = 1

# %%
df_videos_4_months_urls_1_link_with_users_count[
    "n_urls"
] = df_videos_4_months_urls_1_link_with_users_count["n_urls"].apply(lambda x: {x})

# %%
df_videos_4_months_urls_1_link_with_users_count
# Out:
#                                                  link  count  n_users  \
# 0              https://www.youtube.com/c/TuCOSMOPOLIS      2        2
# 1               https://support.google.com/youtube/an      3        2
# 2       https://www.instagram.com/celebrity23insider/      6        1
# 3            https://www.patreon.com/lowcarbdownunder      1        1
# 4                      https://www.washingtonexec.com      1        1
# 5         https://www.youtube.com/watch?v=GhwxJfqI3tE      1        1
# 6   https://www.youtube.com/channel/UCJEY8C5wd0K99...      1        1
# 7   https://www.youtube.com/channel/UCWHvqSU3G3d0R...      1        1
# 8                        https://youtu.be/-t-1wygFTWs      1        1
# 9                           https://bit.ly/mannixplus      1        1
# 10  https://www.nykaa.com/l-oreal-paris-infallible...      1        1
# 11              https://www.youtube.com/channel/UCPI3      1        1
# ...

# %% [markdown]
# <a id='more4v'></a>
# #### More Than One Link
#
# ><ul>
#  <li><a href="#one4v">One Link</a></li>
#  <li><a href="#more4v">More Than One Link</a></li>
#
#  </ul>

# %%
df_videos_4_months_urls_more = df_more_than_link(df_videos_4_months)

# %%
df_videos_4_months_urls_more.head(2)
# Out:
#             id  Unnamed: 0  Unnamed: 0.1           kind  \
# 0  14SUI93R_k8           0           0.0  youtube#video
# 1  FMpQwj2OT8Q          45           0.0  youtube#video
#
#                           etag        snippet.publishedAt  \
# 0  zUX2H4amXbJxvecYfsO-9mMha7c  2021-03-19 17:00:30+00:00
# 1  DgprwoFqcrWkombPAgY-wQxVWyY  2021-04-08 17:30:01+00:00
#
#           snippet.channelId  \
# 0  UC-NINtNMPM75eaqh07RCy_Q
# 1  UCMAwi5fm2yOSEeKd_Qv0Z2Q
#
#                                        snippet.title  \
# 0  jason momoa defends amber heard after aquaman ...
# 1  cancelled! aquaman spinoff canned! aquaman 2 a...
#
#                                  snippet.description  \
# 0  jason momoa defends amber heard after aquaman ...
# 1  cancelled! aquaman spinoff canned! aquaman 2 a...
#
#                    snippet.thumbnails.default.url  ...  \
# 0  https://i.ytimg.com/vi/14SUI93R_k8/default.jpg  ...
# 1  https://i.ytimg.com/vi/FMpQwj2OT8Q/default.jpg  ...
#
# ...

# %%
df_videos_4_months_urls_more_link_with_users_count = more_than_one_link_with_count(df_videos_4_months_urls_more,
                             "snippet.channelId",
                             "urls")

# %%
df_videos_4_months_urls_more_link_with_users_count
# Out:
#                                                    link  count  n_users  \
# 0                                 http://bit.ly/2xB5CqA     18        1
# 1                                https://bit.ly/3qF38D7     36        1
# 2            https://www.instagram.com/thejohnnyrogers/     11        1
# 3                      https://twitter.com/uptownduck00      4        1
# 4              https://www.instagram.com/informoverload     18        1
# ...                                                 ...    ...      ...
# 1434                       https://youtu.be/OuCclSJLIxI      1        1
# 1435           https://www.instagram.com/lataquillagdl/      1        1
# 1436            https://www.facebook.com/LaTaquillaGDL/      1        1
# 1437                 https://www.instagram.com/lenyn12/      1        1
# 1438  https://www.youtube.com/channel/UCak7GgON2G8r1...      1        1
#
#                            users             n_urls
# ...

# %%
df_videos_4_months_urls_with_users_count = pd.concat(
    [
        df_videos_4_months_urls_1_link_with_users_count,
        df_videos_4_months_urls_more_link_with_users_count,
    ]
).sort_values("count", ascending=False)

# %%
df_videos_4_months_urls_with_users_count
# Out:
#                                                    link  count  n_users  \
# 11    https://support.google.com/youtube/answer/1620...     44        4
# 9               https://www.patreon.com/thatumbrellaguy     43        1
# 8     https://www.paypal.com/cgi-bin/webscr?cmd=_s-x...     43        1
# 1                                https://bit.ly/3qF38D7     36        1
# 10    https://www.youtube.com/channel/UCbiT0LUIbQj6C...     31        1
# ...                                                 ...    ...      ...
# 621               https://indyplanet.com/night-knight-1      1        1
# 620                     https://www.paypal.me/MrNailsin      1        1
# 619   https://boundingintocomics.com/2021/02/27/rumo...      1        1
# 618             https://www.airy-youtube-downloader.com      1        1
# 1438  https://www.youtube.com/channel/UCak7GgON2G8r1...      1        1
#
#                                                   users             n_urls
# ...

# %%
df_videos_4_months_urls_with_users_count.to_csv(
    saving + "df_videos_4_months_urls_with_users_count.csv", index=False
)

# %% [markdown]
# ### December
# <a id='12v'></a>
#
#
# ><ul>
#  <li><a href="#one12v">One Link</a></li>
#  <li><a href="#more12v">More Than One Link</a></li>
#
#  </ul>

# %%
df_videos_id_dec = pd.DataFrame({"id": df_comments_dec["snippet.videoId"]})

# %%
df_videos_id_dec
# Out:
#                  id
# 0       ht92feHGR9M
# 1       ht92feHGR9M
# 2       ht92feHGR9M
# 3       ht92feHGR9M
# 4       -elJS12UOnI
# ...             ...
# 156368  Wsn4aXVptWU
# 156369  Wsn4aXVptWU
# 156370  Wsn4aXVptWU
# 156371  Wsn4aXVptWU
# 156372  Wsn4aXVptWU
#
# [156373 rows x 1 columns]

# %%
df_videos_20.head(1)
# Out:
#    Unnamed: 0           id  Unnamed: 0.1           kind  \
# 0           1  9rC1gEB5wSk           0.0  youtube#video
#
#                           etag        snippet.publishedAt  \
# 0  W_OcjSa0xjX5E8u4uZKGTkOVnek  2020-12-30 16:25:16+00:00
#
#           snippet.channelId  \
# 0  UCNoGr_InOOlv0XhHO9KC3Hg
#
#                                        snippet.title snippet.description  \
# 0  solving a rubik's cube everyday until amber he...  fire amber heard 😡
#
#                    snippet.thumbnails.default.url  ...  statistics.viewCount  \
# 0  https://i.ytimg.com/vi/9rC1gEB5wSk/default.jpg  ...                     4
#
#    statistics.likeCount statistics.dislikeCount  statistics.favoriteCount  \
# 0                   2.0                     0.0                         0
#
#    statistics.commentCount snippet.defaultLanguage  \
# 0                      0.0                     NaN
#
#    contentDetails.contentRating.ytRating  \
# 0                                    NaN
#
# ...

# %%
df_videos_dec = pd.merge(df_videos_id_dec, df_videos_20, left_on="id", right_on="id", how="inner")

# %%
df_videos_dec.head(1)
# Out:
#             id  Unnamed: 0  Unnamed: 0.1           kind  \
# 0  ht92feHGR9M          69           0.0  youtube#video
#
#                           etag        snippet.publishedAt  \
# 0  zNkBfCV1TBeKMnDzDWZlqnoNpVM  2020-09-08 20:15:10+00:00
#
#           snippet.channelId  \
# 0  UCO6cSNvOaDs-kjALLQLNhQw
#
#                                        snippet.title  \
# 0  remove amber heard from aquaman 2 petition cou...
#
#                                  snippet.description  \
# 0  remove amber heard from aquaman 2 petition cou...
#
#                    snippet.thumbnails.default.url  ...  statistics.viewCount  \
# 0  https://i.ytimg.com/vi/ht92feHGR9M/default.jpg  ...                  5896
#
#    statistics.likeCount statistics.dislikeCount  statistics.favoriteCount  \
# 0                 318.0                     6.0                         0
#
#    statistics.commentCount snippet.defaultLanguage  \
# 0                    119.0                     NaN
#
# ...

# %%
df_videos_dec.drop_duplicates(inplace=True)

# %%
df_videos_dec["urls"] = (
    df_videos_dec["snippet.description"].astype(str).apply(lambda x: get_urls(x))
)

# %%
df_videos_dec["n_urls"] = df_videos_dec.urls.apply(lambda x: len(x))

# %%
df_videos_dec_urls = urls_df(df_videos_dec)

# %%
df_videos_dec_urls.head(5)
# Out:
#             id  Unnamed: 0  Unnamed: 0.1           kind  \
# 0  ht92feHGR9M          69           0.0  youtube#video
# 1  -elJS12UOnI          70           0.0  youtube#video
# 2  uxgCPIx7sM0          75           0.0  youtube#video
# 3  HXSgBFYg1lc          99           0.0  youtube#video
# 4  MBQGRxdwEGU         155           0.0  youtube#video
#
#                           etag        snippet.publishedAt  \
# 0  zNkBfCV1TBeKMnDzDWZlqnoNpVM  2020-09-08 20:15:10+00:00
# 1  mAmIq8QQtvY_jCUzbM9Wt7vbuSo  2020-11-23 04:06:35+00:00
# 2  1JKQNzTSnPs4P2IDyfwQ47EHz_8  2020-05-09 15:15:04+00:00
# 3  GTlCViRthIa5JRpw1dlcquYud6s  2020-07-23 13:04:23+00:00
# 4  oFAirBfpjFBG3d_MIkqgyUXaAzU  2020-02-09 15:20:27+00:00
#
#           snippet.channelId  \
# 0  UCO6cSNvOaDs-kjALLQLNhQw
# 1  UC4gD0czpXVv_LpADTSU624g
# 2  UCda8lNA3iwSoV1r3o-ViEhQ
# 3  UC3l-bobp_xuBlL_lRRS5RmA
# 4  UCk_wmXvLDO4wg7a_dxbjZAA
#
#                                        snippet.title  \
# ...

# %%
# save data
df_videos_dec_urls.to_csv(
    saving + "df_videos_dec_urls.csv", index=False
)

# %% [markdown]
# <a id='one12v'></a>
# #### One Link
#
# ><ul>
#  <li><a href="#one12v">One Link</a></li>
#  <li><a href="#more12v">More Than One Link</a></li>
#
#  </ul>

# %%
df_videos_dec_urls_1_link = one_link_df(df_videos_dec_urls)

# %%
df_videos_dec_urls_1_link.head(1)
# Out:
#             id  Unnamed: 0  Unnamed: 0.1           kind  \
# 0  ZgdOxbOLDU8         183           0.0  youtube#video
#
#                           etag        snippet.publishedAt  \
# 0  Szh-Nb2P4Cg-4dCpmB3ROL_ZxZQ  2020-11-19 17:00:15+00:00
#
#           snippet.channelId  \
# 0  UC-RQtY6MpSkCkaTRQP6G8PQ
#
#                                        snippet.title  \
# 0  the chaotic timeline of johnny depp and amber ...
#
#                                  snippet.description  \
# 0  johnny depp and amber heard have had a chaotic...
#
#                    snippet.thumbnails.default.url  ...  \
# 0  https://i.ytimg.com/vi/ZgdOxbOLDU8/default.jpg  ...
#
#    statistics.favoriteCount  statistics.commentCount snippet.defaultLanguage  \
# 0                         0                     21.0                     NaN
#
#    contentDetails.contentRating.ytRating  \
# 0                                    NaN
#
#    contentDetails.regionRestriction.blocked  \
# ...

# %%
list_videos_dec_urls_1_link = one_link_urls(df_videos_dec_urls_1_link)

# %%
df_videos_dec_urls_1_link_ith_users_count = one_link_urls_with_count_(
    df_videos_dec_urls_1_link,
    user_column="snippet.channelId",
    url_column="url",
)

# %%
df_videos_dec_urls_1_link_ith_users_count
# Out:
#                                                  link  count  n_users  \
# 0   https://www.change.org/p/dc-entertainment-remo...      3        3
# 1              https://www.youtube.com/c/tucosmopolis      2        2
# 2   https://www.looper.com/168440/stephen-kings-th...      2        2
# 3   https://www.nickiswift.com/15613/double-life-a...      2        2
# 4   https://www.youtube.com/channel/uc-rqty6mpskck...      1        1
# 5   https://www.youtube.com/channel/uc0rpd-lnyw6x6...      1        1
# 6   https://www.dailymail.co.uk/news/article-79667...      1        1
# 7                           https://bit.ly/mannixplus      1        1
# 8    https://www.youtube.com/watch?v=jcjwf9lafxc&t=2s      1        1
# 9   https://www.paypal.com/cgi-bin/webscr?cmd=_s-x...      3        1
# 10                        https://www.thehotline.org/      1        1
# 11                             www.haveitalldaily.com      1        1
# ...

# %%
df_videos_dec_urls_1_link_ith_users_count["n_urls"] = 1

# %%
df_videos_dec_urls_1_link_ith_users_count[
    "n_urls"
] = df_videos_dec_urls_1_link_ith_users_count["n_urls"].apply(lambda x: {x})

# %%
df_videos_dec_urls_1_link_ith_users_count
# Out:
#                                                  link  count  n_users  \
# 0   https://www.change.org/p/dc-entertainment-remo...      3        3
# 1              https://www.youtube.com/c/tucosmopolis      2        2
# 2   https://www.looper.com/168440/stephen-kings-th...      2        2
# 3   https://www.nickiswift.com/15613/double-life-a...      2        2
# 4   https://www.youtube.com/channel/uc-rqty6mpskck...      1        1
# 5   https://www.youtube.com/channel/uc0rpd-lnyw6x6...      1        1
# 6   https://www.dailymail.co.uk/news/article-79667...      1        1
# 7                           https://bit.ly/mannixplus      1        1
# 8    https://www.youtube.com/watch?v=jcjwf9lafxc&t=2s      1        1
# 9   https://www.paypal.com/cgi-bin/webscr?cmd=_s-x...      3        1
# 10                        https://www.thehotline.org/      1        1
# 11                             www.haveitalldaily.com      1        1
# ...

# %% [markdown]
# <a id='more4'></a>
# #### More Than One Link
#
# ><ul>
#  <li><a href="#one4">One Link</a></li>
#  <li><a href="#more4">More Than One Link</a></li>
#
#  </ul>

# %%
df_videos_dec_urls_urls_more = df_more_than_link(df_videos_dec_urls)

# %%
df_videos_dec_urls_urls_more.head(2)
# Out:
#             id  Unnamed: 0  Unnamed: 0.1           kind  \
# 0  ht92feHGR9M          69           0.0  youtube#video
# 1  -elJS12UOnI          70           0.0  youtube#video
#
#                           etag        snippet.publishedAt  \
# 0  zNkBfCV1TBeKMnDzDWZlqnoNpVM  2020-09-08 20:15:10+00:00
# 1  mAmIq8QQtvY_jCUzbM9Wt7vbuSo  2020-11-23 04:06:35+00:00
#
#           snippet.channelId  \
# 0  UCO6cSNvOaDs-kjALLQLNhQw
# 1  UC4gD0czpXVv_LpADTSU624g
#
#                                        snippet.title  \
# 0  remove amber heard from aquaman 2 petition cou...
# 1  amber heard coming to the mcu as sue storm in ...
#
#                                  snippet.description  \
# 0  remove amber heard from aquaman 2 petition cou...
# 1  📢 new enamel pins on pre-order here - http://w...
#
#                    snippet.thumbnails.default.url  ...  \
# 0  https://i.ytimg.com/vi/ht92feHGR9M/default.jpg  ...
# 1  https://i.ytimg.com/vi/-elJS12UOnI/default.jpg  ...
#
# ...

# %%
df_videos_dec_urls_more_with_users_count = more_than_one_link_with_count(df_videos_dec_urls_urls_more,
                             "snippet.channelId",
                             "urls")

# %%
df_videos_dec_urls_more_with_users_count
# Out:
#                                                    link  count  n_users  \
# 0                                 http://bit.ly/32rc7vi     16        1
# 1                          https://youtu.be/jny-dp3lgcg     16        1
# 2                          http://www.shopclownfish.com      2        1
# 3                 https://www.youtube.com/c/clownfishtv      3        1
# 4     https://www.youtube.com/channel/uchlb7rolzvap0...      3        1
# ...                                                 ...    ...      ...
# 1964          https://plus.google.com/+somoytvnetupdate      1        1
# 1965            http://www.youtube.com/somoytvnetupdate      1        1
# 1966               http://www.facebook.com/somoynews.tv      1        1
# 1967                     http://www.twitter.com/somoytv      1        1
# 1968         https://www.instagram.com/valensinfiltro_/      1        1
#
#                            users   n_urls
# 0     {UCO6cSNvOaDs-kjALLQLNhQw}      {2}
# ...

# %%
df_videos_dec_urls_with_users_count = pd.concat(
    [
        df_videos_dec_urls_1_link_ith_users_count,
        df_videos_dec_urls_more_with_users_count,
    ]
).sort_values("count", ascending=False)

# %%
df_videos_dec_urls_with_users_count.to_csv(
    saving + "df_videos_dec_urls_with_users_count.csv", index=False
)
