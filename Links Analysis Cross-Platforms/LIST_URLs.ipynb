# %%
import pandas as pd

# %%
saving = "URLs_Lists/"

# %%
def saving_list(df, column, name):
    with open(saving + f"{name}.txt", "w") as f:
        f.write(str(list(df[column].values)))

# %% [markdown]
# ## top interacted data

# %%
# load 4 months data
df_top_interacted_4_months = pd.read_csv("Top_Interacted/Data/_all_4_months.csv")
display(df_top_interacted_4_months.head(2), df_top_interacted_4_months.shape[0])
# Out:
#                                           shared_url  \
# 0  https://www.youtube.com/watch?v=HIShWZkr0hs&li...
# 1  https://www.youtube.com/watch?v=-AP5Y791RN4&li...
#
#                                         id/url  \
# 0  https://www.youtube.com/watch?v=A1kOXoxgt18
# 1  https://www.youtube.com/watch?v=A1kOXoxgt18
#
#                                                 text   n_likes       total  \
# 0  the day olive was born... 1 million subscriber...  154907.0  14885900.0
# 1  the day olive was born... 1 million subscriber...  154907.0  14885900.0
#
#                       url_id  media_id  n_replies  score    n_views  \
# 0  youtube_videos_4_months_0       NaN        NaN    NaN  7271086.0
# 1  youtube_videos_4_months_0       NaN        NaN    NaN  7271086.0
#
#    n_dislikes  n_favorites  n_comments platform
# 0      4605.0          0.0     12352.0  youtube
# 1      4605.0          0.0     12352.0  youtube
# 561

# %%
saving_list(df_top_interacted_4_months, "shared_url", "top_interacted_4_months")

# %%
df_top_interacted_dec = pd.read_csv("Top_Interacted/Data/_all_dec.csv")
df_top_interacted_dec.shape[0]
# Out:
# 598

# %%
saving_list(df_top_interacted_dec, "shared_url", "top_interacted_dec")

# %% [markdown]
# ## top shared

# %%
# load 4 months data
df_top_shared_4_months = pd.read_csv("Top_Shared/Data/_top_shared_4_months_all_platforms.csv")
display(df_top_shared_4_months.head(2), df_top_shared_4_months.shape[0])
# Out:
#    Unnamed: 0                                         shared_url  n_shared  \
# 0           0         https://www.instagram.com/amberryphoeberry         1
# 1           1  https://www.roblox.com/groups/3857126/Amberry-...         1
#
#    from_n_users                         users n_urls platform     from  \
# 0             1  {'UCxnYiv7s4698GRIlGE1_T7g'}    {7}  youtube  comment
# 1             1  {'UCxnYiv7s4698GRIlGE1_T7g'}    {7}  youtube  comment
#
#                                         id/url  \
# 0  https://www.youtube.com/watch?v=A1kOXoxgt18
# 1  https://www.youtube.com/watch?v=A1kOXoxgt18
#
#                                                 text   n_likes       total  \
# 0  the day olive was born... 1 million subscriber...  154907.0  14885900.0
# 1  the day olive was born... 1 million subscriber...  154907.0  14885900.0
#
#                       url_id  media_id  n_replies  score    n_views  \
# 0  youtube_videos_4_months_0       NaN        NaN    NaN  7271086.0
# 1  youtube_videos_4_months_0       NaN        NaN    NaN  7271086.0
#
#    n_dislikes  n_favorites  n_comments
# 0      4605.0          0.0     12352.0
# 1      4605.0          0.0     12352.0
# 753

# %%
saving_list(df_top_shared_4_months, "shared_url", "top_shared_4_months")

# %%
# load dec data
df_top_shared_dec = pd.read_csv("Top_Shared/Data/_top_shared_dec_all_platforms.csv")
display(df_top_shared_dec[16:], df_top_shared_dec.shape[0])
# Out:
#      Unnamed: 0                                         shared_url  n_shared  \
# 16           16           https://www.facebook.com/madisonellebeer         1
# 17           17              https://www.instagram.com/madisonbeer         1
# 18           18                 https://madisonbeer.lnk.to/selfish         1
# 19           19                    https://twitter.com/madisonbeer         1
# 20           20        https://www.youtube.com/watch?v=-t_pzplyvag         1
# ..          ...                                                ...       ...
# 896         896  https://www.change.org/p/united-nations-remove...         1
# 897         897  https://www.change.org/p/united-nations-remove...         4
# 898         898  https://www.change.org/p/united-nations-remove...         4
# 899         899  https://www.change.org/p/the-walt-disney-compa...         1
# 900         900  https://www.change.org/p/united-nations-remove...         4
#
#      from_n_users                          users n_urls platform  \
# 16              1   {'UCniqtXw3nZho_0HEO5IBqvg'}    {4}  youtube
# 17              1   {'UCniqtXw3nZho_0HEO5IBqvg'}    {4}  youtube
# 18              1   {'UCniqtXw3nZho_0HEO5IBqvg'}    {4}  youtube
# 19              1   {'UCniqtXw3nZho_0HEO5IBqvg'}    {4}  youtube
# 20              1  ('UCTWv3oYrqh_DNAtr8Hm_zGw',)    {1}  youtube
# ..            ...                            ...    ...      ...
# 896             1                  (1048865725,)    {1}   change
# 897             1                   {1048865725}    {2}   change
# 898             1                   {1048865725}    {2}   change
# 899             1                  (1167331579,)    {1}   change
# 900             1                   {1048865725}    {2}   change
#
#                  from                                       id/url  \
# 16            comment  https://www.youtube.com/watch?v=978iHuFKfS4
# 17            comment  https://www.youtube.com/watch?v=978iHuFKfS4
# 18            comment  https://www.youtube.com/watch?v=978iHuFKfS4
# 19            comment  https://www.youtube.com/watch?v=978iHuFKfS4
# 20            comment  https://www.youtube.com/watch?v=uVfBxa57Kno
# ..                ...                                          ...
# 896  petition_comment                                     14094292
# 897  petition_comment                                     14094292
# 898  petition_comment                                     14094292
# 899  petition_comment                                     25829282
# 900  petition_comment                                     22874214
#
#                                                   text    n_likes       total  \
# 16             madison beer - selfish (official video)  1227003.0  43830270.0
# 17             madison beer - selfish (official video)  1227003.0  43830270.0
# 18             madison beer - selfish (official video)  1227003.0  43830270.0
# 19             madison beer - selfish (official video)  1227003.0  43830270.0
# 20   she really needed our help, but it was too late..   560922.0  21254517.0
# ..                                                 ...        ...         ...
# 896  There's another new similar petition by DV sur...        0.0         0.0
# 897  Another similar petition, please sign:\n\n<a h...        0.0         0.0
# 898  Another similar petition, please sign:\n\n<a h...        0.0         0.0
# 899  Johnny Depp deserves to get his career back. H...        0.0         0.0
# 900  New petition against Amber Heard, please sign:...        0.0         0.0
#
#                               url_id  media_id  n_replies  score     n_views  \
# 16              youtube_videos_dec_1       NaN        NaN    NaN  42540987.0
# 17              youtube_videos_dec_1       NaN        NaN    NaN  42540987.0
# 18              youtube_videos_dec_1       NaN        NaN    NaN  42540987.0
# 19              youtube_videos_dec_1       NaN        NaN    NaN  42540987.0
# 20              youtube_videos_dec_2       NaN        NaN    NaN  20612790.0
# ..                               ...       ...        ...    ...         ...
# 896  change_petition_comments_dec_12       NaN        NaN    NaN         NaN
# 897  change_petition_comments_dec_13       NaN        NaN    NaN         NaN
# 898  change_petition_comments_dec_13       NaN        NaN    NaN         NaN
# 899  change_petition_comments_dec_15       NaN        NaN    NaN         NaN
# 900  change_petition_comments_dec_14       NaN        NaN    NaN         NaN
#
#      n_dislikes  n_favorites  n_comments
# 16      21590.0          0.0     40690.0
# 17      21590.0          0.0     40690.0
# 18      21590.0          0.0     40690.0
# 19      21590.0          0.0     40690.0
# 20      24533.0          0.0     56272.0
# ..          ...          ...         ...
# 896         NaN          NaN         NaN
# 897         NaN          NaN         NaN
# 898         NaN          NaN         NaN
# 899         NaN          NaN         NaN
# 900         NaN          NaN         NaN
#
# [885 rows x 20 columns]
# 901

# %%
from pandas import option_context

with option_context('display.max_colwidth', 400):
    display(df_top_shared_dec[["shared_url", "text"]][20:])
# Out:
#                                                                                                                                                                                                                                                                        shared_url  \
# 20                                                                                                                                                                                                                                    https://www.youtube.com/watch?v=-t_pzplyvag
# 21                                                                                                                                                                                                                                  http://supercell.helpshift.com/a/brawl-stars/
# 22                                                                                                                                                                                                                                                      https://supr.cl/playbrawl
# 23                                                                                                                                                                                                                                        http://supercell.com/en/privacy-policy/
# 24                                                                                                                                                                                                                                               http://supercell.com/en/parents/
# ..                                                                                                                                                                                                                                                                            ...
# 896                                                                                                                                                    https://www.change.org/p/united-nations-remove-amber-heard-as-a-spokesperson-for-harry-walker-agency-for-domestic-violence
# 897         https://www.change.org/p/united-nations-remove-amber-heard-as-a-spokesperson-for-harry-walker-agency-for-domestic-violence?utm_content=cl_sharecopy_26528188_en-US%3A3&recruiter=1048865725&utm_source=share_petition&utm_medium=copylink&utm_campaign=share_petition
# 898         https://www.change.org/p/united-nations-remove-amber-heard-as-a-spokesperson-for-harry-walker-agency-for-domestic-violence?utm_content=cl_sharecopy_26528188_en-US%3A3&recruiter=1048865725&utm_source=share_petition&utm_medium=copylink&utm_campaign=share_petition
# 899  https://www.change.org/p/the-walt-disney-company-pirates-of-the-caribbean-6-with-johnny-depp-as-captain-jack-sparrow?recruiter=1167331579&recruited_by_id=26e267d0-3669-11eb-9277-ed5517335b25&utm_source=share_petition&utm_medium=copylink&utm_campaign=petition_dashboard
# 900         https://www.change.org/p/united-nations-remove-amber-heard-as-a-spokesperson-for-harry-walker-agency-for-domestic-violence?utm_content=cl_sharecopy_26528188_en-US%3A3&recruiter=1048865725&utm_source=share_petition&utm_medium=copylink&utm_campaign=share_petition
#
#                                                                                                                                                                                                                                                                                                                                        text
# 20                                                                                                                                                                                                                                                                                        she really needed our help, but it was too late..
# 21                                                                                                                                                                                                                                                                                          brawl stars animation - amber - this is fine...
# 22                                                                                                                                                                                                                                                                                          brawl stars animation - amber - this is fine...
# 23                                                                                                                                                                                                                                                                                          brawl stars animation - amber - this is fine...
# 24                                                                                                                                                                                                                                                                                          brawl stars animation - amber - this is fine...
# ..                                                                                                                                                                                                                                                                                                                                      ...
# 896                                                                                            There's another new similar petition by DV survivors for the same cause, I really hope we can have them listen\n\nhttps://www.change.org/p/united-nations-remove-amber-heard-as-a-spokesperson-for-harry-walker-agency-for-domestic-violence
# 897                                                                                                                                                                                                              Another similar petition, please sign:\n\n<a href="http://chng.it/HYYZppLLgb" rel="nofollow">http://chng.it/HYYZppLLgb</a>
# 898                                                                                                                                                                                                              Another similar petition, please sign:\n\n<a href="http://chng.it/HYYZppLLgb" rel="nofollow">http://chng.it/HYYZppLLgb</a>
# 899  Johnny Depp deserves to get his career back. He is one of the biggest and talented actors of the century. If you love also his role as Captain Jack Sparrow please sign this petition: http://chng.it/qfVpYf2T\nBring Johnny Depp back as Captain Jack Sparrow in Pirates of the Caribbean 6 is the name of the petition. Please sign!
# 900                                                                                                                                                                                                      New petition against Amber Heard, please sign:\n\n<a href="http://chng.it/HYYZppLLgb" rel="nofollow">http://chng.it/HYYZppLLgb</a>
#
# [881 rows x 2 columns]

# %%
saving_list(df_top_shared_dec[20:], "shared_url", "top_shared_dec")

# %%
df_top_shared_dec[df_top_shared_dec.text.str.lower().str.contains(" amber h")]
# Out:
#      Unnamed: 0                                         shared_url  n_shared  \
# 28           28                       https://youtu.be/hwkb80xzdus         1
# 49           49       https://www.patreon.com/observeentertainment         1
# 50           50             https://teespring.com/stores/observe-4         1
# 51           51                http://www.audibletrial.com/observe         1
# 52           52  http://www.youtube.com/c/observewithlogan?sub_...         1
# ..          ...                                                ...       ...
# 892         892  https://www.latimes.com/entertainment/gossip/l...        16
# 893         893  https://www.latimes.com/entertainment/gossip/l...        16
# 894         894  https://www.change.org/p/united-nations-remove...         4
# 895         895  https://www.change.org/p/dc-entertainment-remo...         1
# 900         900  https://www.change.org/p/united-nations-remove...         4
#
#      from_n_users                                            users  \
# 28              1                    ('UCAIycRkUrsSP73CZIYFLCWw',)
# 49              1                     {'UCzMvqwt21xqm7Fg5Uo3lsRQ'}
# 50              1                     {'UCzMvqwt21xqm7Fg5Uo3lsRQ'}
# 51              1                     {'UCzMvqwt21xqm7Fg5Uo3lsRQ'}
# 52              1                     {'UCzMvqwt21xqm7Fg5Uo3lsRQ'}
# ..            ...                                              ...
# 892             4  {948054032, 1129808400, 1136503772, 1081693988}
# 893             4  {948054032, 1129808400, 1136503772, 1081693988}
# 894             1                                     {1048865725}
# 895             1                                      (95107240,)
# 900             1                                     {1048865725}
#
#          n_urls platform              from  \
# 28          {1}  youtube           comment
# 49          {8}  youtube           comment
# 50          {8}  youtube           comment
# 51          {8}  youtube           comment
# 52          {8}  youtube           comment
# ..          ...      ...               ...
# 892  {8, 10, 4}   change  petition_comment
# 893  {8, 10, 4}   change  petition_comment
# 894         {2}   change  petition_comment
# 895         {1}   change  petition_comment
# 900         {2}   change  petition_comment
#
#                                           id/url  \
# 28   https://www.youtube.com/watch?v=h-wpBkiMKd0
# 49   https://www.youtube.com/watch?v=hQFFm_X2lps
# 50   https://www.youtube.com/watch?v=hQFFm_X2lps
# 51   https://www.youtube.com/watch?v=hQFFm_X2lps
# 52   https://www.youtube.com/watch?v=hQFFm_X2lps
# ..                                           ...
# 892                                     14521372
# 893                                     14521372
# 894                                     22874214
# 895                                     26152026
# 900                                     22874214
#
#                                                   text   n_likes      total  \
# 28   caso de johnny depp y amber heard: amber es at...   98986.0  9525759.0
# 49   body language analyst reacts to amber heard's ...  131103.0  2914030.0
# 50   body language analyst reacts to amber heard's ...  131103.0  2914030.0
# 51   body language analyst reacts to amber heard's ...  131103.0  2914030.0
# 52   body language analyst reacts to amber heard's ...  131103.0  2914030.0
# ..                                                 ...       ...        ...
# 892  I absolutely support women in film and for dir...       1.0        1.0
# 893  I absolutely support women in film and for dir...       1.0        1.0
# 894  New petition against Amber Heard, please sign:...       0.0        0.0
# 895  KAITLYN HAESTIER-KAITLYN HAESTIER\nPlease note...       0.0        0.0
# 900  New petition against Amber Heard, please sign:...       0.0        0.0
#
#                               url_id  media_id  n_replies  score    n_views  \
# 28              youtube_videos_dec_4       NaN        NaN    NaN  9402370.0
# 49              youtube_videos_dec_8       NaN        NaN    NaN  2762734.0
# 50              youtube_videos_dec_8       NaN        NaN    NaN  2762734.0
# 51              youtube_videos_dec_8       NaN        NaN    NaN  2762734.0
# 52              youtube_videos_dec_8       NaN        NaN    NaN  2762734.0
# ..                               ...       ...        ...    ...        ...
# 892   change_petition_comments_dec_9       NaN        NaN    NaN        NaN
# 893   change_petition_comments_dec_9       NaN        NaN    NaN        NaN
# 894  change_petition_comments_dec_14       NaN        NaN    NaN        NaN
# 895  change_petition_comments_dec_11       NaN        NaN    NaN        NaN
# 900  change_petition_comments_dec_14       NaN        NaN    NaN        NaN
#
#      n_dislikes  n_favorites  n_comments
# 28       6188.0          0.0     18215.0
# 49       2611.0          0.0     17582.0
# 50       2611.0          0.0     17582.0
# 51       2611.0          0.0     17582.0
# 52       2611.0          0.0     17582.0
# ..          ...          ...         ...
# 892         NaN          NaN         NaN
# 893         NaN          NaN         NaN
# 894         NaN          NaN         NaN
# 895         NaN          NaN         NaN
# 900         NaN          NaN         NaN
#
# [270 rows x 20 columns]
