# %%
import pandas as pd

# %%
df_tweets_dec_morelinks = pd.read_csv("df_tweets_dec_morelinks.csv")
df_tweets_dec_onelink = pd.read_csv("df_tweets_dec_onelink.csv")

# %%
df_tweets_dec_morelinks
# Out:
#                   id_str                 created_at  \
# 0    1338252357453443075  2020-12-13 22:40:00+00:00
# 1    1338262424063860738  2020-12-13 23:20:00+00:00
# 2    1338011906116886537  2020-12-13 06:44:32+00:00
# 3    1338166244755734530  2020-12-13 16:57:49+00:00
# 4    1338118831647158279  2020-12-13 13:49:25+00:00
# ..                   ...                        ...
# 939  1335602482823786497  2020-12-06 15:10:20+00:00
# 940  1335664203433189376  2020-12-06 19:15:36+00:00
# 941  1335660032705302534  2020-12-06 18:59:01+00:00
# 942  1335465464802258946  2020-12-06 06:05:53+00:00
# 943  1335464707902369792  2020-12-06 06:02:52+00:00
#
#                                              full_text          user.id_str  \
# 0    Johnny Depp exige a Warner Bros. sacar a Amber...            244218738
# 1    Johnny Depp exige a Warner Bros. sacar a Amber...            415155226
# 2    Petition · DC Entertainment: Remove Amber Hear...            525558173
# ...

# %%
df_tweets_dec_onelink["unshorten_urls"] = df_tweets_dec_onelink["unshorten_urls"] .apply(lambda x: [x])

# %%
df_tweets_dec_onelink
# Out:
#              id_str                 created_at  \
# 0      1.338250e+18  2020-12-13 22:43:30+00:00
# 1      1.338250e+18  2020-12-13 22:43:23+00:00
# 2      1.338250e+18  2020-12-13 22:36:59+00:00
# 3      1.338250e+18  2020-12-13 22:35:31+00:00
# 4      1.338250e+18  2020-12-13 22:34:26+00:00
# ...             ...                        ...
# 23021  1.335460e+18  2020-12-06 05:54:59+00:00
# 23022  1.335460e+18  2020-12-06 05:53:27+00:00
# 23023  1.335460e+18  2020-12-06 05:47:44+00:00
# 23024  1.335460e+18  2020-12-06 05:45:32+00:00
# 23025  1.335460e+18  2020-12-06 05:41:52+00:00
#
#                                                full_text   user.id_str  \
# 0      It Is just me? Or everybody does when sees Joh...  1.327950e+18
# 1      I reckon the old boy is behind all of this.\nP...  1.329500e+18
# 2      Yesterday I went to a store and asked for the ...  1.231252e+09
# 3      @feral_feminist @Zephyrdust8 @win_confidante @...  1.302990e+18
# ...

# %%
df_tweets_dec_morelinks.rename(columns={"shorten_link": "unshorten_urls"}, inplace=True)

# %%
df_tweets_dec_onelink.drop(columns="one_url", inplace=True)

# %%
df_tweets_dec_urls = pd.concat([df_tweets_dec_onelink, df_tweets_dec_morelinks])

# %%
df_tweets_dec_urls.to_csv("../df_tweets_dec_urls.csv", index=False)
