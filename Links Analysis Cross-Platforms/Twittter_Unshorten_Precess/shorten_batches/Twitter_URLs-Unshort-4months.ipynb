# %%
from helpers import (
    URLS,
    get_urls,
    urls_df,
    one_link_df,
    one_link_urls,
    one_link_urls_with_count_,
    df_more_than_link, more_than_one_link_with_count_
)
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Twitter Data URLs

# %%
twitter_path =  "../Twitter/Unshorten_Data/filtering/"

# %% [markdown]
# ### 4 Months
# <a id='12'></a>
#
#
# ><ul>
#  <li><a href="#one12">One Link</a></li>
#  <li><a href="#more12">More Than One Link</a></li>
#
#  </ul>

# %%
df_tweets_4_urls = pd.read_csv(twitter_path + "df_tweets_4_months_one.csv")

# %%
df_tweets_4_urls
# Out:
#                     id_str                 created_at  \
# 0      1345358697959047168  2021-01-02 13:18:03+00:00
# 1      1345357307115307009  2021-01-02 13:12:32+00:00
# 2      1345357193709826052  2021-01-02 13:12:05+00:00
# 3      1345356222191591424  2021-01-02 13:08:13+00:00
# 4      1345354652930494465  2021-01-02 13:01:59+00:00
# ...                    ...                        ...
# 62949  1379904862549381120  2021-04-07 21:12:11+00:00
# 62950  1379904853770657802  2021-04-07 21:12:09+00:00
# 62951  1379904292358914050  2021-04-07 21:09:55+00:00
# 62952  1379903624248188932  2021-04-07 21:07:16+00:00
# 62953  1379903143274803204  2021-04-07 21:05:21+00:00
#
#                                                full_text lang  \
# 0      @_missyc97_ 2021 to Amber Heard.😂 https://t.co...   en
# 1      When Amber Heard is in the mood but her mortal...   en
# 2      @kathygriffin These didn’t age well. Oh Kathy ...   en
# 3      Amores, hoje vai rolar mais uma #DeppMovieNigh...   pt
# ...

# %%
df_tweets_4_urls = df_tweets_4_urls[df_tweets_4_urls["user.statuses_count"] > 500000]

# %%
df_tweets_4_urls.to_csv("URLs_Data/Twitter/" + "df_tweets_4_urls.csv", index=False)

# %%
df_tweets_4_urls.rename(columns={"urls": "shorten_urls",
                                  "unshorten_urls": "urls"}, inplace=True)

# %%
df_tweets_4_urls["urls"]
# Out:
# 0        https://twitter.com/f_liono/status/13453586979...
# 1        https://twitter.com/danblock4/status/134535730...
# 2        https://twitter.com/MsDizzyGillespi/status/134...
# 3        https://twitter.com/PrinConsuella_/status/1345...
# 4        https://twitter.com/DeppUruguay/status/1345354...
#                                ...
# 62949    https://twitter.com/jayneb68910675/status/1379...
# 62950    https://twitter.com/montselech/status/13799048...
# 62951    https://www.youtube.com/watch?v=waXKykBTrQI&fe...
# 62952    https://twitter.com/jayneb68910675/status/1379...
# 62953    https://twitter.com/Astartiel/status/137989817...
# Name: urls, Length: 62954, dtype: object

# %% [markdown]
# <a id='one12'></a>
# #### One Link
#
# ><ul>
#  <li><a href="#one12">One Link</a></li>
#  <li><a href="#more12">More Than One Link</a></li>
#
#  </ul>

# %%
df_tweets_4_urls_1_link = df_tweets_4_urls

# %%
df_tweets_4_urls_1_link.head(1)
# Out:
#                 id_str                 created_at  \
# 0  1345358697959047168  2021-01-02 13:18:03+00:00
#
#                                            full_text lang  \
# 0  @_missyc97_ 2021 to Amber Heard.😂 https://t.co...   en
#
#    in_reply_to_status_id_str  in_reply_to_user_id entities.hashtags  \
# 0               1.345358e+18         1.083787e+18                []
#
#                                       entities.media entities.symbols  \
# 0  [{'original_info': {'width': 296, 'focus_rects...               []
#
#   entities.urls  ... user.name user.screen_name  \
# 0            []  ...     Liono          f_liono
#
#                              user.profile_banner_url  \
# 0  https://pbs.twimg.com/profile_banners/12438150...
#
#                               user.profile_image_url user.statuses_count  \
# 0  http://pbs.twimg.com/profile_images/1384133945...             28996.0
#
#   user.url  user.verified                 shorten_urls n_urls  \
# ...

# %%
list_tweets_4_urls_1_link = one_link_urls(df_tweets_4_urls_1_link)

# %%
df_tweets_4_urls_1_link
# Out:
#                     id_str                 created_at  \
# 0      1345358697959047168  2021-01-02 13:18:03+00:00
# 1      1345357307115307009  2021-01-02 13:12:32+00:00
# 2      1345357193709826052  2021-01-02 13:12:05+00:00
# 3      1345356222191591424  2021-01-02 13:08:13+00:00
# 4      1345354652930494465  2021-01-02 13:01:59+00:00
# ...                    ...                        ...
# 62949  1379904862549381120  2021-04-07 21:12:11+00:00
# 62950  1379904853770657802  2021-04-07 21:12:09+00:00
# 62951  1379904292358914050  2021-04-07 21:09:55+00:00
# 62952  1379903624248188932  2021-04-07 21:07:16+00:00
# 62953  1379903143274803204  2021-04-07 21:05:21+00:00
#
#                                                full_text lang  \
# 0      @_missyc97_ 2021 to Amber Heard.😂 https://t.co...   en
# 1      When Amber Heard is in the mood but her mortal...   en
# 2      @kathygriffin These didn’t age well. Oh Kathy ...   en
# 3      Amores, hoje vai rolar mais uma #DeppMovieNigh...   pt
# ...

# %%
df_tweets_4_urls_1_link.columns
# Out:
# Index(['id_str', 'created_at', 'full_text', 'lang',
#        'in_reply_to_status_id_str', 'in_reply_to_user_id', 'entities.hashtags',
#        'entities.media', 'entities.symbols', 'entities.urls',
#        'entities.user_mentions', 'source', 'quoted_status.id_str',
#        'quoted_status.created_at', 'quoted_status.full_text',
#        'quoted_status.lang', 'quoted_status.in_reply_to_status_id_str',
#        'quoted_status.in_reply_to_user_id', 'quoted_status.entities.hashtags',
#        'quoted_status.entities.media', 'quoted_status.entities.symbols',
#        'quoted_status.entities.urls', 'quoted_status.entities.user_mentions',
#        'quoted_status.user.id_str', 'quoted_status.source', 'user.id_str',
#        'user.created_at', 'user.description', 'user.followers_count',
#        'user.friends_count', 'user.lang', 'user.location', 'user.name',
#        'user.screen_name', 'user.profile_banner_url', 'user.profile_image_url',
# ...

# %%
df_tweets_4_urls_1_link = df_tweets_4_urls_1_link[df_tweets_4_urls_1_link["user.statuses_count"] > 500000]

# %%
df_tweets_4_urls_1_link.rename(columns={"urls": "url"}, inplace=True)

# %%
df_tweets_4_urls_1_link_ith_users_count = one_link_urls_with_count_(
    df_tweets_4_urls_1_link, user_column="user.id_str", url_column="url"
)

# %%
df_tweets_4_urls_1_link_ith_users_count.head(2)
# Out:
#                                                 link  count  n_users  \
# 0  https://www.justjared.com/2021/04/16/johnny-de...      2        2
# 1  https://hollywoodlife.com/2021/04/16/johnny-de...      2        2
#
#                          users
# 0  (2780443681.0, 762349027.0)
# 1  (762349027.0, 2544914191.0)

# %%
# save data
# df_tweets_4_urls_1_link_ith_users_count.to_csv(
#     "../Twitter/Unshorten_Data/" + "df_tweets_4_months_urls_1_link.csv", index=False,
# )

# %%
df_tweets_4_urls_1_link_ith_users_count["n_urls"] = 1
df_tweets_4_urls_1_link_ith_users_count[
    "n_urls"
] = df_tweets_4_urls_1_link_ith_users_count["n_urls"].apply(lambda x: {x})

# %% [markdown]
# <a id='more12'></a>
# #### More Than One Link
#
# ><ul>
#  <li><a href="#one12">One Link</a></li>
#  <li><a href="#more12">More Than One Link</a></li>
#
#  </ul>

# %%
df_tweets_4_urls_more = pd.read_csv(twitter_path + "df_tweets_4_months_more.csv")

# %%
df_tweets_4_urls_more.rename(columns={"urls": "short_urls", "unshortened_urls": "urls"}, inplace=True)

# %%
import ast

# %%
df_tweets_4_urls_more["urls"] = df_tweets_4_urls_more.urls.apply(lambda x: ast.literal_eval(x))

# %%
df_tweets_4_urls_more_with_users_count = more_than_one_link_with_count_(df_tweets_4_urls_more,
                             "user.id_str",
                             "urls")

# %%
# df_tweets_4_urls_more_with_users_count.to_csv(
#     "../Twitter/Unshorten_Data/"
#     + "df_tweets_4_urls_more.csv",
#     index=False,
# )

# %%
# df_tweets_4_urls_more_with_users_count

# %%
df_tweets_4_urls_more_with_users_count
# Out:
#                                                    link  count  n_users  \
# 0                    https://at-angys.de/jd/survey.html      8        1
# 1     https://twitter.com/JDsupportSurvey/status/134...      1        1
# 2                 https://www.instagram.com/jdforeveruk      1        1
# 3     https://twitter.com/JDForeverUK/status/1353271...      1        1
# 4     https://heraldodemexico.com.mx/espectaculos/20...      1        1
# ...                                                 ...    ...      ...
# 3280  https://www.youtube.com/watch?v=yQuC3ZMqwCk&fe...      1        1
# 3281  https://twitter.com/StevieJRaw/status/13796876...      1        1
# 3282                          https://ow.ly/rVul50EhetQ      1        1
# 3283  https://twitter.com/marshmyers/status/13795999...      1        1
# 3284  https://twitter.com/cinepop/status/13795864864...      1        1
#
#                          users n_urls
# 0      {1.338967066469167e+18}    {2}
# ...

# %%
df_tweets_4_months_urls_with_users_count = pd.concat(
    [
        df_tweets_4_urls_1_link_ith_users_count,
        df_tweets_4_urls_more_with_users_count,
    ]
).sort_values("count", ascending=False)

# %%
df_tweets_4_months_urls_with_users_count
# Out:
#                                                    link  count  n_users  \
# 287                                    connection error   2003      480
# 495         https://www.youtube.com/watch?v=ny3A4kBbUvE    146        1
# 496   https://fandango.com/city-of-lies-212058/movie...    146        1
# 238   https://www.lasopa.com/carrusel/bye-bye-amber-...     74        1
# 125   https://www.lasopa.com/escandalos/amber-heard-...     52        1
# ...                                                 ...    ...      ...
# 1092        https://www.youtube.com/watch?v=nthKIiDEf5g      1        1
# 1093  https://twitter.com/GretaAurora/status/1376922...      1        1
# 142   https://www.eonline.com/news/1225154/amber-hea...      1        1
# 1095               https://en.everybodywiki.com/Prabook      1        1
# 3284  https://twitter.com/cinepop/status/13795864864...      1        1
#
#                                                   users              n_urls
# ...

# %%
df_tweets_4_months_urls_with_users_count = df_tweets_4_months_urls_with_users_count[
    df_tweets_4_months_urls_with_users_count.link != "connection error"
]

# %%
saving = "URLs_Data/Twitter/"

# %%
df_tweets_4_months_urls_with_users_count.to_csv(
    saving + "df_tweets_4_months_urls_with_users_count.csv", index=False
)
