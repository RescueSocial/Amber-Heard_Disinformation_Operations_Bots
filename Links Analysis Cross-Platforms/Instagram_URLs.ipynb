# %%
from helpers import (
    URLS,
    get_urls,
    urls_df,
    one_link_df,
    one_link_urls,
    one_link_urls_with_count_,
    df_more_than_link, more_than_one_link_with_count_
)
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Instagram Data URLs

# %%
instagram_filter_path =  "URLs_Data/Instagram/"

# %% [markdown]
# ## Table of Contents
# <ul>
# <li><a href="#Comments"><b>Comments</b></a></li>
# <li><a href="#Posts">Posts</a></li>
# </ul>

# %% [markdown]
# <a id='Comments'></a>
#
# ## Comments
#
#
# ><ul>
#  <li><a href="#4">4 Months</a></li>
#  <li><a href="#12">December</a></li>
#
#  </ul>

# %%
data_path = "../Filtered Data/Instagram/CSV/"

# %%
df_comments_4_months = pd.read_csv(data_path + "comments_4_months.csv")

# %%
df_comments_4_months.head(1)
# Out:
#   message            timestamp            id  n_replies  n_likes  \
# 0    ❤️❤️  2021-04-06 20:05:29  1.787907e+16        0.0      0.0
#
#        media_id  in_reply_to       from.id  from.username from.is_verified  \
# 0  2.546044e+18          NaN  5.756303e+09  alsaifimuayad            False
#
#                                   from.url from.profile_pic
# 0  https://www.instagram.com/alsaifimuayad              NaN

# %%
df_comments_dec = pd.read_csv(data_path + "comments_dec.csv")

# %% [markdown]
# ### 4 Months
# <a id='4'></a>
#
#
# ><ul>
#  <li><a href="#one4">One Link</a></li>
#  <li><a href="#more4">More Than One Link</a></li>
#
#  </ul>

# %%
df_comments_4_months["urls"] = df_comments_4_months.message.apply(lambda x: get_urls(x))

# %%
df_comments_4_months["n_urls"] = df_comments_4_months.urls.apply(lambda x: len(x))

# %%
df_comments_4_months_urls = urls_df(df_comments_4_months)

# %%
df_comments_4_months_urls.head(10)
# Out:
#                                              message            timestamp  \
# 0  Тебя я встретил — и пропал.\nВ любви к тебе я ...  2021-03-05 13:23:00
# 1  There you are! I was searching this beach high...  2021-01-16 13:08:28
# 2  https://m.facebook.com/story.php?story_fbid=13...  2021-01-19 02:38:24
# 3  Please subscribe my channel https://youtube.co...  2021-01-17 17:13:19
# 4  https://www.cbr.com/johnny-depp-amber-heard-po...  2021-04-19 15:09:15
# 5  https://youtube.com/channel/UCq16Kp_3EgFYvCGeD...  2021-03-02 16:07:31
# 6                       https://youtu.be/oEaUIWJoX34  2021-02-17 22:42:18
# 7  https://instagram.com/johnny.depp.is.a.bully?i...  2021-03-26 01:32:02
# 8  Ты царевна моя,\nИ готов я пройти\nЭту землю к...  2021-03-05 15:10:30
# 9  https://youtu.be/lLT-vCRhc0E. 😱. https://youtu...  2021-01-18 19:56:06
#
#              id  n_replies  n_likes      media_id  in_reply_to       from.id  \
# ...

# %%
# save data
df_comments_4_months_urls.to_csv(
    instagram_filter_path + "df_comments_4_months_urls.csv", index=False
)

# %% [markdown]
# <a id='one4'></a>
# #### One Link
#
# ><ul>
#  <li><a href="#one4">One Link</a></li>
#  <li><a href="#more4">More Than One Link</a></li>
#
#  </ul>

# %%
df_comments_4_months_urls_1_link = one_link_df(df_comments_4_months_urls)

# %%
df_comments_4_months_urls_1_link.head(1)
# Out:
#                                              message            timestamp  \
# 0  Тебя я встретил — и пропал.\nВ любви к тебе я ...  2021-03-05 13:23:00
#
#              id  n_replies  n_likes      media_id  in_reply_to       from.id  \
# 0  1.819656e+16        0.0      0.0  2.522479e+18          NaN  2.702826e+10
#
#    from.username from.is_verified                                 from.url  \
# 0  mir_o_slav_71            False  https://www.instagram.com/mir_o_slav_71
#
#   from.profile_pic                                               urls  n_urls  \
# 0              NaN  [http://lovefond.ru/stihi/o-lyubvi/lyubimoy-de...       1
#
#                                                  url
# 0  http://lovefond.ru/stihi/o-lyubvi/lyubimoy-dev...

# %%
list_comments_4_months_urls_1_link = one_link_urls(df_comments_4_months_urls_1_link)

# %%
df_comments_4_months_urls_1_link.head(1)
# Out:
#                                              message            timestamp  \
# 0  Тебя я встретил — и пропал.\nВ любви к тебе я ...  2021-03-05 13:23:00
#
#              id  n_replies  n_likes      media_id  in_reply_to       from.id  \
# 0  1.819656e+16        0.0      0.0  2.522479e+18          NaN  2.702826e+10
#
#    from.username from.is_verified                                 from.url  \
# 0  mir_o_slav_71            False  https://www.instagram.com/mir_o_slav_71
#
#   from.profile_pic                                               urls  n_urls  \
# 0              NaN  [http://lovefond.ru/stihi/o-lyubvi/lyubimoy-de...       1
#
#                                                  url
# 0  http://lovefond.ru/stihi/o-lyubvi/lyubimoy-dev...

# %%
df_comments_4_months_urls_1_link_ith_users_count = one_link_urls_with_count_(
    df_comments_4_months_urls_1_link, user_column="from.id", url_column="url"
)

# %%
df_comments_4_months_urls_1_link_ith_users_count
# Out:
#                                                   link  count  n_users  \
# 0                         https://youtu.be/uretrfMA-Io     17        8
# 1    https://www.change.org/p/walt-disney-we-want-j...      3        3
# 2    www.change.org/p/walt-disney-we-want-johnny-de...     10        2
# 3    https://mailchi.mp/e05adb114afb/pirateslifeforyou      1        1
# 4          https://www.youtube.com/watch?v=B_KgLvcWFTY      1        1
# ..                                                 ...    ...      ...
# 171                       https://youtu.be/DMezgn2SSqQ      1        1
# 172  https://www.instagram.com/mirnateomachile?r=na...      1        1
# 173                          http://chng.it/r7wxtqT8N9      2        1
# 174                          http://chng.it/9fvfm2mSb4     17        1
# 175  https://m.youtube.com/watch?v=79GX1RNB4B8&feat...      1        1
#
#                                                  users
# 0    (8576468286.0, 8993278596.0, 6355289605.0, 292...
# ...

# %%
df_comments_4_months_urls_1_link_ith_users_count["n_urls"] = 1

# %%
df_comments_4_months_urls_1_link_ith_users_count[
    "n_urls"
] = df_comments_4_months_urls_1_link_ith_users_count["n_urls"].apply(lambda x: {x})

# %% [markdown]
# <a id='more4'></a>
# #### More Than One Link
#
# ><ul>
#  <li><a href="#one4">One Link</a></li>
#  <li><a href="#more4">More Than One Link</a></li>
#
#  </ul>

# %%
df_comments_4_months_urls_more = df_more_than_link(df_comments_4_months_urls)

# %%
df_comments_4_months_urls_more.head(2)
# Out:
#                                              message            timestamp  \
# 0  https://youtu.be/lLT-vCRhc0E. 😱. https://youtu...  2021-01-18 19:56:06
# 1  Cool... love that vacation spot like who’d kno...  2021-02-04 23:34:01
#
#              id  n_replies  n_likes      media_id  in_reply_to       from.id  \
# 0  1.787584e+16        0.0      0.0  2.489460e+18          NaN  1.579422e+10
# 1  1.787397e+16        0.0      0.0  2.501514e+18          NaN  1.579422e+10
#
#   from.username from.is_verified                           from.url  \
# 0       ticetm6            False  https://www.instagram.com/ticetm6
# 1       ticetm6            False  https://www.instagram.com/ticetm6
#
#   from.profile_pic                                               urls  n_urls
# 0              NaN  [https://youtu.be/lLT-vCRhc0E, https://youtu.b...       6
# 1              NaN  [https://youtu.be/Sa7tTNA7t0Q, https://youtu.b...       3

# %%
df_comments_4_months_urls_more_link_with_users_count = more_than_one_link_with_count_(df_comments_4_months_urls_more,
                             "from.id",
                             "urls")

# %%
df_comments_4_months_urls_more_link_with_users_count
# Out:
#                                         link  count  n_users            users  \
# 0               https://youtu.be/lLT-vCRhc0E      1        1  {15794220150.0}
# 1               https://youtu.be/eeoc35OZnr8      1        1  {15794220150.0}
# 2               https://youtu.be/6HvdfJEkoa8      1        1  {15794220150.0}
# 3               https://youtu.be/vPrYKz9DZ6E      1        1  {15794220150.0}
# 4               https://youtu.be/cvWWEwM-Yz8      1        1  {15794220150.0}
# 5               https://youtu.be/Hz_JF3oM_U0      1        1  {15794220150.0}
# 6               https://youtu.be/Sa7tTNA7t0Q      1        1  {15794220150.0}
# 7               https://youtu.be/KEKNcVgYhz4      1        1  {15794220150.0}
# 8               https://youtu.be/Od3_X2XeRGo      1        1  {15794220150.0}
# 9               https://youtu.be/iaj3-avTAP8      1        1  {15794220150.0}
# 10              https://youtu.be/6xcOZghoZZY      1        1  {15794220150.0}
# ...

# %%
df_comments_4_months_urls_with_users_count = pd.concat(
    [
        df_comments_4_months_urls_1_link_ith_users_count,
        df_comments_4_months_urls_more_link_with_users_count,
    ]
).sort_values("count", ascending=False)

# %%
df_comments_4_months_urls_with_users_count.head(2)
# Out:
#                              link  count  n_users  \
# 0    https://youtu.be/uretrfMA-Io     17        8
# 174     http://chng.it/9fvfm2mSb4     17        1
#
#                                                  users n_urls
# 0    (8576468286.0, 8993278596.0, 6355289605.0, 292...    {1}
# 174                                    (2066707406.0,)    {1}

# %%
df_comments_4_months_urls_with_users_count.to_csv(
    instagram_filter_path + "df_comments_4_months_urls_with_users_count.csv", index=False
)

# %% [markdown]
# ### December
# <a id='12'></a>
#
#
# ><ul>
#  <li><a href="#one12">One Link</a></li>
#  <li><a href="#more12">More Than One Link</a></li>
#
#  </ul>

# %%
df_comments_dec["urls"] = df_comments_dec.message.apply(lambda x: get_urls(x))

# %%
df_comments_dec["n_urls"] = df_comments_dec.urls.apply(lambda x: len(x))

# %%
df_comments_dec_urls = urls_df(df_comments_dec)

# %%
df_comments_dec_urls.head(5)
# Out:
#                                              message            timestamp  \
# 0  @lmntrix24_7 https://m.ru.armeniasputnik.am/wo...  2020-12-25 05:41:10
# 1  He's been doing podcasts on youtube with infor...  2020-12-15 23:17:57
# 2  Петиция удалять Амбер Херд из Аquaman \n\nhttp...  2020-12-11 04:12:06
# 3                          http://chng.it/F4WMKk42TV  2020-12-11 04:12:17
# 4  http://chng.it/Zb2d5RBR2S  میتونین توی این لین...  2020-12-01 06:36:54
#
#              id  n_replies  n_likes      media_id   in_reply_to       from.id  \
# 0  1.796951e+16        NaN      2.0  2.469892e+18  1.786325e+16  1.279517e+09
# 1  1.812600e+16        0.0      1.0  2.453144e+18           NaN  2.238739e+09
# 2  1.814437e+16        0.0      0.0  2.460910e+18           NaN  1.095513e+09
# 3  1.817843e+16        0.0      0.0  2.460910e+18           NaN  1.095513e+09
# 4  1.785958e+16        0.0      0.0  2.453755e+18           NaN  8.405193e+09
#
#      from.username from.is_verified  \
# ...

# %%
# save data
df_comments_dec_urls.to_csv(
    instagram_filter_path + "df_comments_dec_urls.csv", index=False
)

# %% [markdown]
# <a id='one12'></a>
# #### One Link
#
# ><ul>
#  <li><a href="#one12">One Link</a></li>
#  <li><a href="#more12">More Than One Link</a></li>
#
#  </ul>

# %%
df_comments_dec_urls_1_link = one_link_df(df_comments_dec_urls)

# %%
df_comments_dec_urls_1_link.head(1)
# Out:
#                                              message            timestamp  \
# 0  @lmntrix24_7 https://m.ru.armeniasputnik.am/wo...  2020-12-25 05:41:10
#
#              id  n_replies  n_likes      media_id   in_reply_to       from.id  \
# 0  1.796951e+16        NaN      2.0  2.469892e+18  1.786325e+16  1.279517e+09
#
#   from.username from.is_verified                              from.url  \
# 0    eva_soturi              NaN  https://www.instagram.com/eva_soturi
#
#   from.profile_pic                                               urls  n_urls  \
# 0              NaN  [https://m.ru.armeniasputnik.am/world/20200203...       1
#
#                                                  url
# 0  https://m.ru.armeniasputnik.am/world/20200203/...

# %%
list_comments_dec_urls_1_link = one_link_urls(df_comments_dec_urls_1_link)

# %%
df_comments_dec_urls_1_link_ith_users_count = one_link_urls_with_count_(
    df_comments_dec_urls_1_link, user_column="from.id", url_column="url"
)

# %%
df_comments_dec_urls_1_link_ith_users_count
# Out:
#                                                   link  count  n_users  \
# 0    https://www.change.org/p/dc-entertainment-remo...     26        7
# 1    https://www.change.org/p/dc-entertainment-remo...      4        3
# 2                         https://youtu.be/uretrfMA-Io      2        2
# 3                            http://chng.it/d4wSkC9HZs     12        2
# 4    https://www.change.org/p/dc-entertainment-remo...      4        2
# ..                                                 ...    ...      ...
# 106                    https://vm.tiktok.com/ZSsbeEeW/      1        1
# 107  https://www.instagram.com/s/aGlnaGxpZ2h0OjE4MT...      1        1
# 108  https://www.instagram.com/p/CIFo0qKhalp/?igshi...      1        1
# 109        https://images.app.goo.gl/iWXssPz56qnNWbiz5      1        1
# 110                          http://chng.it/mDwQCbGGpt      3        1
#
#                                                  users
# 0    (30074255940.0, 3703701611.0, 2200653740.0, 56...
# ...

# %%
df_comments_dec_urls_1_link_ith_users_count["n_urls"] = 1
df_comments_dec_urls_1_link_ith_users_count[
    "n_urls"
] = df_comments_dec_urls_1_link_ith_users_count["n_urls"].apply(lambda x: {x})

# %%
df_comments_dec_urls_1_link_ith_users_count
# Out:
#                                                   link  count  n_users  \
# 0    https://www.change.org/p/dc-entertainment-remo...     26        7
# 1    https://www.change.org/p/dc-entertainment-remo...      4        3
# 2                         https://youtu.be/uretrfMA-Io      2        2
# 3                            http://chng.it/d4wSkC9HZs     12        2
# 4    https://www.change.org/p/dc-entertainment-remo...      4        2
# ..                                                 ...    ...      ...
# 106                    https://vm.tiktok.com/ZSsbeEeW/      1        1
# 107  https://www.instagram.com/s/aGlnaGxpZ2h0OjE4MT...      1        1
# 108  https://www.instagram.com/p/CIFo0qKhalp/?igshi...      1        1
# 109        https://images.app.goo.gl/iWXssPz56qnNWbiz5      1        1
# 110                          http://chng.it/mDwQCbGGpt      3        1
#
#                                                  users n_urls
# ...

# %% [markdown]
# <a id='more4'></a>
# #### More Than One Link
#
# ><ul>
#  <li><a href="#one4">One Link</a></li>
#  <li><a href="#more4">More Than One Link</a></li>
#
#  </ul>

# %%
df_comments_dec_urls_urls_more = df_more_than_link(df_comments_dec_urls)

# %%
df_comments_dec_urls_urls_more.head(2)
# Out:
#                                              message            timestamp  \
# 0  https://youtu.be/MR7p5Qhj4AE. https://youtu.be...  2020-12-12 15:43:24
# 1  Hood ornament? https://youtu.be/PIU07K_28ck. h...  2020-12-07 12:16:34
#
#              id  n_replies  n_likes      media_id  in_reply_to       from.id  \
# 0  1.786305e+16        0.0      0.0  2.462526e+18          NaN  1.579422e+10
# 1  1.794331e+16        0.0      0.0  2.458729e+18          NaN  1.579422e+10
#
#   from.username from.is_verified                           from.url  \
# 0       ticetm6            False  https://www.instagram.com/ticetm6
# 1       ticetm6            False  https://www.instagram.com/ticetm6
#
#   from.profile_pic                                               urls  n_urls
# 0              NaN  [https://youtu.be/MR7p5Qhj4AE, https://youtu.b...       2
# 1              NaN  [https://youtu.be/PIU07K_28ck, https://youtu.b...       5

# %%
df_comments_dec_urls_urls_more_with_users_count = more_than_one_link_with_count_(
    df_comments_dec_urls_urls_more, "from.id", "urls"
)

# %%
df_comments_dec_urls_urls_more_with_users_count
# Out:
#                             link  count  n_users            users n_urls
# 0   https://youtu.be/MR7p5Qhj4AE      2        1  {15794220150.0}    {2}
# 1   https://youtu.be/nxz1DuVaRr8      1        1  {15794220150.0}    {2}
# 2   https://youtu.be/PIU07K_28ck      1        1  {15794220150.0}    {5}
# 3   https://youtu.be/sdktDOeG2VI      1        1  {15794220150.0}    {5}
# 4   https://youtu.be/vksEJR9EPQ8      1        1  {15794220150.0}    {5}
# 5   https://youtu.be/tQowAJAZgoU      1        1  {15794220150.0}    {5}
# 6   https://youtu.be/GVDF_GkNAYA      1        1  {15794220150.0}    {5}
# 7   https://youtu.be/YRpSW12W0X0      1        1  {15794220150.0}    {5}
# 8   https://youtu.be/VkWecKUvS1c      1        1  {15794220150.0}    {5}
# 9   https://youtu.be/wJUn3XkGZVg      1        1  {15794220150.0}    {5}
# 10  https://youtu.be/4qGNAAephuk      1        1  {15794220150.0}    {5}
# 11  https://youtu.be/bMCpVtWFL-Y      1        1  {15794220150.0}    {5}
# ...

# %%
df_comments_dec_urls_with_users_count = pd.concat(
    [
        df_comments_dec_urls_1_link_ith_users_count,
        df_comments_dec_urls_urls_more_with_users_count,
    ]
).sort_values("count", ascending=False)

# %%
df_comments_dec_urls_with_users_count
# Out:
#                                                  link  count  n_users  \
# 0   https://www.change.org/p/dc-entertainment-remo...     26        7
# 30                          http://chng.it/6FQKFDHkLS     13        1
# 38                          http://chng.it/Tx29y72h7Y     12        1
# 3                           http://chng.it/d4wSkC9HZs     12        2
# 41                          http://chng.it/DT7NQwK8kG     11        1
# ..                                                ...    ...      ...
# 18                       https://youtu.be/eYxKUWuXVbQ      1        1
# 73  https://www.nativedsd.com/album-of-the-year-au...      1        1
# 19                       https://youtu.be/PJxHUA8muGQ      1        1
# 20                          http://chng.it/wppkqzRBBV      1        1
# 53                       https://youtu.be/g2NDs8QsyDI      1        1
#
#                                                 users n_urls
# 0   (30074255940.0, 3703701611.0, 2200653740.0, 56...    {1}
# ...

# %%
df_comments_dec_urls_with_users_count.to_csv(
    instagram_filter_path
    + "df_comments_dec_urls_with_users_count.csv",
    index=False,
)

# %% [markdown]
# <a id='Posts'></a>
#
# ## Posts
#
#
# ><ul>
#  <li><a href="#4p">4 Months</a></li>
#  <li><a href="#12p">December</a></li>
#
#  </ul>

# %%
df_posts = pd.read_csv(data_path + "posts.csv")

# %%
df_posts.head(2)
# Out:
#                     id            shortcode  \
# 0  2312672024680952662  2312672024680952662
# 1  2337634847974873162  2337634847974873162
#
#                                          display_url  \
# 0  https://instagram.fmci2-1.fna.fbcdn.net/v/t51....
# 1  https://scontent-lax3-1.cdninstagram.com/v/t51...
#
#                                    display_resources  is_video  \
# 0  [{'src': 'https://instagram.fmci2-1.fna.fbcdn....     False
# 1  [{'src': 'https://scontent-lax3-1.cdninstagram...     False
#
#                          edge_media_to_caption.edges  location.id  \
# 0  [{'node': {'text': 'According to the Digital t...  255561330.0
# 1                  [{'node': {'text': 'My girl❤️'}}]          NaN
#
#   location.has_public_page location.name location.slug  \
# 0                     True     Hollywood     hollywood
# 1                      NaN           NaN           NaN
#
#                                location.address_json      from.id  \
# ...

# %% [markdown]
# ### 4 Months
# <a id='4p'></a>
#
#
# ><ul>
#  <li><a href="#one4p">One Link</a></li>
#  <li><a href="#more4p">More Than One Link</a></li>
#
#  </ul>

# %%
# we have comments of the  4 months
# I will get posts ids of those comments
# then get all data for thos ids
df_comments_4_months.head(1)
# Out:
#   message           timestamp            id  n_replies  n_likes      media_id  \
# 0    ❤️❤️ 2021-04-06 20:05:29  1.787907e+16        0.0      0.0  2.546044e+18
#
#    in_reply_to       from.id  from.username from.is_verified  \
# 0          NaN  5.756303e+09  alsaifimuayad            False
#
#                                   from.url from.profile_pic urls  n_urls
# 0  https://www.instagram.com/alsaifimuayad              NaN   []       0

# %%
df_comments_4_months["media_id"][0]
# Out:
# 2.546043604621435e+18

# %%
df_posts[df_posts.id == df_comments_4_months["media_id"][0]]
# Out:
#                      id            shortcode  \
# 15  2546043604621434897  2546043604621434897
#
#                                           display_url  \
# 15  https://instagram.fmci2-1.fna.fbcdn.net/v/t51....
#
#                                     display_resources  is_video  \
# 15  [{'src': 'https://instagram.fmci2-1.fna.fbcdn....     False
#
#                           edge_media_to_caption.edges  location.id  \
# 15  [{'node': {'text': 'Link In Bio To Download Ta...          NaN
#
#    location.has_public_page location.name location.slug location.address_json  \
# 15                      NaN           NaN           NaN                   NaN
#
#         from.id from.username                                from.url  \
# 15  36751142509  amberheard.0  https://www.instagram.com/amberheard.0
#
#     location  taken_at_timestamp
# 15       NaN                 NaN

# %%
list_posts_ids_4_months = df_comments_4_months["media_id"].unique()

# %%
len(list_posts_ids_4_months)
# Out:
# 20928

# %%
len(df_posts.id.unique())
# Out:
# 193967

# %%
set(list_posts_ids_4_months).intersection(set(df_posts.id.unique()))
# Out:
# {1.9035445920050988e+18,
#  2.0734994473627994e+18,
#  2.1014975475759939e+18,
#  2.2586359230385733e+18,
#  2.421882471016575e+18,
#  2.422750292845442e+18,
#  2.432675037331797e+18,
#  2.439284102874798e+18,
#  2.447221389284803e+18,
#  2.4529160702166513e+18,
#  2.461260700167683e+18,
#  2.4775340182227057e+18,
#  2.4888356193486633e+18,
#  2.4900682544944435e+18,
#  2.490715753135702e+18,
#  2.4942116494654157e+18,
#  2.495650111061998e+18,
#  2.4994771103077975e+18,
#  2.5009388877973734e+18,
#  2.507236984840184e+18,
#  2.5162532350348575e+18,
#  2.5162873835117757e+18,
#  2.5177076516270484e+18,
#  2.521340643911749e+18,
#  2.5214231972754115e+18,
#  2.5219887401056246e+18,
#  2.5232477128144225e+18,
#  2.530113723997099e+18,
#  2.531243624144615e+18,
#  2.5322374864812785e+18,
#  2.5338919470313897e+18,
#  2.538991579011128e+18,
#  2.540587780839128e+18,
#  2.5408939905073664e+18,
#  2.541843572536169e+18,
#  2.5480581903799496e+18,
#  2.5492450622046106e+18,
# ...
