# %%
import pandas as pd
import json
import ast
import warnings
from ast import literal_eval as le
import plotly.express as px

warnings.filterwarnings("ignore")
import requests
import pandas as pd
import urlexpander


def unshorten(url):
    if "http" not in url:
        url = "http://" + url

    try:
        short = urlexpander.expand(url)
    except:
        short = url

    if "_ERROR__" in short:
        return url
    else:
        return short


def one_url_df(df, column="n_urls", urls="urls"):
    df = df[df[column] == 1]
    df[urls] = df[urls].apply(lambda x: x[0])
    return df


def more_url_df(df, interaction, n="n_urls", urls="urls"):
    df = df[df[n] > 1]
    temp = []
    for i in df.iterrows():
        row = i[1].to_dict()
        for url in row[urls]:
            temp.append((url, row[interaction], row[n]))
    return (
        pd.DataFrame(temp)
        .drop_duplicates()
        .rename(columns={0: urls, 1: interaction, 2: n})
    )

def plot(df, x):
    fig = px.histogram(df, x)
    fig.show();
    
def fix(df):
    df["urls"] = df["urls"].apply(lambda x: le(x))
    df["n_urls"] = df["urls"].apply(lambda x: len(x))

def un(df):
    df["urls"] = df["urls"].apply(lambda x: unshorten(x))
    
def sort(df, column):
    df.sort_values(column, inplace=True, ascending=False)

# %% [markdown]
# # Top Shared

# %% [markdown]
# ## Top Interacted

# %%
import os

# %%
# top interacted all files paths
all_top_interacted = [
    "../Top_Interacted/Data/" + i
    for i in os.listdir("../Top_Interacted/Data/")
    if i.split(".")[-1] == "csv"
]
all_top_interacted
# Out:
# ['../Top_Interacted/Data/change_4_months.csv',
#  '../Top_Interacted/Data/change_dec.csv',
#  '../Top_Interacted/Data/instagram_4_months.csv',
#  '../Top_Interacted/Data/instagram_dec.csv',
#  '../Top_Interacted/Data/reddits_4_months.csv',
#  '../Top_Interacted/Data/reddits_dec.csv',
#  '../Top_Interacted/Data/youtube_4_months.csv',
#  '../Top_Interacted/Data/youtube_dec.csv']

# %%
all_top_interacted_4_months = [i for i in all_top_interacted if "4_months" in i]
all_top_interacted_4_months
# Out:
# ['../Top_Interacted/Data/change_4_months.csv',
#  '../Top_Interacted/Data/instagram_4_months.csv',
#  '../Top_Interacted/Data/reddits_4_months.csv',
#  '../Top_Interacted/Data/youtube_4_months.csv']

# %%
all_top_interacted_dec = [i for i in all_top_interacted if "dec" in i]
all_top_interacted_dec
# Out:
# ['../Top_Interacted/Data/change_dec.csv',
#  '../Top_Interacted/Data/instagram_dec.csv',
#  '../Top_Interacted/Data/reddits_dec.csv',
#  '../Top_Interacted/Data/youtube_dec.csv']

# %%
li_4 = []
for filename in all_top_interacted_4_months:
    df = pd.read_csv(filename, index_col=None)
    li_4.append(df)

df_top_interacted_4_months = pd.concat(li_4, ignore_index=True).drop(columns={"Unnamed: 0"})
df_top_interacted_4_months
# Out:
#                                             shared_url  \
# 0    https://www.change.org/p/all-world-leaders-des...
# 1    https://www.change.org/p/%D0%BC%D0%B8%D0%B4-%D...
# 2    https://www.change.org/p/%D0%BC%D0%B8%D0%B4-%D...
# 3    https://www.change.org/p/loma-vista-recordings...
# 4    https://www.change.org/p/loma-vista-recordings...
# ..                                                 ...
# 556                              http://bit.ly/2OEM0OO
# 557                              http://bit.ly/2YPP8er
# 558                              http://bit.ly/2M8Mqei
# 559                              http://bit.ly/2KmFvfq
# 560                                                NaN
#
#                                           id/url  \
# 0                                       25752458
# 1                                       13641580
# 2                                       13641580
# 3                                       13641580
# 4                                       13641580
# ..                                           ...
# 556  https://www.youtube.com/watch?v=yeTS2Fx6nPg
# 557  https://www.youtube.com/watch?v=yeTS2Fx6nPg
# 558  https://www.youtube.com/watch?v=yeTS2Fx6nPg
# 559  https://www.youtube.com/watch?v=yeTS2Fx6nPg
# 560  https://www.youtube.com/watch?v=VzG4rT-BDEA
#
#                                                   text  n_likes     total  \
# 0    sign this, the fate of the world depends on it...      2.0       2.0
# 1    Johnny hold on! Now the same script was writte...      1.0       1.0
# 2    Johnny hold on! Now the same script was writte...      1.0       1.0
# 3    Johnny hold on! Now the same script was writte...      1.0       1.0
# 4    Johnny hold on! Now the same script was writte...      1.0       1.0
# ..                                                 ...      ...       ...
# 556               the evolution of amber | teen mom og   3002.0  774854.0
# 557               the evolution of amber | teen mom og   3002.0  774854.0
# 558               the evolution of amber | teen mom og   3002.0  774854.0
# 559               the evolution of amber | teen mom og   3002.0  774854.0
# 560  amber heard psychotic in elevator james franco...   4647.0  756424.0
#
#                                   url_id  media_id  n_replies  score  \
# 0    change_petition_comments_4_months_0       NaN        NaN    NaN
# 1    change_petition_comments_4_months_1       NaN        NaN    NaN
# 2    change_petition_comments_4_months_1       NaN        NaN    NaN
# 3    change_petition_comments_4_months_1       NaN        NaN    NaN
# 4    change_petition_comments_4_months_1       NaN        NaN    NaN
# ..                                   ...       ...        ...    ...
# 556           youtube_videos_4_months_35       NaN        NaN    NaN
# 557           youtube_videos_4_months_35       NaN        NaN    NaN
# 558           youtube_videos_4_months_35       NaN        NaN    NaN
# 559           youtube_videos_4_months_35       NaN        NaN    NaN
# 560           youtube_videos_4_months_36       NaN        NaN    NaN
#
#       n_views  n_dislikes  n_favorites  n_comments
# 0         NaN         NaN          NaN         NaN
# 1         NaN         NaN          NaN         NaN
# 2         NaN         NaN          NaN         NaN
# 3         NaN         NaN          NaN         NaN
# 4         NaN         NaN          NaN         NaN
# ..        ...         ...          ...         ...
# 556  383338.0       221.0          0.0       866.0
# 557  383338.0       221.0          0.0       866.0
# 558  383338.0       221.0          0.0       866.0
# 559  383338.0       221.0          0.0       866.0
# 560  372255.0       388.0          0.0       922.0
#
# [561 rows x 13 columns]

# %%
li_dec = []
for filename in all_top_interacted_dec:
    df = pd.read_csv(filename, index_col=None)
    li_dec.append(df)

df_top_interacted_dec = pd.concat(li_dec, ignore_index=True).drop(
    columns={"Unnamed: 0"}
)
df_top_interacted_dec
# Out:
#                                             shared_url  \
# 0    https://www.documentcloud.org/documents/583586...
# 1    https://www.documentcloud.org/documents/583586...
# 2    https://www.youtube.com/channel/UCjKNc-woAlnxt...
# 3    https://www.youtube.com/channel/UCjKNc-woAlnxt...
# 4    https://www.latimes.com/entertainment/gossip/l...
# ..                                                 ...
# 593                                www.scottreisch.com
# 594                          http://reischlawfirm.com/
# 595      https://teespring.com/stores/scottreischcom-3
# 596                        http://voirdire.libsyn.com/
# 597      https://www.facebook.com/crimetalkafficianado
#
#                                           id/url  \
# 0                                       25809054
# 1                                       25809054
# 2                                       25809054
# 3                                       25809054
# 4                                       25809054
# ..                                           ...
# 593  https://www.youtube.com/watch?v=XiuUzvZMyro
# 594  https://www.youtube.com/watch?v=XiuUzvZMyro
# 595  https://www.youtube.com/watch?v=XiuUzvZMyro
# 596  https://www.youtube.com/watch?v=XiuUzvZMyro
# 597  https://www.youtube.com/watch?v=XiuUzvZMyro
#
#                                                   text  n_likes     total  \
# 0    Amber Heard won and is innocent... UK Judge Ni...      9.0       9.0
# 1    Amber Heard won and is innocent... UK Judge Ni...      9.0       9.0
# 2    Amber Heard won and is innocent... UK Judge Ni...      9.0       9.0
# 3    Amber Heard won and is innocent... UK Judge Ni...      9.0       9.0
# 4    Amber Heard won and is innocent... UK Judge Ni...      9.0       9.0
# ..                                                 ...      ...       ...
# 593    amber heard arguing with johnny depp full audio   9233.0  706312.0
# 594    amber heard arguing with johnny depp full audio   9233.0  706312.0
# 595    amber heard arguing with johnny depp full audio   9233.0  706312.0
# 596    amber heard arguing with johnny depp full audio   9233.0  706312.0
# 597    amber heard arguing with johnny depp full audio   9233.0  706312.0
#
#                              url_id  media_id  n_replies  score   n_views  \
# 0    change_petition_comments_dec_0       NaN        NaN    NaN       NaN
# 1    change_petition_comments_dec_0       NaN        NaN    NaN       NaN
# 2    change_petition_comments_dec_0       NaN        NaN    NaN       NaN
# 3    change_petition_comments_dec_0       NaN        NaN    NaN       NaN
# 4    change_petition_comments_dec_0       NaN        NaN    NaN       NaN
# ..                              ...       ...        ...    ...       ...
# 593           youtube_videos_dec_43       NaN        NaN    NaN  686559.0
# 594           youtube_videos_dec_43       NaN        NaN    NaN  686559.0
# 595           youtube_videos_dec_43       NaN        NaN    NaN  686559.0
# 596           youtube_videos_dec_43       NaN        NaN    NaN  686559.0
# 597           youtube_videos_dec_43       NaN        NaN    NaN  686559.0
#
#      n_dislikes  n_favorites  n_comments
# 0           NaN          NaN         NaN
# 1           NaN          NaN         NaN
# 2           NaN          NaN         NaN
# 3           NaN          NaN         NaN
# 4           NaN          NaN         NaN
# ..          ...          ...         ...
# 593       331.0          0.0     10189.0
# 594       331.0          0.0     10189.0
# 595       331.0          0.0     10189.0
# 596       331.0          0.0     10189.0
# 597       331.0          0.0     10189.0
#
# [598 rows x 13 columns]

# %% [markdown]
# ## Shared URLs

# %%
shared_4_months = pd.read_csv("../URLs_Data/df_shared_4_months.csv")
shared_4_months.fillna("{1}", inplace=True)
shared_4_months["n_urls"] = shared_4_months["n_urls"].apply(lambda x: le(x))
shared_4_months.rename(columns={"shared_link": "shared_url"}, inplace=True)
shared_4_months.head(5)
# Out:
#                                           shared_url  n_shared  from_n_users  \
# 0  https://www.change.org/p/walt-disney-back-john...         6             1
# 1  https://www.change.org/p/me-johnny-depp-as-jac...         3             1
# 2  https://www.change.org/p/%D0%BC%D0%B8%D0%B4-%D...         2             1
# 3  https://www.change.org/p/loma-vista-recordings...         2             1
# 4  https://www.change.org/p/warner-brothers-keep-...         2             1
#
#            users n_urls platform              from
# 0  (1181480925,)    {1}   change  petition_comment
# 1  (1181480925,)    {1}   change  petition_comment
# 2   {1179297829}    {4}   change  petition_comment
# 3   {1179297829}    {4}   change  petition_comment
# 4   {1198070350}    {2}   change  petition_comment

# %%
shared_dec = pd.read_csv("../URLs_Data/df_shared_dec.csv")
shared_dec.rename(columns={"shared_link": "shared_url"}, inplace=True)
shared_dec.head(5)
# Out:
#                                           shared_url  n_shared  from_n_users  \
# 0  https://www.documentcloud.org/documents/583586...        16             4
# 1  https://www.latimes.com/entertainment/gossip/l...        16             4
# 2  https://www.truehollywoodtalk.com/amber-heards...        10             2
# 3  https://www.youtube.com/channel/UCjKNc-woAlnxt...         8             2
# 4  https://www.change.org/p/we-support-amber-hear...         6             1
#
#                                              users      n_urls platform  \
# 0  {948054032, 1129808400, 1136503772, 1081693988}  {8, 10, 4}   change
# 1  {948054032, 1129808400, 1136503772, 1081693988}  {8, 10, 4}   change
# 2                         {1136503772, 1081693988}  {8, 10, 2}   change
# 3                         {1136503772, 1081693988}     {8, 10}   change
# 4                                     {1081693988}        {10}   change
#
#                from
# 0  petition_comment
# 1  petition_comment
# 2  petition_comment
# 3  petition_comment
# 4  petition_comment

# %% [markdown]
# # 4

# %% [markdown]
# ### Top shared youtube across all platforms

# %%
top_shared_4_months_all_platforms = pd.merge(
    shared_4_months, df_top_interacted_4_months, how="inner"
)
top_shared_4_months_all_platforms = top_shared_4_months_all_platforms.sort_values(
    "total", ascending=False
).reset_index(drop=True)

# %%
top_shared_4_months_all_platforms
# Out:
#                                             shared_url  n_shared  \
# 0           https://www.instagram.com/amberryphoeberry         1
# 1    https://www.roblox.com/groups/3857126/Amberry-...         1
# 2       https://www.roblox.com/users/275424983/profile         1
# 3    https://www.youtube.com/watch?v=HIShWZkr0hs&li...         1
# 4    https://www.youtube.com/watch?v=-AP5Y791RN4&li...         1
# ..                                                 ...       ...
# 748  https://www.change.org/p/walt-disney-back-john...         6
# 749  https://www.change.org/p/walt-disney-back-john...         6
# 750  https://www.change.org/p/walt-disney-back-john...         6
# 751  https://www.change.org/p/walt-disney-back-john...         6
# 752  https://www.change.org/p/walt-disney-back-john...         6
#
#      from_n_users                         users n_urls platform  \
# 0               1  {'UCxnYiv7s4698GRIlGE1_T7g'}    {7}  youtube
# 1               1  {'UCxnYiv7s4698GRIlGE1_T7g'}    {7}  youtube
# 2               1  {'UCxnYiv7s4698GRIlGE1_T7g'}    {7}  youtube
# 3               1  {'UCxnYiv7s4698GRIlGE1_T7g'}    {7}  youtube
# 4               1  {'UCxnYiv7s4698GRIlGE1_T7g'}    {7}  youtube
# ..            ...                           ...    ...      ...
# 748             1                 (1181480925,)    {1}   change
# 749             1                 (1181480925,)    {1}   change
# 750             1                 (1181480925,)    {1}   change
# 751             1                 (1181480925,)    {1}   change
# 752             1                 (1181480925,)    {1}   change
#
#                  from                                       id/url  \
# 0             comment  https://www.youtube.com/watch?v=A1kOXoxgt18
# 1             comment  https://www.youtube.com/watch?v=A1kOXoxgt18
# 2             comment  https://www.youtube.com/watch?v=A1kOXoxgt18
# 3             comment  https://www.youtube.com/watch?v=A1kOXoxgt18
# 4             comment  https://www.youtube.com/watch?v=A1kOXoxgt18
# ..                ...                                          ...
# 748  petition_comment                                     20186707
# 749  petition_comment                                     25829282
# 750  petition_comment                                     25829282
# 751  petition_comment                                     25717146
# 752  petition_comment                                     25717146
#
#                                                   text   n_likes       total  \
# 0    the day olive was born... 1 million subscriber...  154907.0  14885900.0
# 1    the day olive was born... 1 million subscriber...  154907.0  14885900.0
# 2    the day olive was born... 1 million subscriber...  154907.0  14885900.0
# 3    the day olive was born... 1 million subscriber...  154907.0  14885900.0
# 4    the day olive was born... 1 million subscriber...  154907.0  14885900.0
# ..                                                 ...       ...         ...
# 748                            http://chng.it/VzrzLNcM       0.0         0.0
# 749  Amber Heard/,,ble" jak já jí říkám je příšerná...       0.0         0.0
# 750                            http://chng.it/VzrzLNcM       0.0         0.0
# 751                            http://chng.it/VzrzLNcM       0.0         0.0
# 752  Ahoj, k petici jsem se připojila a podepsala j...       0.0         0.0
#
#                                    url_id  media_id  n_replies  score  \
# 0               youtube_videos_4_months_0       NaN        NaN    NaN
# 1               youtube_videos_4_months_0       NaN        NaN    NaN
# 2               youtube_videos_4_months_0       NaN        NaN    NaN
# 3               youtube_videos_4_months_0       NaN        NaN    NaN
# 4               youtube_videos_4_months_0       NaN        NaN    NaN
# ..                                    ...       ...        ...    ...
# 748  change_petition_comments_4_months_12       NaN        NaN    NaN
# 749   change_petition_comments_4_months_8       NaN        NaN    NaN
# 750   change_petition_comments_4_months_7       NaN        NaN    NaN
# 751   change_petition_comments_4_months_6       NaN        NaN    NaN
# 752   change_petition_comments_4_months_4       NaN        NaN    NaN
#
#        n_views  n_dislikes  n_favorites  n_comments
# 0    7271086.0      4605.0          0.0     12352.0
# 1    7271086.0      4605.0          0.0     12352.0
# 2    7271086.0      4605.0          0.0     12352.0
# 3    7271086.0      4605.0          0.0     12352.0
# 4    7271086.0      4605.0          0.0     12352.0
# ..         ...         ...          ...         ...
# 748        NaN         NaN          NaN         NaN
# 749        NaN         NaN          NaN         NaN
# 750        NaN         NaN          NaN         NaN
# 751        NaN         NaN          NaN         NaN
# 752        NaN         NaN          NaN         NaN
#
# [753 rows x 19 columns]

# %%
saving = "Data/_"

# %%
top_shared_4_months_all_platforms.to_csv(saving + "top_shared_4_months_all_platforms.csv")

# %% [markdown]
# # DEC

# %% [markdown]
# ### Top shared change across all platforms

# %%
top_shared_dec_all_platforms = pd.merge(
    shared_dec, df_top_interacted_dec, how="inner"
)
top_shared_dec_all_platforms = top_shared_dec_all_platforms.sort_values(
    "total", ascending=False
).reset_index(drop=True)

# %%
top_shared_dec_all_platforms
# Out:
#                                             shared_url  n_shared  \
# 0                      https://link.chtbl.com/7fp6uoqk         1
# 1                              https://twitter.com/wwe         1
# 2                                 http://goo.gl/akf0j4         1
# 3                    http://bit.ly/afterthebellpodcast         1
# 4                                https://giphy.com/wwe         1
# ..                                                 ...       ...
# 896  https://www.change.org/p/united-nations-remove...         1
# 897  https://www.change.org/p/united-nations-remove...         4
# 898  https://www.change.org/p/united-nations-remove...         4
# 899  https://www.change.org/p/the-walt-disney-compa...         1
# 900  https://www.change.org/p/united-nations-remove...         4
#
#      from_n_users                         users n_urls platform  \
# 0               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 1               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 2               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 3               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 4               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# ..            ...                           ...    ...      ...
# 896             1                 (1048865725,)    {1}   change
# 897             1                  {1048865725}    {2}   change
# 898             1                  {1048865725}    {2}   change
# 899             1                 (1167331579,)    {1}   change
# 900             1                  {1048865725}    {2}   change
#
#                  from                                       id/url  \
# 0             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 1             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 2             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 3             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 4             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# ..                ...                                          ...
# 896  petition_comment                                     14094292
# 897  petition_comment                                     14094292
# 898  petition_comment                                     14094292
# 899  petition_comment                                     25829282
# 900  petition_comment                                     22874214
#
#                                                   text    n_likes       total  \
# 0    full match - men's elimination chamber match: ...  1100425.0  91303003.0
# 1    full match - men's elimination chamber match: ...  1100425.0  91303003.0
# 2    full match - men's elimination chamber match: ...  1100425.0  91303003.0
# 3    full match - men's elimination chamber match: ...  1100425.0  91303003.0
# 4    full match - men's elimination chamber match: ...  1100425.0  91303003.0
# ..                                                 ...        ...         ...
# 896  There's another new similar petition by DV sur...        0.0         0.0
# 897  Another similar petition, please sign:\n\n<a h...        0.0         0.0
# 898  Another similar petition, please sign:\n\n<a h...        0.0         0.0
# 899  Johnny Depp deserves to get his career back. H...        0.0         0.0
# 900  New petition against Amber Heard, please sign:...        0.0         0.0
#
#                               url_id  media_id  n_replies  score     n_views  \
# 0               youtube_videos_dec_0       NaN        NaN    NaN  90110984.0
# 1               youtube_videos_dec_0       NaN        NaN    NaN  90110984.0
# 2               youtube_videos_dec_0       NaN        NaN    NaN  90110984.0
# 3               youtube_videos_dec_0       NaN        NaN    NaN  90110984.0
# 4               youtube_videos_dec_0       NaN        NaN    NaN  90110984.0
# ..                               ...       ...        ...    ...         ...
# 896  change_petition_comments_dec_12       NaN        NaN    NaN         NaN
# 897  change_petition_comments_dec_13       NaN        NaN    NaN         NaN
# 898  change_petition_comments_dec_13       NaN        NaN    NaN         NaN
# 899  change_petition_comments_dec_15       NaN        NaN    NaN         NaN
# 900  change_petition_comments_dec_14       NaN        NaN    NaN         NaN
#
#      n_dislikes  n_favorites  n_comments
# 0       70870.0          0.0     20724.0
# 1       70870.0          0.0     20724.0
# 2       70870.0          0.0     20724.0
# 3       70870.0          0.0     20724.0
# 4       70870.0          0.0     20724.0
# ..          ...          ...         ...
# 896         NaN          NaN         NaN
# 897         NaN          NaN         NaN
# 898         NaN          NaN         NaN
# 899         NaN          NaN         NaN
# 900         NaN          NaN         NaN
#
# [901 rows x 19 columns]

# %%
top_shared_dec_all_platforms.to_csv(saving + "top_shared_dec_all_platforms.csv")

# %%
top_shared_dec_all_platforms
# Out:
#                                             shared_url  n_shared  \
# 0                      https://link.chtbl.com/7fp6uoqk         1
# 1                              https://twitter.com/wwe         1
# 2                                 http://goo.gl/akf0j4         1
# 3                    http://bit.ly/afterthebellpodcast         1
# 4                                https://giphy.com/wwe         1
# ..                                                 ...       ...
# 896  https://www.change.org/p/united-nations-remove...         1
# 897  https://www.change.org/p/united-nations-remove...         4
# 898  https://www.change.org/p/united-nations-remove...         4
# 899  https://www.change.org/p/the-walt-disney-compa...         1
# 900  https://www.change.org/p/united-nations-remove...         4
#
#      from_n_users                         users n_urls platform  \
# 0               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 1               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 2               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 3               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 4               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# ..            ...                           ...    ...      ...
# 896             1                 (1048865725,)    {1}   change
# 897             1                  {1048865725}    {2}   change
# 898             1                  {1048865725}    {2}   change
# 899             1                 (1167331579,)    {1}   change
# 900             1                  {1048865725}    {2}   change
#
#                  from                                       id/url  \
# 0             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 1             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 2             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 3             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 4             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# ..                ...                                          ...
# 896  petition_comment                                     14094292
# 897  petition_comment                                     14094292
# 898  petition_comment                                     14094292
# 899  petition_comment                                     25829282
# 900  petition_comment                                     22874214
#
#                                                   text    n_likes       total  \
# 0    full match - men's elimination chamber match: ...  1100425.0  91303003.0
# 1    full match - men's elimination chamber match: ...  1100425.0  91303003.0
# 2    full match - men's elimination chamber match: ...  1100425.0  91303003.0
# 3    full match - men's elimination chamber match: ...  1100425.0  91303003.0
# 4    full match - men's elimination chamber match: ...  1100425.0  91303003.0
# ..                                                 ...        ...         ...
# 896  There's another new similar petition by DV sur...        0.0         0.0
# 897  Another similar petition, please sign:\n\n<a h...        0.0         0.0
# 898  Another similar petition, please sign:\n\n<a h...        0.0         0.0
# 899  Johnny Depp deserves to get his career back. H...        0.0         0.0
# 900  New petition against Amber Heard, please sign:...        0.0         0.0
#
#                               url_id  media_id  n_replies  score     n_views  \
# 0               youtube_videos_dec_0       NaN        NaN    NaN  90110984.0
# 1               youtube_videos_dec_0       NaN        NaN    NaN  90110984.0
# 2               youtube_videos_dec_0       NaN        NaN    NaN  90110984.0
# 3               youtube_videos_dec_0       NaN        NaN    NaN  90110984.0
# 4               youtube_videos_dec_0       NaN        NaN    NaN  90110984.0
# ..                               ...       ...        ...    ...         ...
# 896  change_petition_comments_dec_12       NaN        NaN    NaN         NaN
# 897  change_petition_comments_dec_13       NaN        NaN    NaN         NaN
# 898  change_petition_comments_dec_13       NaN        NaN    NaN         NaN
# 899  change_petition_comments_dec_15       NaN        NaN    NaN         NaN
# 900  change_petition_comments_dec_14       NaN        NaN    NaN         NaN
#
#      n_dislikes  n_favorites  n_comments
# 0       70870.0          0.0     20724.0
# 1       70870.0          0.0     20724.0
# 2       70870.0          0.0     20724.0
# 3       70870.0          0.0     20724.0
# 4       70870.0          0.0     20724.0
# ..          ...          ...         ...
# 896         NaN          NaN         NaN
# 897         NaN          NaN         NaN
# 898         NaN          NaN         NaN
# 899         NaN          NaN         NaN
# 900         NaN          NaN         NaN
#
# [901 rows x 19 columns]

# %% [markdown]
# ## Shared across all platforms

# %%
top_shared_4_months_all_platforms[["n_shared", "total"]].corr()
# Out:
#           n_shared     total
# n_shared  1.000000 -0.071608
# total    -0.071608  1.000000

# %%
top_shared_dec_all_platforms[["n_shared", "total"]].corr()
# Out:
#           n_shared     total
# n_shared  1.000000 -0.070427
# total    -0.070427  1.000000

# %%
top_shared_dec_all_platforms = pd.read_csv(saving + "top_shared_dec_all_platforms.csv")

# %%
top_shared_dec_all_platforms
# Out:
#      Unnamed: 0                                         shared_url  n_shared  \
# 0             0                    https://link.chtbl.com/7fp6uoqk         1
# 1             1                            https://twitter.com/wwe         1
# 2             2                               http://goo.gl/akf0j4         1
# 3             3                  http://bit.ly/afterthebellpodcast         1
# 4             4                              https://giphy.com/wwe         1
# ..          ...                                                ...       ...
# 896         896  https://www.change.org/p/united-nations-remove...         1
# 897         897  https://www.change.org/p/united-nations-remove...         4
# 898         898  https://www.change.org/p/united-nations-remove...         4
# 899         899  https://www.change.org/p/the-walt-disney-compa...         1
# 900         900  https://www.change.org/p/united-nations-remove...         4
#
#      from_n_users                         users n_urls platform  \
# 0               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 1               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 2               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 3               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# 4               1  {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube
# ..            ...                           ...    ...      ...
# 896             1                 (1048865725,)    {1}   change
# 897             1                  {1048865725}    {2}   change
# 898             1                  {1048865725}    {2}   change
# 899             1                 (1167331579,)    {1}   change
# 900             1                  {1048865725}    {2}   change
#
#                  from                                       id/url  \
# 0             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 1             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 2             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 3             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 4             comment  https://www.youtube.com/watch?v=lnlE_HEKuc0
# ..                ...                                          ...
# 896  petition_comment                                     14094292
# 897  petition_comment                                     14094292
# 898  petition_comment                                     14094292
# 899  petition_comment                                     25829282
# 900  petition_comment                                     22874214
#
#                                                   text    n_likes       total  \
# 0    full match - men's elimination chamber match: ...  1100425.0  91303003.0
# 1    full match - men's elimination chamber match: ...  1100425.0  91303003.0
# 2    full match - men's elimination chamber match: ...  1100425.0  91303003.0
# 3    full match - men's elimination chamber match: ...  1100425.0  91303003.0
# 4    full match - men's elimination chamber match: ...  1100425.0  91303003.0
# ..                                                 ...        ...         ...
# 896  There's another new similar petition by DV sur...        0.0         0.0
# 897  Another similar petition, please sign:\n\n<a h...        0.0         0.0
# 898  Another similar petition, please sign:\n\n<a h...        0.0         0.0
# 899  Johnny Depp deserves to get his career back. H...        0.0         0.0
# 900  New petition against Amber Heard, please sign:...        0.0         0.0
#
#                               url_id  media_id  n_replies  score     n_views  \
# 0               youtube_videos_dec_0       NaN        NaN    NaN  90110984.0
# 1               youtube_videos_dec_0       NaN        NaN    NaN  90110984.0
# 2               youtube_videos_dec_0       NaN        NaN    NaN  90110984.0
# 3               youtube_videos_dec_0       NaN        NaN    NaN  90110984.0
# 4               youtube_videos_dec_0       NaN        NaN    NaN  90110984.0
# ..                               ...       ...        ...    ...         ...
# 896  change_petition_comments_dec_12       NaN        NaN    NaN         NaN
# 897  change_petition_comments_dec_13       NaN        NaN    NaN         NaN
# 898  change_petition_comments_dec_13       NaN        NaN    NaN         NaN
# 899  change_petition_comments_dec_15       NaN        NaN    NaN         NaN
# 900  change_petition_comments_dec_14       NaN        NaN    NaN         NaN
#
#      n_dislikes  n_favorites  n_comments
# 0       70870.0          0.0     20724.0
# 1       70870.0          0.0     20724.0
# 2       70870.0          0.0     20724.0
# 3       70870.0          0.0     20724.0
# 4       70870.0          0.0     20724.0
# ..          ...          ...         ...
# 896         NaN          NaN         NaN
# 897         NaN          NaN         NaN
# 898         NaN          NaN         NaN
# 899         NaN          NaN         NaN
# 900         NaN          NaN         NaN
#
# [901 rows x 20 columns]

# %%
with open("list_top_shared_urls.txt", "w") as f:
    f.write(str(list(top_shared_dec_all_platforms.shared_url.values)))
