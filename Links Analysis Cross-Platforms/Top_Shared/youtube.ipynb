# %%
import pandas as pd
import json
import ast
import warnings
from ast import literal_eval as le
import plotly.express as px

warnings.filterwarnings("ignore")
import requests
import pandas as pd
import urlexpander


def unshorten(url):
    if "http" not in url:
        url = "http://" + url

    try:
        short = urlexpander.expand(url)
    except:
        short = url

    if "_ERROR__" in short:
        return url
    else:
        return short


def one_url_df(df, column="n_urls", urls="urls"):
    df = df[df[column] == 1]
    df[urls] = df[urls].apply(lambda x: x[0])
    return df


def more_url_df(df, interaction, n="n_urls", urls="urls"):
    df = df[df[n] > 1]
    temp = []
    for i in df.iterrows():
        row = i[1].to_dict()
        for url in row[urls]:
            temp.append((url, row[interaction], row[n]))
    return (
        pd.DataFrame(temp)
        .drop_duplicates()
        .rename(columns={0: urls, 1: interaction, 2: n})
    )

def plot(df, x):
    fig = px.histogram(df, x)
    fig.show();
    
def fix(df):
    df["urls"] = df["urls"].apply(lambda x: le(x))
    df["n_urls"] = df["urls"].apply(lambda x: len(x))

def un(df):
    df["urls"] = df["urls"].apply(lambda x: unshorten(x))
    
def sort(df, column):
    df.sort_values(column, inplace=True, ascending=False)

# %% [markdown]
# # Top Shared

# %% [markdown]
# ## Top Interacted

# %%
top_4_months = pd.read_csv("../Top_Interacted_Data/youtube_4_months.csv").drop(columns= "Unnamed: 0")
top_4_months.head(5)
# Out:
#                                           shared_url  \
# 0                       https://youtu.be/Axcjv9YqYns
# 1                       https://youtu.be/dJe8bl_BLDE
# 2        https://www.youtube.com/watch?v=xCe6qh5kZ8Q
# 3                    https://ko-fi.com/irisbabilonia
# 4  https://www.change.org/p/dc-entertainment-remo...
#
#                                         id/url  \
# 0  https://www.youtube.com/watch?v=UvsHWTGHmts
# 1  https://www.youtube.com/watch?v=gEfWUbRfFR8
# 2  https://www.youtube.com/watch?v=Gq5uItRcKlo
# 3  https://www.youtube.com/watch?v=ESp6yvC3AxA
# 4  https://www.youtube.com/watch?v=gECq8x8b6bo
#
#                                                 text  n_likes  n_replies  \
# 0  Disney Officially Rehires Johnny Depp After Ca...   2174.0       82.0
# 1  WATCH NEXT ًں‘‡\n\nAmber Heard Faces Prison Af...    644.0       29.0
# 2  How much prison time do you think she deserves...    408.0      159.0
# ...

# %%
top_dec = pd.read_csv("../Top_Interacted_Data/youtube_dec.csv").drop(columns= "Unnamed: 0")
top_dec.head(5)
# Out:
#                                           shared_url  \
# 0  https://www.change.org/p/dc-entertainment-remo...
# 1  https://privateinternetaccess.com/TheQuarteringBF
# 2  https://displate.com/thequartering?art=5e0b6fe...
# 3                         n.pr/support-the-tiny-desk
# 4              https://lbry.tv/@NerdettesNewsStand:7
#
#                                         id/url  \
# 0  https://www.youtube.com/watch?v=pueTfFnZYt4
# 1  https://www.youtube.com/watch?v=XqdI8icEbDM
# 2  https://www.youtube.com/watch?v=9ILLMyWcUdE
# 3  https://www.youtube.com/watch?v=B_ymY0xG0LI
# 4  https://www.youtube.com/watch?v=hf-Udu30Lzs
#
#                                                 text  n_likes  n_replies  \
# 0  I am not a bot, I signed the petition and so d...    441.0       20.0
# 1  Amber Heard Wants You To Subscribe To My Chann...    282.0       40.0
# 2  Smash Like If You Are Getting Impatient On Kar...    125.0       14.0
# ...

# %% [markdown]
# ## Shared URLs

# %%
shared_4_months = pd.read_csv("../URLs_Data/df_shared_4_months.csv")
shared_4_months.fillna("{1}", inplace=True)
shared_4_months["n_urls"] = shared_4_months["n_urls"].apply(lambda x: le(x))
shared_4_months.rename(columns={"shared_link": "shared_url"}, inplace=True)
shared_4_months.head(5)
# Out:
#                                           shared_url  n_shared  from_n_users  \
# 0  https://www.change.org/p/walt-disney-back-john...         6             1
# 1  https://www.change.org/p/me-johnny-depp-as-jac...         3             1
# 2  https://www.change.org/p/%D0%BC%D0%B8%D0%B4-%D...         2             1
# 3  https://www.change.org/p/loma-vista-recordings...         2             1
# 4  https://www.change.org/p/warner-brothers-keep-...         2             1
#
#            users n_urls platform              from
# 0  (1181480925,)    {1}   change  petition_comment
# 1  (1181480925,)    {1}   change  petition_comment
# 2   {1179297829}    {4}   change  petition_comment
# 3   {1179297829}    {4}   change  petition_comment
# 4   {1198070350}    {2}   change  petition_comment

# %%
shared_dec = pd.read_csv("../URLs_Data/df_shared_dec.csv")
shared_dec.rename(columns={"shared_link": "shared_url"}, inplace=True)
shared_dec.head(5)
# Out:
#                                           shared_url  n_shared  from_n_users  \
# 0  https://www.documentcloud.org/documents/583586...        16             4
# 1  https://www.latimes.com/entertainment/gossip/l...        16             4
# 2  https://www.truehollywoodtalk.com/amber-heards...        10             2
# 3  https://www.youtube.com/channel/UCjKNc-woAlnxt...         8             2
# 4  https://www.change.org/p/we-support-amber-hear...         6             1
#
#                                              users      n_urls platform  \
# 0  {948054032, 1129808400, 1136503772, 1081693988}  {8, 10, 4}   change
# 1  {948054032, 1129808400, 1136503772, 1081693988}  {8, 10, 4}   change
# 2                         {1136503772, 1081693988}  {8, 10, 2}   change
# 3                         {1136503772, 1081693988}     {8, 10}   change
# 4                                     {1081693988}        {10}   change
#
#                from
# 0  petition_comment
# 1  petition_comment
# ...

# %% [markdown]
# # 4

# %% [markdown]
# ### Top shared youtube

# %%
shared_4_months_youtube = shared_4_months[shared_4_months.platform == "youtube"]
shared_4_months_youtube
# Out:
#                                               shared_url  n_shared  \
# 57281  https://support.google.com/youtube/answer/1620...        44
# 57282            https://www.patreon.com/thatumbrellaguy        43
# 57283  https://www.paypal.com/cgi-bin/webscr?cmd=_s-x...        43
# 57284                             https://bit.ly/3qF38D7        36
# 57285  https://www.youtube.com/channel/UCbiT0LUIbQj6C...        31
# ...                                                  ...       ...
# 59571                            https://amzn.to/3f38Nvw         1
# 59572  https://www.youtube.com/channel/UC5IjrvwGFvQQG...         1
# 59573                       https://youtu.be/Q8_DwMG1Rxc         1
# 59574                               http://goo.gl/sNYcVP         1
# 59575           https://www.instagram.com/p/CJEdjaNDQe5/         1
#
#        from_n_users                                              users  \
# 57281             4  {'UCzlicyYuPMjtF9VVvJr-PeA', 'UCbiT0LUIbQj6CQS...
# ...

# %%
saving = "../Top_Shared_Data/"

# %%
top_shared_youtube_4_months = pd.merge(
    shared_4_months_youtube, top_4_months, how="inner"
)
top_shared_youtube_4_months = top_shared_youtube_4_months.sort_values(
    "total", ascending=False
).reset_index(drop=True)

# %%
top_shared_youtube_4_months.to_csv(saving + "top_shared_youtube_4_months.csv")

# %% [markdown]
# ### Top shared youtube across all platforms

# %%
shared_4_months_youtube_all_platforms = pd.merge(
    shared_4_months, top_4_months, how="inner"
)
top_shared_youtube_4_months = top_shared_youtube_4_months.sort_values(
    "total", ascending=False
).reset_index(drop=True)

# %%
shared_4_months_youtube_all_platforms
# Out:
#                                             shared_url  n_shared  \
# 0                         https://youtu.be/uretrfMA-Io        17
# 1                         https://youtu.be/uretrfMA-Io         2
# 2                         https://youtu.be/uretrfMA-Io         1
# 3    https://www.change.org/p/dc-entertainment-remo...         1
# 4    https://www.change.org/p/dc-entertainment-remo...        58
# ..                                                 ...       ...
# 362            https://www.instagram.com/alvaromatusm/         1
# 363                             https://bit.ly/3qyOeOf         1
# 364  https://www.youtube.com/channel/UC7KWleqojdeC2...         1
# 365                                     http://wwe.yt/         1
# 366                     https://www.instagram.com/wwe/         1
#
#      from_n_users                                              users n_urls  \
# 0               8  (8576468286.0, 8993278596.0, 6355289605.0, 292...    {1}
# ...

# %%
shared_4_months_youtube_all_platforms.to_csv(saving + "top_shared_4_months_youtube_all_platforms.csv")

# %% [markdown]
# # DEC

# %% [markdown]
# ### Top shared youtube

# %%
shared_dec_youtube = shared_dec[shared_dec.platform == "youtube"]
shared_dec_youtube
# Out:
#                                               shared_url  n_shared  \
# 21839  https://www.paypal.com/cgi-bin/webscr?cmd=_s-x...        40
# 21840            https://www.patreon.com/thatumbrellaguy        39
# 21841                              http://bit.ly/2xb5cqa        33
# 21842                 https://twitter.com/informoverload        32
# 21843  https://www.change.org/p/dc-entertainment-remo...        27
# ...                                                  ...       ...
# 24375               http://instagram.com/konradgladyszek         1
# 24376                      https://nordvpn.org/communitv         1
# 24377                             https://bit.ly/2ynbkes         1
# 24378                https://www.tubebuddy.com/communitv         1
# 24379                       https://youtu.be/rVYo2cz6_ME         1
#
#        from_n_users                                              users  \
# 21839             1                       {'UCMAwi5fm2yOSEeKd_Qv0Z2Q'}
# ...

# %%
top_shared_youtube_dec = pd.merge(
    shared_dec_youtube, top_dec, how="inner"
)
top_shared_youtube_dec = top_shared_youtube_dec.sort_values(
    "total", ascending=False
).reset_index(drop=True)

# %%
top_shared_youtube_dec
# Out:
#                                             shared_url  n_shared  \
# 0                     https://www.youtube.com/wwemusic         1
# 1                             http://wwe.yt/wwenetwork         1
# 2                https://www.youtube.com/wwetotaldivas         1
# 3                       https://www.instagram.com/wwe/         1
# 4                 https://www.youtube.com/upupdowndown         1
# ..                                                 ...       ...
# 336  https://www.google.com/url?sa=t&source=web&rct...         1
# 337  https://variety.com/2018/biz/news/johnny-depp-...         1
# 338  https://www.dnaindia.com/hollywood/report-neve...         1
# 339           http://news.bbc.co.uk/1/hi/uk/269156.stm         1
# 340  https://www.cdc.gov/coronavirus/2019-ncov/dail...         1
#
#      from_n_users                          users n_urls platform     from  \
# 0               1   {'UCJ5v_MCY6GNUBTO8-D3XoAg'}   {16}  youtube  comment
# ...

# %%
top_shared_youtube_dec.to_csv(saving + "top_shared_youtube_dec.csv")

# %% [markdown]
# ### Top shared youtube across all platforms

# %%
shared_dec_youtube_all_platforms = pd.merge(
    shared_dec, top_dec, how="inner"
)
top_shared_youtube_dec = top_shared_youtube_dec.sort_values(
    "total", ascending=False
).reset_index(drop=True)

# %%
shared_dec_youtube_all_platforms
# Out:
#                                             shared_url  n_shared  \
# 0    https://www.change.org/p/dc-entertainment-remo...         1
# 1    https://www.change.org/p/dc-entertainment-remo...        26
# 2    https://www.change.org/p/dc-entertainment-remo...         2
# 3    https://www.change.org/p/dc-entertainment-remo...       105
# 4    https://www.change.org/p/dc-entertainment-remo...        14
# ..                                                 ...       ...
# 345  https://www.cbssports.com/nfl/news/2020-super-...         1
# 346                            https://phil.chrono.gg/         1
# 347                           http://defrancoelite.com         1
# 348                        http://beautifulbastard.com         1
# 349                            http://shopdefranco.com         1
#
#      from_n_users                                              users n_urls  \
# 0               1                                       (948054032,)    {1}
# ...

# %%
shared_dec_youtube_all_platforms.to_csv(saving + "top_shared_dec_youtube_all_platforms.csv")
