# %%
import pandas as pd
import os
import glob

# %%
all_data = [i for i in os.listdir("Data") if i.split('.')[-1] == "csv"]
all_data
# Out:
# ['change_4_months.csv',
#  'change_dec.csv',
#  'instagram_4_months.csv',
#  'instagram_dec.csv',
#  'reddits_4_months.csv',
#  'reddits_dec.csv',
#  'youtube_4_months.csv',
#  'youtube_dec.csv']

# %%
dec_data = [i for i in all_data if "dec" in i]
months_data = [i for i in all_data if "4_months" in i]

# %%
dec_data
# Out:
# ['change_dec.csv', 'instagram_dec.csv', 'reddits_dec.csv', 'youtube_dec.csv']

# %%
months_data
# Out:
# ['change_4_months.csv',
#  'instagram_4_months.csv',
#  'reddits_4_months.csv',
#  'youtube_4_months.csv']

# %%
dec = []

for filename in dec_data:
    df = pd.read_csv("Data/" + filename, index_col=None, header=0)
    dec.append(df)

df_dec = pd.concat(dec, axis=0, ignore_index=True)

# %%
df_dec["platform"] = df_dec["url_id"].apply(lambda x: str(x).split("_")[0])

# %%
df_dec["platform"] =df_dec["platform"].replace("nan", "reddit")

# %%
df_dec.drop(columns="Unnamed: 0").sort_values("total", ascending=False).to_csv(
    "Data/_all_dec.csv", index=False
)

# %%
df_dec.drop(columns="Unnamed: 0").sort_values("total", ascending=False)
# Out:
#                                             shared_url  \
# 362                       https://www.facebook.com/wwe
# 360              https://www.youtube.com/wwetotaldivas
# 352                           http://wwe.yt/wwenetwork
# 353                                     http://wwe.yt/
# 354                               http://goo.gl/akf0j4
# ..                                                 ...
# 63   https://www.change.org/p/united-nations-remove...
# 62   https://www.change.org/p/united-nations-remove...
# 61   https://www.change.org/p/united-nations-remove...
# 60   https://www.change.org/p/united-nations-remove...
# 59   https://www.change.org/p/dc-entertainment-remo...
#
#                                           id/url  \
# 362  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 360  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 352  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 353  https://www.youtube.com/watch?v=lnlE_HEKuc0
# 354  https://www.youtube.com/watch?v=lnlE_HEKuc0
# ..                                           ...
# 63                                      22874214
# 62                                      14094292
# 61                                      14094292
# 60                                      14094292
# 59                                      26152026
#
#                                                   text    n_likes       total  \
# 362  full match - men's elimination chamber match: ...  1100425.0  91303003.0
# 360  full match - men's elimination chamber match: ...  1100425.0  91303003.0
# 352  full match - men's elimination chamber match: ...  1100425.0  91303003.0
# 353  full match - men's elimination chamber match: ...  1100425.0  91303003.0
# 354  full match - men's elimination chamber match: ...  1100425.0  91303003.0
# ..                                                 ...        ...         ...
# 63   New petition against Amber Heard, please sign:...        0.0         0.0
# 62   Another similar petition, please sign:\n\n<a h...        0.0         0.0
# 61   Another similar petition, please sign:\n\n<a h...        0.0         0.0
# 60   There's another new similar petition by DV sur...        0.0         0.0
# 59   KAITLYN HAESTIER-KAITLYN HAESTIER\nPlease note...        0.0         0.0
#
#                               url_id  media_id  n_replies  score     n_views  \
# 362             youtube_videos_dec_0       NaN        NaN    NaN  90110984.0
# 360             youtube_videos_dec_0       NaN        NaN    NaN  90110984.0
# 352             youtube_videos_dec_0       NaN        NaN    NaN  90110984.0
# 353             youtube_videos_dec_0       NaN        NaN    NaN  90110984.0
# 354             youtube_videos_dec_0       NaN        NaN    NaN  90110984.0
# ..                               ...       ...        ...    ...         ...
# 63   change_petition_comments_dec_14       NaN        NaN    NaN         NaN
# 62   change_petition_comments_dec_13       NaN        NaN    NaN         NaN
# 61   change_petition_comments_dec_13       NaN        NaN    NaN         NaN
# 60   change_petition_comments_dec_12       NaN        NaN    NaN         NaN
# 59   change_petition_comments_dec_11       NaN        NaN    NaN         NaN
#
#      n_dislikes  n_favorites  n_comments platform
# 362     70870.0          0.0     20724.0  youtube
# 360     70870.0          0.0     20724.0  youtube
# 352     70870.0          0.0     20724.0  youtube
# 353     70870.0          0.0     20724.0  youtube
# 354     70870.0          0.0     20724.0  youtube
# ..          ...          ...         ...      ...
# 63          NaN          NaN         NaN   change
# 62          NaN          NaN         NaN   change
# 61          NaN          NaN         NaN   change
# 60          NaN          NaN         NaN   change
# 59          NaN          NaN         NaN   change
#
# [598 rows x 14 columns]

# %%
months_4 = []

for filename in months_data:
    df = pd.read_csv("Data/" + filename, index_col=None, header=0)
    months_4.append(df)

df_4_months = pd.concat(months_4, axis=0, ignore_index=True)

# %%
df_4_months["platform"] = df_4_months["url_id"].apply(lambda x: str(x).split("_")[0])

# %%
df_4_months = df_4_months.drop(columns="Unnamed: 0").sort_values("total", ascending=False)

# %%
df_4_months["platform"] = df_4_months["platform"].replace("nan", "reddit")

# %%
df_4_months.to_csv("Data/_all_4_months.csv", index=False)

# %%
df_4_months.drop(columns="Unnamed: 0").sort_values("total", ascending=False)
# Out:
#                                             shared_url  \
# 392  https://www.youtube.com/watch?v=HIShWZkr0hs&li...
# 391  https://www.youtube.com/watch?v=-AP5Y791RN4&li...
# 390  https://www.youtube.com/watch?v=4ZLluUVOnHo&li...
# 389  https://www.roblox.com/groups/3857126/Amberry-...
# 388     https://www.roblox.com/users/275424983/profile
# ..                                                 ...
# 13   https://www.change.org/p/warner-brothers-keep-...
# 14   https://www.change.org/p/warner-brothers-keep-...
# 16                            http://www.eximp.com.co/
# 17   https://www.change.org/p/walt-disney-back-john...
# 15   https://www.facebook.com/Delihealth-1014197053...
#
#                                           id/url  \
# 392  https://www.youtube.com/watch?v=A1kOXoxgt18
# 391  https://www.youtube.com/watch?v=A1kOXoxgt18
# 390  https://www.youtube.com/watch?v=A1kOXoxgt18
# 389  https://www.youtube.com/watch?v=A1kOXoxgt18
# 388  https://www.youtube.com/watch?v=A1kOXoxgt18
# ..                                           ...
# 13                                      25699776
# 14                                      25699776
# 16                                      26128212
# 17                                      20186707
# 15                                      26128212
#
#                                                   text   n_likes       total  \
# 392  the day olive was born... 1 million subscriber...  154907.0  14885900.0
# 391  the day olive was born... 1 million subscriber...  154907.0  14885900.0
# 390  the day olive was born... 1 million subscriber...  154907.0  14885900.0
# 389  the day olive was born... 1 million subscriber...  154907.0  14885900.0
# 388  the day olive was born... 1 million subscriber...  154907.0  14885900.0
# ..                                                 ...       ...         ...
# 13   <a href="https://www.change.org/p/warner-broth...       0.0         0.0
# 14   <a href="https://www.change.org/p/warner-broth...       0.0         0.0
# 16   Granolas Delihealth\nEn Delihealth. Solicita t...       0.0         0.0
# 17                             http://chng.it/VzrzLNcM       0.0         0.0
# 15   Granolas Delihealth\nEn Delihealth. Solicita t...       0.0         0.0
#
#                                    url_id  media_id  n_replies  score  \
# 392             youtube_videos_4_months_0       NaN        NaN    NaN
# 391             youtube_videos_4_months_0       NaN        NaN    NaN
# 390             youtube_videos_4_months_0       NaN        NaN    NaN
# 389             youtube_videos_4_months_0       NaN        NaN    NaN
# 388             youtube_videos_4_months_0       NaN        NaN    NaN
# ..                                    ...       ...        ...    ...
# 13   change_petition_comments_4_months_10       NaN        NaN    NaN
# 14   change_petition_comments_4_months_10       NaN        NaN    NaN
# 16   change_petition_comments_4_months_11       NaN        NaN    NaN
# 17   change_petition_comments_4_months_12       NaN        NaN    NaN
# 15   change_petition_comments_4_months_11       NaN        NaN    NaN
#
#        n_views  n_dislikes  n_favorites  n_comments platform
# 392  7271086.0      4605.0          0.0     12352.0  youtube
# 391  7271086.0      4605.0          0.0     12352.0  youtube
# 390  7271086.0      4605.0          0.0     12352.0  youtube
# 389  7271086.0      4605.0          0.0     12352.0  youtube
# 388  7271086.0      4605.0          0.0     12352.0  youtube
# ..         ...         ...          ...         ...      ...
# 13         NaN         NaN          NaN         NaN   change
# 14         NaN         NaN          NaN         NaN   change
# 16         NaN         NaN          NaN         NaN   change
# 17         NaN         NaN          NaN         NaN   change
# 15         NaN         NaN          NaN         NaN   change
#
# [561 rows x 14 columns]
